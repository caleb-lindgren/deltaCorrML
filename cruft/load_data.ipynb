# %% [markdown]
# # Load data

# %%
import cptac.pancan as pc
import cptac.utils as cput
import numpy as np
import os
import pandas as pd
import pcprutils as ut
import altair as alt

# %% [markdown]
# ### Get pancancerProteinMRNA repository path
#
# This analysis will build off of data stored in the [pancancerProteinMRNA repo](https://github.com/PayneLab/pancancerProteinMRNA), which is publicly accessible. To access that data, clone the repository, then store the path to it in a text file with no quotes named `pancancerProteinMRNA_repo_path.txt` in the same directory as this notebook. The notebook will then read the path from that file and be able to access the data.

# %%
with open("pancancerProteinMRNA_repo_path.txt", "r") as pcp_path_file:
    pcp_path = pcp_path_file.read()

print(pcp_path)
# Out:
# /Users/Bryn/PayneLab/pancancer/pancancerProteinMRNA

# %%
cancer_types = [
    "ccrcc",
    "endometrial",
    "hnscc",
    "lscc",
    "luad",
]

# %% [markdown]
# ### Load delta correlations

# %%
delta_corr_path = os.path.join(pcp_path, "notebook_steps_Spearman", "data", "delta_correlation_df.csv")
delta_corr = pd.read_csv(delta_corr_path)
delta_corr = delta_corr.assign(Cancer=delta_corr["Cancer"].str.lower())

delta_corr
# Out:
#          Gene  Delta_Correlation       P_Value           FDR       Cancer
# 0        A1BG          -0.198013  2.451044e-01  4.045115e-01        hnscc
# 1         A2M          -0.118384  4.480278e-01  6.091130e-01        hnscc
# 2       A2ML1          -0.023469  2.918125e-01  4.561968e-01        hnscc
# 3        AAAS           0.275905  1.051756e-01  2.209072e-01        hnscc
# 4        AACS          -0.136836  1.800586e-01  3.266475e-01        hnscc
# ...       ...                ...           ...           ...          ...
# 50684   ZWINT           1.219024  2.267627e-09  1.049863e-07  endometrial
# 50685    ZXDC          -0.346532  2.983295e-01  5.386144e-01  endometrial
# 50686  ZYG11B           0.768196  5.463938e-04  5.319699e-03  endometrial
# 50687     ZYX           0.253630  2.456049e-01  4.795301e-01  endometrial
# 50688   ZZEF1           0.176244  5.839048e-01  7.795750e-01  endometrial
#
# [50689 rows x 5 columns]

# %% [markdown]
# ### Load gene-based residuals data

# %%
residuals = {}
residuals_dir_path = os.path.join(pcp_path, "notebook_steps_Spearman", "clinical_associations")

for cancer_type in cancer_types:
    file_name = f"{cancer_type}_residuals.tsv.gz"
    res = pd.read_csv(os.path.join(residuals_dir_path, file_name), sep="\t")
    res = res.assign(Patient_ID=res["Patient_ID"].str.split("\.N", expand=True)[0]) # Make paired Patient_IDs same
    residuals[cancer_type] = res

residuals["ccrcc"]
# Out:
#        Patient_ID     Gene  Proteomics  Tissue  Transcriptomics         m  \
# 0       C3L-00004     A1CF    0.641447   Tumor        16.677828  0.082623
# 1       C3L-00010     A1CF    0.194620   Tumor        16.682712  0.082623
# 2       C3L-00011     A1CF   -0.780455   Tumor         0.245606  0.082623
# 3       C3L-00026     A1CF    0.404286   Tumor        16.347532  0.082623
# 4       C3L-00079     A1CF   -0.677773   Tumor         4.858958  0.082623
# ...           ...      ...         ...     ...              ...       ...
# 527860  C3N-01646  ZSCAN18   -0.018171  Normal        13.238732  0.045205
# 527861  C3N-01648  ZSCAN18    0.155586  Normal        10.655611  0.045205
# 527862  C3N-01649  ZSCAN18    0.076949  Normal        15.453511  0.045205
# 527863  C3N-01651  ZSCAN18    0.091213  Normal        10.846205  0.045205
# 527864  C3N-01808  ZSCAN18   -0.032070  Normal        13.181020  0.045205
#
#                b  orth_resid  intersect_x  intersect_y  above_reg_line
# 0      -0.847022    0.110114    16.686895     0.531707            True
# 1      -0.847022    0.335598    16.655078     0.529078           False
# 2      -0.847022    0.046116     0.249403    -0.826415            True
# 3      -0.847022    0.099045    16.339377     0.502994           False
# 4      -0.847022    0.231427     4.839902    -0.447132           False
# ...          ...         ...          ...          ...             ...
# 527860 -0.511652    0.104866    13.233996     0.086587           False
# 527861 -0.511652    0.185364    10.663982    -0.029590            True
# 527862 -0.511652    0.109859    15.448550     0.186696           False
# 527863 -0.511652    0.112450    10.851283    -0.021123            True
# 527864 -0.511652    0.116144    13.175775     0.083955           False
#
# [527865 rows x 11 columns]

# %% [markdown]
# ## For information's sake, use the residuals tables to figure out how many paired tumor-normal samples there are in each cancer type

# %%
def get_paired_sample_count(cancer_type, residuals_map):
    res = residuals_map[cancer_type][["Patient_ID", "Tissue"]].drop_duplicates(keep="first")
    return res.\
    assign(Patient_ID=res["Patient_ID"].str.split("\.N", expand=True)[0]).\
    pivot(
        index="Patient_ID",
        columns="Tissue",
        values="Tissue"
    ).\
    dropna(axis=0, how="any").\
    shape[0]

print("Number of paired tumor-normal samples in each cancer type:")
for cancer_type in cancer_types:
    print(f"{cancer_type: >11} - {get_paired_sample_count(cancer_type, residuals): >3}")
# Out:
# Number of paired tumor-normal samples in each cancer type:
#       ccrcc -  75
# endometrial -  14
#       hnscc -  42
#        lscc -  94
#        luad - 101

# %% [markdown]
# #### Calculate patient-wise tumor-normal residuals differences for genes with greatest change in correlation between tumor and normal (highest absolute value of delta correlation)

# %%
def get_highest_delta_corr(df):
    df = df.assign(abs_delta_corr=df["Delta_Correlation"].abs())
    df = df.sort_values(by="abs_delta_corr")
    df = df.loc[(df['FDR'] < 0.05) & ((df['Delta_Correlation'] > 0.7) | (df['Delta_Correlation'] < -0.7))]
    return df["Gene"].tolist()

highest_delta_genes = {}
for cancer in cancer_types:
    cancer_df = delta_corr.loc[delta_corr['Cancer'] == cancer]
    highest_delta_genes[cancer] = get_highest_delta_corr(cancer_df)

highest_delta_genes
# Out:
# {'ccrcc': ['AP4S1',
#   'GDAP1',
#   'UNC5B',
#   'ZDHHC2',
#   'USP47',
#   'NEK3',
#   'PTTG1IP',
#   'STRA6',
#   'AZI2',
#   'WNK1',
#   'RALGAPA1',
#   'FAF2',
#   'TSPYL4',
#   'SCGN',
#   'LSR',
#   'MUC15',
#   'SLC35A5',
#   'CLINT1',
#   'GMFB',
#   'RHAG',
#   'MARK3',
#   'EFHD1',
#   'CR2',
#   'CNTLN',
#   'PEG10',
#   'PTPRG',
#   'NACC1',
#   'C9orf78',
#   'IGF2BP3',
#   'LY6E',
#   'MUC13',
#   'YARS2',
#   'CERCAM',
#   'PGK1',
#   'LPCAT1',
#   'AP3M1',
#   'NCOA7',
#   'DNAAF2',
#   'NPEPPS',
#   'METAP1D',
#   'PGBD5',
#   'SCAP',
#   'CCP110',
#   'GOLPH3L',
#   'ALDH18A1',
#   'SLC36A2',
#   'PDCD7',
#   'PPM1M',
#   'GCDH',
#   'RBP2',
#   'POMT2',
#   'NOVA2',
#   'DLG5',
#   'APLP2',
#   'PGD',
#   'COLEC12',
#   'MCC',
#   'PIK3R4',
#   'PDZRN3',
#   'AHSA1',
#   'KIAA1522',
#   'CYP4F2',
#   'NOL3',
#   'SLC44A1',
#   'DCTD',
#   'ZNF358',
#   'ENPP2',
#   'PPID',
#   'PLS1',
#   'TTC36',
#   'NGLY1',
#   'EHD4',
#   'MAPK10',
#   'SMAP1',
#   'CCNY',
#   'PNCK',
#   'TREM2',
#   'PDP1',
#   'SMPD2',
#   'CALCRL',
#   'CLCC1',
#   'PPP1R3G',
#   'SLC22A8',
#   'NCAPD2',
#   'MIOS',
#   'PISD',
#   'BTN3A1',
#   'COL5A1',
#   'DUSP11',
#   'GNAI3',
#   'ANKZF1',
#   'SORCS3',
#   'XPNPEP1',
#   'HOOK1',
#   'SCAMP1',
#   'CTSS',
#   'FAM114A2',
#   'AGK',
#   'CD70',
#   'SLC12A1',
#   'POLA2',
#   'VPS25',
#   'TATDN1',
#   'DNALI1',
#   'PPIP5K2',
#   'GAP43',
#   'TTC7B',
#   'AGXT',
#   'USP6NL',
#   'SLC34A3',
#   'RNF138',
#   'CDH4',
#   'CTSV',
#   'KIR3DL2',
#   'NFIB',
#   'GNA13',
#   'RALA',
#   'FPGS',
#   'TMEM132A',
#   'C1GALT1C1',
#   'CTSO',
#   'SNTB2',
#   'KLHL12',
#   'UHRF1',
#   'DUSP9',
#   'KCNAB2',
#   'CACNA2D1',
#   'ASPN',
#   'GFOD1',
#   'TPX2',
#   'OLA1',
#   'EIF4EBP1',
#   'CFDP1',
#   'CLASP2',
#   'TRAM2',
#   'MAP2K4',
#   'COMMD2',
#   'GNAQ',
#   'SLC29A1',
#   'ATP2C1',
#   'GINS3',
#   'AQP2',
#   'CPNE6',
#   'GRAMD4',
#   'IDO1',
#   'PCSK6',
#   'GALNT5',
#   'ESD',
#   'CA9',
#   'CALB1',
#   'ASPM',
#   'NT5C1A',
#   'SEMA6B',
#   'CFAP36',
#   'FBXL2',
#   'RAB5A',
#   'KLHL29',
#   'ZEB1',
#   'HSD17B4',
#   'RCAN2',
#   'PTPRK',
#   'CHRD',
#   'TMEM88',
#   'PLA2G7',
#   'SLC12A3',
#   'PPP1R13B',
#   'COPZ2',
#   'TFG',
#   'SLFN13',
#   'ATP2B1',
#   'EPS8L3',
#   'ADCY3',
#   'HLA-G',
#   'SLC40A1',
#   'ATG2B',
#   'BET1',
#   'APPL1',
#   'MYCT1',
#   'INPP5E',
#   'INPP5A',
#   'C4orf19',
#   'ZNF397',
#   'SNX2',
#   'TLN2',
#   'KRBA1',
#   'RNASET2'],
#  'endometrial': ['GBP4',
#   'C12orf57',
#   'LRRC8E',
#   'SMC4',
#   'FKBP3',
#   'SERPINA3',
#   'HSPB7',
#   'IFIT2',
#   'NT5DC2',
#   'CXorf38',
#   'TRMT1L',
#   'SETMAR',
#   'MALT1',
#   'OTUD7B',
#   'RRP1B',
#   'CEACAM5',
#   'FBXL17',
#   'IPO9',
#   'KNTC1',
#   'BCAM',
#   'MIPEP',
#   'CKS1B',
#   'MET',
#   'GYS1',
#   'CLPTM1',
#   'POGZ',
#   'RTF1',
#   'PDCD2L',
#   'ACOT13',
#   'MUC4',
#   'EZR',
#   'CD47',
#   'WDR75',
#   'USP15',
#   'MACROD1',
#   'PPP2CB',
#   'UPF1',
#   'CTSZ',
#   'LDHD',
#   'RNASET2',
#   'TOM1',
#   'HKDC1',
#   'LPXN',
#   'ARHGAP35',
#   'TNFSF10',
#   'BOLA3',
#   'CEP55',
#   'SPAG1',
#   'SCYL2',
#   'EVI2B',
#   'TRERF1',
#   'FOXJ2',
#   'STRN',
#   'EHHADH',
#   'CLIC1',
#   'POF1B',
#   'HINT3',
#   'MSR1',
#   'EIF4EBP2',
#   'INCENP',
#   'PCNA',
#   'HOOK3',
#   'WDR47',
#   'RIPK1',
#   'PTPN12',
#   'INPP1',
#   'NCOA5',
#   'YBX3',
#   'SLC22A18',
#   'GATAD2A',
#   'CDC73',
#   'PHYHIPL',
#   'PTPRJ',
#   'PARP12',
#   'TMCO3',
#   'HSD17B4',
#   'CLTB',
#   'CWH43',
#   'SLC6A14',
#   'RANGRF',
#   'CHEK2',
#   'CPT1A',
#   'ANXA7',
#   'PPM1L',
#   'ZNF608',
#   'HEXIM1',
#   'GSTO1',
#   'DTX2',
#   'FGD4',
#   'HDHD2',
#   'KRTCAP3',
#   'CHMP4C',
#   'RHEB',
#   'ZWILCH',
#   'PLEKHS1',
#   'ZNF687',
#   'GM2A',
#   'TTYH3',
#   'YTHDF1',
#   'ERAL1',
#   'NME5',
#   'KIAA1211L',
#   'SLC9A7',
#   'ATP8B1',
#   'DECR1',
#   'ECHS1',
#   'ESRP1',
#   'ZNRF2',
#   'PIK3AP1',
#   'POLI',
#   'ANKRD22',
#   'FGFBP1',
#   'ZFP36L2',
#   'CEP97',
#   'SLC12A4',
#   'LGALS8',
#   'CYP2S1',
#   'KIF1A',
#   'KCTD12',
#   'GRAP',
#   'SLC38A1',
#   'PLCH1',
#   'SQLE',
#   'CD3EAP',
#   'FAM114A2',
#   'TXLNG',
#   'DDX60L',
#   'FBXL20',
#   'RABEP1',
#   'SMARCA2',
#   'NCLN',
#   'KIF20A',
#   'PIP4K2C',
#   'ZNF704',
#   'YRDC',
#   'EIF3H',
#   'CHCHD6',
#   'BAZ2A',
#   'AMOT',
#   'TTI2',
#   'SCGB2A2',
#   'MKNK1',
#   'RNF169',
#   'IFIT1',
#   'C2orf69',
#   'ARL3',
#   'IFT46',
#   'PCDH7',
#   'PROSER2',
#   'ZBTB10',
#   'KCTD1',
#   'CLEC3B',
#   'GMPS',
#   'MPV17',
#   'MARVELD2',
#   'DCAF6',
#   'CASP3',
#   'DPF2',
#   'ALDH3A1',
#   'DOK1',
#   'RFC1',
#   'SRP54',
#   'FAM83G',
#   'NPL',
#   'CAND1',
#   'OAS3',
#   'AQP5',
#   'GNE',
#   'MISP',
#   'CCDC86',
#   'TOMM22',
#   'GPX1',
#   'KIFC1',
#   'SNTB2',
#   'DDX49',
#   'SIRT1',
#   'FBXO4',
#   'ESR1',
#   'VIM',
#   'BCKDK',
#   'FGR',
#   'PITPNC1',
#   'ZNF592',
#   'SYNCRIP',
#   'NSUN2',
#   'RIOK1',
#   'UBR1',
#   'GIMAP1',
#   'COPRS',
#   'NTN4',
#   'RELB',
#   'RTN4IP1',
#   'SECISBP2L',
#   'MLKL',
#   'THADA',
#   'ZYG11B',
#   'FOLH1',
#   'NFAT5',
#   'TBXAS1',
#   'SOX6',
#   'GCNT1',
#   'ASF1B',
#   'SLC44A4',
#   'HSD17B12',
#   'S100A14',
#   'GTF2E2',
#   'MGLL',
#   'STOX2',
#   'PDE12',
#   'STARD7',
#   'CHD4',
#   'PCGF5',
#   'TARS2',
#   'CPPED1',
#   'NCF2',
#   'GET4',
#   'GTF3C4',
#   'CTNNAL1',
#   'EHMT2',
#   'SS18L1',
#   'EZH1',
#   'CPOX',
#   'PROM2',
#   'NAALADL2',
#   'KLC3',
#   'OSBPL3',
#   'ZNFX1',
#   'STEAP1',
#   'SSU72',
#   'CHTF18',
#   'STK4',
#   'ROBO2',
#   'FAM110C',
#   'SERPINA6',
#   'CYBB',
#   'IL1R1',
#   'FAM120B',
#   'PYCARD',
#   'SLC27A1',
#   'TTC28',
#   'NUDC',
#   'MDM1',
#   'RP9',
#   'PRR15',
#   'S100A12',
#   'BIN2',
#   'HOXD9',
#   'FASTKD5',
#   'MAP3K2',
#   'CCDC137',
#   'CAMSAP2',
#   'LRP4',
#   'CAPN1',
#   'GIMAP4',
#   'CAMSAP3',
#   'ALPL',
#   'KIF4A',
#   'AKR7A2',
#   'ACOT11',
#   'SPTLC3',
#   'APOBEC3F',
#   'VPS4A',
#   'FGD3',
#   'HSPA13',
#   'SGTA',
#   'TSEN15',
#   'SHB',
#   'RMDN3',
#   'GOLIM4',
#   'MAP1LC3A',
#   'TRAF3IP1',
#   'RCBTB2',
#   'PLD2',
#   'NIT1',
#   'GSDMD',
#   'GPX4',
#   'APLF',
#   'UAP1',
#   'SH3RF1',
#   'HIGD1A',
#   'ODF3B',
#   'CCL20',
#   'ECH1',
#   'ABI3BP',
#   'MTIF3',
#   'TAGAP',
#   'C19orf33',
#   'ACTR1A',
#   'PSTPIP2',
#   'KCNN4',
#   'SCAMP3',
#   'SCO2',
#   'APOBEC3B',
#   'RGS19',
#   'HOMER1',
#   'RSRC1',
#   'NR2F2',
#   'GBF1',
#   'HP',
#   'YY1AP1',
#   'CCNE1',
#   'LRRK2',
#   'ZNF587',
#   'NAA38',
#   'LMO7',
#   'HS6ST1',
#   'ARF1',
#   'KDM3B',
#   'HEATR6',
#   'PDSS2',
#   'DNAJA3',
#   'SNX13',
#   'CARD6',
#   'MRPS18B',
#   'CHMP1A',
#   'SAA1',
#   'KIF15',
#   'SEC23IP',
#   'COQ9',
#   'PYGB',
#   'RNF170',
#   'DCP1A',
#   'OTUD4',
#   'ACAD8',
#   'TDRKH',
#   'TMCO4',
#   'TMEM165',
#   'TBC1D22B',
#   'RPL18',
#   'PDE8A',
#   'AP1AR',
#   'UBE2E3',
#   'AAGAB',
#   'RPRD2',
#   'RNASEL',
#   'RANBP1',
#   'STC2',
#   'TEC',
#   'CCDC8',
#   'RAB19',
#   'UQCRC1',
#   'TFF3',
#   'EIF4EBP1',
#   'FTO',
#   'TRMT6',
#   'SIK3',
#   'PARP14',
#   'HOMER2',
#   'ANP32B',
#   'HMGN5',
#   'SFXN5',
#   'FDFT1',
#   'EPS8L3',
#   'RNF181',
#   'CD300A',
#   'PPP3CC',
#   'ARHGEF5',
#   'ERAP1',
#   'PMM1',
#   'SCAMP4',
#   'AJUBA',
#   'CAPN13',
#   'ZC3H4',
#   'TRAPPC1',
#   'MSX1',
#   'CYB561',
#   'BMP2K',
#   'LMAN2L',
#   'NARF',
#   'SERF2',
#   'AGPAT3',
#   'KRT13',
#   'PPP1R3D',
#   'EFNB1',
#   'KLK10',
#   'IVNS1ABP',
#   'ACSF3',
#   'FGFR2',
#   'CCT2',
#   'NUF2',
#   'NID1',
#   'CNNM3',
#   'WDR26',
#   'DNAL1',
#   'CCDC78',
#   'GPRIN3',
#   'RNF113A',
#   'IMPDH2',
#   'TRAPPC5',
#   'TBC1D2',
#   'FBXL15',
#   'FAM177A1',
#   'DYNC1LI1',
#   'CBX2',
#   'BCAR3',
#   'TCEA2',
#   'WTIP',
#   'MINPP1',
#   'GEMIN2',
#   'SRA1',
#   'HTT',
#   'MGME1',
#   'PRAME',
#   'APBA2',
#   'SAAL1',
#   'RIC8B',
#   'PRKAB1',
#   'MCM5',
#   'FBLN5',
#   'ATAD2B',
#   'CCP110',
#   'DR1',
#   'SZRD1',
#   'MAD2L2',
#   'GPATCH11',
#   'PLXNB1',
#   'IGLL1',
#   'PFKL',
#   'ALG13',
#   'GIMAP8',
#   'AGPAT1',
#   'FANCD2',
#   'HMGCS1',
#   'SDHA',
#   'STRA6',
#   'SNX2',
#   'RNF13',
#   'GLUD2',
#   'GNAQ',
#   'PRRC2C',
#   'PRSS23',
#   'TP53I11',
#   'PTPN9',
#   'RPA1',
#   'PRR36',
#   'MCCC1',
#   'CLPB',
#   'GORASP1',
#   'NAT14',
#   'CHD7',
#   'PECR',
#   'CNOT3',
#   'LARP4',
#   'EPC1',
#   'IRAK1',
#   'PAFAH1B3',
#   'RAB27B',
#   'SLC16A3',
#   'SWAP70',
#   'DTNB',
#   'AOC1',
#   'ARL8A',
#   'VAV1',
#   'NLRP2',
#   'CLU',
#   'IFT74',
#   'SCGB2A1',
#   'TATDN3',
#   'EIF4H',
#   'ENPP3',
#   'NUP37',
#   'CD55',
#   'IDNK',
#   'RPS8',
#   'RSPH4A',
#   'PLEKHA2',
#   'TBC1D30',
#   'GPT2',
#   'FAM172A',
#   'S100P',
#   'ZC3H18',
#   'CRYL1',
#   'TSC22D4',
#   'THOC5',
#   'NEK6',
#   'PAMR1',
#   'FOLR1',
#   'PPP4R1',
#   'WASL',
#   'HYKK',
#   'EXOC6B',
#   'DBI',
#   'LAMTOR2',
#   'TTC39B',
#   'ZNF639',
#   'POLDIP2',
#   'IDI1',
#   'CDC40',
#   'PPP6R3',
#   'C12orf29',
#   'STARD10',
#   'LACTB2',
#   'CFAP36',
#   'XAF1',
#   'PDSS1',
#   'C3',
#   'ATXN2L',
#   'WDR60',
#   'MT1G',
#   'CNP',
#   'IDO1',
#   'DCTD',
#   'FNDC3A',
#   'CDV3',
#   'TRAP1',
#   'NUDT8',
#   'DNAJB13',
#   'EIF6',
#   'UBR7',
#   'TET3',
#   'GEMIN5',
#   'EFS',
#   'MCRS1',
#   'EEFSEC',
#   'MTHFD1L',
#   'UFL1',
#   'RPS6KB2',
#   'CTHRC1',
#   'ARFGAP3',
#   'NNMT',
#   'PLD3',
#   'ANGPT2',
#   'ITGB8',
#   'CD40',
#   'CLDN10',
#   'RPL32',
#   'ANKRD35',
#   'ZMIZ1',
#   'USP34',
#   'ITIH1',
#   'PCSK9',
#   'EXOSC2',
#   'TNFAIP2',
#   'ASAP3',
#   'CEACAM1',
#   'SLC25A35',
#   'KDM5B',
#   'ZMYM3',
#   'TPBG',
#   'HMMR',
#   'HLA-B',
#   'ZNF853',
#   'MST1R',
#   'CARD9',
#   'CXCL1',
#   'CLPP',
#   'NAPG',
#   'BLNK',
#   'IL1RN',
#   'NAAA',
#   'MYO10',
#   'TFAP4',
#   'SPC25',
#   'CHAF1B',
#   'NBEAL1',
#   'NRP1',
#   'MRPL37',
#   'S100A8',
#   'TXNDC12',
#   'ADD2',
#   'HELLS',
#   'GLRX5',
#   'GPHN',
#   'KIF2C',
#   'ACTR1B',
#   'PRKCI',
#   'DZIP3',
#   'MT1F',
#   'ABCC4',
#   'SCEL',
#   'CBLB',
#   'TAP2',
#   'CENPF',
#   'SNTB1',
#   'RAPGEF1',
#   'ATP6V1F',
#   'EPHA4',
#   'DHX36',
#   'MEGF8',
#   'EBAG9',
#   'APOBEC3C',
#   'FBXO11',
#   'SPRYD7',
#   'RPP25',
#   'CKMT2',
#   'COA4',
#   'MECR',
#   'RHBDD3',
#   'ECI2',
#   'BCL3',
#   'CEP78',
#   'SOWAHB',
#   'CARS2',
#   'MAP2K4',
#   'ANLN',
#   'XIAP',
#   'RNPEP',
#   'PRIM1',
#   'CNOT7',
#   'AKAP7',
#   'TPX2',
#   'SMARCAL1',
#   'APOE',
#   'PLOD2',
#   'TRIM22',
#   'TOR1B',
#   'ARFIP2',
#   'RPAP1',
#   'PLEK2',
#   'CASP9',
#   'CUL1',
#   'GATAD2B',
#   'SAMD12',
#   'KLHL14',
#   'SLC47A1',
#   'USP16',
#   'TAGLN2',
#   'C1RL',
#   'TUT1',
#   'SRPK2',
#   'DENND4A',
#   'TMEM159',
#   'FOXA2',
#   'FARP2',
#   'OSBP',
#   'PYCR1',
#   'PRPSAP1',
#   'ASNS',
#   'ALMS1',
#   'RASAL1',
#   'PPP6R1',
#   'CHAC2',
#   'HLA-DMA',
#   'NCAPH',
#   'PSME2',
#   'C6orf132',
#   'NPDC1',
#   'AZGP1',
#   'S100A9',
#   'SACS',
#   'UBE3C',
#   'ACOT8',
#   'CCNA2',
#   'TTC38',
#   'TYMS',
#   'NMT1',
#   'TOR3A',
#   'ZC3H7A',
#   'SDK1',
#   'NXT2',
#   'LMBRD2',
#   'STK3',
#   'AURKB',
#   'RPL19',
#   'MCMBP',
#   'GRAMD1A',
#   'CTH',
#   'ECD',
#   'NMD3',
#   'BCAT2',
#   'SLC1A5',
#   'HK2',
#   'DHCR24',
#   'FILIP1L',
#   'CRISP3',
#   'ACADS',
#   'CCNB1',
#   'B9D2',
#   'MSX2',
#   'BLOC1S2',
#   'FRMD4A',
#   'KLHL29',
#   'FAM204A',
#   'ITGB6',
#   'PTPRG',
#   'SERPINA1',
#   'LYRM1',
#   'MTHFD2',
#   'VPS37B',
#   'WDHD1',
#   'XYLT2',
#   'FZD6',
#   'HAPLN1',
#   'KLHL7',
#   'PACS1',
#   'SARDH',
#   'RRAGC',
#   'SHMT1',
#   'FAM120C',
#   'TRIP13',
#   'MMP7',
#   'GRB14',
#   'ORM2',
#   'DEFB1',
#   'GMNN',
#   'KRT4',
#   'XPNPEP3',
#   'RPL13',
#   'SERPINA5',
#   'ATXN10',
#   'MRPL57',
#   'HADHB',
#   'GK',
#   'PGK1',
#   'PATL1',
#   'PBK',
#   'SCYL3',
#   'RFK',
#   'ATAD2',
#   'UCK2',
#   'PIK3CD',
#   'VNN1',
#   'TXNRD2',
#   'TLR2',
#   'OAT',
#   'MEF2C',
#   'NAPRT',
#   'RNF141',
#   'FAM92B',
#   'CEP131',
#   'KRT80',
#   'FOXA1',
#   'SLC27A2',
#   'SETD3',
#   'TALDO1',
#   'TESC',
#   'TSPAN1',
#   'CTSL',
#   'ZNF219',
#   'NFATC2',
#   'MMS19',
#   'XDH',
#   'NFKB1',
#   'PRODH',
#   'DCDC2',
#   'CERS6',
#   'ANKLE2',
#   'CHEK1',
#   'RAP1GAP2',
#   'TBC1D5',
#   'CD151',
#   'RUFY2',
#   'MSTO1',
#   'C1QTNF7',
#   'C15orf39',
#   'ECT2',
#   'GCLM',
#   'HELZ2',
#   'GFM1',
#   'HAUS4',
#   'OSBPL2',
#   'ARMC4',
#   'RAB11FIP3',
#   'TNFAIP8L2',
#   'ERCC6L',
#   'GSPT2',
#   'GPALPP1',
#   'KRT17',
#   'CLIC3',
#   'EIF2S2',
#   'QKI',
#   'GNB1L',
#   'DUSP23',
#   'GDF15',
#   'FAM83B',
#   'FLRT3',
#   'FANCI',
#   'PEX2',
#   'PTS',
#   'REEP6',
#   'MSI1',
#   'ACBD7',
#   'TACC3',
#   'MYOC',
#   'SLC3A2',
#   'HK3',
#   'GATA2',
#   'DCUN1D1',
#   'NCAPD3',
#   'EGLN1',
#   'GPR39',
#   'BBS4',
#   'SLC7A5',
#   'UXS1',
#   'CDK1',
#   'MBNL2',
#   'WIPI1',
#   'VPS37A',
#   'CUL2',
#   'KLHL25',
#   'UBA6',
#   'EPHA7',
#   'UBE2E2',
#   'ACAA2',
#   'C9orf64',
#   'GDAP2',
#   'GAPVD1',
#   'GPCPD1',
#   'CP',
#   'KIF11',
#   'AS3MT',
#   'PLAU',
#   'SDS',
#   'RRAD',
#   'TSTD2',
#   'RNF2',
#   'PYGO1',
#   'SLC16A1',
#   'LRG1',
#   'HLA-DPB1',
#   'FAM3D',
#   'CHMP7',
#   'UHRF1BP1L',
#   'MAD2L1',
#   'ZWINT',
#   'CAD',
#   'HERC4',
#   'CFI',
#   'MTM1',
#   'LIN54',
#   'LIMK2',
#   'ZNF281',
#   'C1orf116',
#   'SRD5A3',
#   'ZFP3',
#   'ABHD6',
#   'ZNF318',
#   'C15orf48',
#   'CDKN2A',
#   'S100A13',
#   'TFRC',
#   'XYLB',
#   'NDP',
#   'IFT43',
#   'GOT1'],
#  'hnscc': ['IGFBP3',
#   'MIEF1',
#   'IDO1',
#   'MELK',
#   'CRBN',
#   'PSMG3',
#   'TRMT10C',
#   'NPEPL1',
#   'CENPF',
#   'RBKS',
#   'TMEM223',
#   'HTATSF1',
#   'IFFO2',
#   'APEH',
#   'CLPB',
#   'ST13',
#   'TRAP1',
#   'HMGA2',
#   'COL28A1',
#   'MASTL',
#   'PPME1',
#   'POMP',
#   'KCTD18',
#   'LRRC8E',
#   'KCNK1',
#   'RNF115',
#   'PLAT',
#   'DHX58',
#   'NDUFV2',
#   'PELO',
#   'KAT7',
#   'FARS2',
#   'PRPSAP2',
#   'GATAD1',
#   'HPDL',
#   'CHD8',
#   'PGK1',
#   'RCN2',
#   'PCSK5',
#   'GNB5',
#   'MUCL1',
#   'RAB7A',
#   'SLC25A15',
#   'UBE2F',
#   'SSBP1',
#   'PLAA',
#   'MTAP',
#   'ATG2B',
#   'ZNF282',
#   'CXCL10',
#   'KRT4',
#   'UBE4A',
#   'GCFC2',
#   'SLC7A8',
#   'PARP16',
#   'PCP4',
#   'FAM133B',
#   'RPIA',
#   'HTT',
#   'UBA1',
#   'ITGB6',
#   'UBE2T',
#   'MRRF',
#   'EPHB4',
#   'NCS1',
#   'DNMT3A',
#   'TMEM143',
#   'CAMKMT',
#   'PAFAH1B1',
#   'DNAJC11',
#   'EGFL7',
#   'PDHA1',
#   'BRAF',
#   'KCTD21',
#   'REPIN1',
#   'WDR77',
#   'SMIM12',
#   'EIF2B3',
#   'NCEH1',
#   'C2CD2L',
#   'ALPK1',
#   'THTPA',
#   'URB1',
#   'HMBS',
#   'RARRES2',
#   'ACADL',
#   'KHDC1L',
#   'TBL1X',
#   'LAMC2',
#   'SCGB3A2',
#   'DDX19A',
#   'ZWINT',
#   'ALKBH4',
#   'TARBP1',
#   'MAP2K3',
#   'NTHL1',
#   'RSBN1L',
#   'DDHD2',
#   'MED9',
#   'TP53BP2',
#   'NUDT22',
#   'RFK',
#   'FKBP14',
#   'PMPCA',
#   'KIAA1191',
#   'DCAF10',
#   'ERAL1',
#   'YWHAE',
#   'SLC25A17',
#   'IARS2',
#   'PDCD2',
#   'FBXL6',
#   'NGLY1',
#   'MYH15',
#   'TMEM177',
#   'MAGEA4',
#   'ISCA2',
#   'KLK5',
#   'GGT5',
#   'CLUAP1',
#   'IPO7',
#   'ENPP6',
#   'FAM168A',
#   'MMAA',
#   'GRHPR',
#   'MT-ND4',
#   'APLP2',
#   'TFB1M',
#   'KIFC1',
#   'ATAD3A',
#   'MTM1',
#   'EPM2AIP1',
#   'LANCL2',
#   'DCAF16',
#   'MMP13',
#   'CCNA2',
#   'METTL25',
#   'VAMP3',
#   'DDX31',
#   'NAP1L4',
#   'NUDT15',
#   'BPGM',
#   'HEATR5A',
#   'MAGEA3',
#   'ARHGEF26',
#   'INPP5K',
#   'SLC2A1',
#   'RIC8A',
#   'THBD',
#   'LRPPRC',
#   'UBE3C',
#   'THOP1',
#   'FAM117A',
#   'WDR37',
#   'PCDH7',
#   'UBE2O',
#   'CTSE',
#   'COA4',
#   'MCTS1',
#   'CMC1',
#   'ISG15',
#   'PAIP1',
#   'GEMIN5',
#   'CEACAM6',
#   'MTX1',
#   'RTP4',
#   'XPNPEP3',
#   'VCP',
#   'FAT1',
#   'PDGFC',
#   'RANBP6',
#   'AASDHPPT',
#   'ACAD9',
#   'DGKH',
#   'TFAM',
#   'SCO1',
#   'HSD17B2',
#   'MCTS2P',
#   'FLRT3',
#   'PADI3',
#   'CYP27C1',
#   'RFX3',
#   'CDKN2A',
#   'OXLD1',
#   'SOX13',
#   'WDR90',
#   'PARL',
#   'NCAPG2',
#   'PHB2',
#   'HTRA2',
#   'GPCPD1',
#   'PCM1',
#   'BIRC2',
#   'PLEKHG4',
#   'QSER1',
#   'SMAD4',
#   'GNG12',
#   'UBE2N',
#   'PXMP2',
#   'TBRG4',
#   'SIAE',
#   'PDE6D',
#   'PRR16',
#   'ASB6',
#   'GBP5',
#   'MFSD3',
#   'AIM2',
#   'RNLS',
#   'NUAK2',
#   'PBX1',
#   'USP18',
#   'BCS1L',
#   'CENPL',
#   'PCTP',
#   'WDR1',
#   'STK25',
#   'CCNB2',
#   'HINT1',
#   'DPH5',
#   'MYO10',
#   'ESCO1',
#   'CCDC127',
#   'SCAF8',
#   'PRC1',
#   'LSM1',
#   'OLA1',
#   'FLAD1',
#   'IGF2BP1',
#   'CDKN2B',
#   'PRKAR2A',
#   'MAGEB2',
#   'NACC2',
#   'LYZ',
#   'IRGQ',
#   'TIMM50',
#   'C14orf119',
#   'DARS2',
#   'CCDC58',
#   'TATDN1',
#   'SBK2',
#   'TIPIN',
#   'OPA1',
#   'PRDM11',
#   'DLGAP5',
#   'STOML2',
#   'RNF114',
#   'ALKBH2',
#   'HARS2',
#   'SUGP2',
#   'FADD',
#   'TOMM22',
#   'TBC1D9'],
#  'lscc': ['WDR45B',
#   'NRIP1',
#   'CHPF',
#   'GYG1',
#   'RAD51AP1',
#   'LNX1',
#   'QRSL1',
#   'A2ML1',
#   'XXYLT1',
#   'UROD',
#   'CDH2',
#   'PITPNC1',
#   'DUSP22',
#   'STX17',
#   'STRA6',
#   'FREM2',
#   'NCBP1',
#   'TRMT1',
#   'NFATC1',
#   'MT1F',
#   'SPRR2G',
#   'LY6D',
#   'RAD51C',
#   'AGK',
#   'HDAC4',
#   'LRRN4CL',
#   'TLK2',
#   'DNAJA1',
#   'ZBTB7C',
#   'SPRR1A',
#   'PLEKHG3',
#   'CALML3',
#   'DUSP9',
#   'DERL2',
#   'DNAJC21',
#   'TTF1',
#   'ZDHHC17',
#   'ARL1',
#   'PPM1L',
#   'VPS4B',
#   'ATPAF1',
#   'UBP1',
#   'TGS1',
#   'FAM210B',
#   'GNE',
#   'CENPU',
#   'IRF2BPL',
#   'MIEN1',
#   'DPY19L1',
#   'CTSV',
#   'AKR1B10',
#   'XPO5',
#   'UBE3C',
#   'SSBP1',
#   'UBLCP1',
#   'HAS3',
#   'RBBP5',
#   'SPRTN',
#   'ZHX2',
#   'TACO1',
#   'CENPJ',
#   'RAB15',
#   'DMKN',
#   'MIS18A',
#   'PIGM',
#   'DLST',
#   'SEC16B',
#   'CEACAM7',
#   'ANXA8',
#   'P4HA3',
#   'SERPINB9',
#   'KRT75',
#   'WBP4',
#   'USP5',
#   'FAM83C',
#   'TRMT1L',
#   'MTA3',
#   'KHSRP',
#   'TRMT5',
#   'MAD2L1',
#   'SNX19',
#   'AKAP8',
#   'TFAP2A',
#   'EIF2B1',
#   'MSN',
#   'ACSS1',
#   'PIN1',
#   'FH',
#   'DHRS7B',
#   'ASF1A',
#   'DPH5',
#   'SUV39H2',
#   'KIF11',
#   'IL36A',
#   'ATP7A',
#   'NLRX1',
#   'ISCA1',
#   'KIFC1',
#   'FURIN',
#   'EIF4A3',
#   'RTN4IP1',
#   'PLEKHG4B',
#   'GUF1',
#   'MLLT11',
#   'KDM1B',
#   'IDE',
#   'LYSMD1',
#   'TPI1',
#   'ABHD4',
#   'PTK6',
#   'PYCR1',
#   'LMAN2L',
#   'TIMM50',
#   'CLTB',
#   'DUSP12',
#   'IL36RN',
#   'PPAT',
#   'DICER1',
#   'UBIAD1',
#   'RIC8A',
#   'CPTP',
#   'SOX15',
#   'TOR3A',
#   'GINS3',
#   'SPRR2F',
#   'MAST4',
#   'SLC5A3',
#   'GYS1',
#   'GSDMC',
#   'GINS2',
#   'DCLRE1A',
#   'TPD52L1',
#   'ZFP36L2',
#   'COASY',
#   'PPP1R2',
#   'FGFBP1',
#   'PNMA5',
#   'OSBP',
#   'SEMA3C',
#   'MCAT',
#   'ANXA2',
#   'NOS1AP',
#   'DDX31',
#   'TES',
#   'RHBDL2',
#   'RAE1',
#   'SRSF7',
#   'UCHL5',
#   'ABCF1',
#   'SERPINI1',
#   'SLC6A4',
#   'UPRT',
#   'SETD3',
#   'C5orf22',
#   'B4GALT4',
#   'SMG7',
#   'RIOK1',
#   'TFAP2C',
#   'JRK',
#   'GSS',
#   'PAQR7',
#   'ETNK2',
#   'BEND5',
#   'PRMT5',
#   'PHC2',
#   'ARF4',
#   'CACYBP',
#   'GAPVD1',
#   'CIT',
#   'NPTXR',
#   'KPNA1',
#   'UBAP2',
#   'BICD2',
#   'SPC24',
#   'MCU',
#   'TRA2B',
#   'DDI2',
#   'MTPAP',
#   'RAB3GAP2',
#   'CARM1',
#   'UPF1',
#   'CELSR2',
#   'APEH',
#   'ZMYM2',
#   'TUBB6',
#   'RAB43',
#   'POLA1',
#   'SYTL5',
#   'LIG3',
#   'BCL11A',
#   'TXNDC11',
#   'NKRF',
#   'TOE1',
#   'DDX52',
#   'MASTL',
#   'CELF2',
#   'XPA',
#   'RPRD1A',
#   'CLCA2',
#   'NCOR1',
#   'SEPSECS',
#   'GGT7',
#   'CERS3',
#   'RPTN',
#   'CCDC127',
#   'SEMA4B',
#   'ANAPC1',
#   'MAGEA6',
#   'INPP1',
#   'PELP1',
#   'KIF4A',
#   'MEX3A',
#   'YY1',
#   'CSNK1G1',
#   'CALB1',
#   'CBX2',
#   'IARS2',
#   'RRP12',
#   'DDX18',
#   'WIPI2',
#   'DUSP14',
#   'SERPINB3',
#   'CROT',
#   'EIF3J',
#   'CEP170B',
#   'TMPRSS4',
#   'CDV3',
#   'CAB39',
#   'FAM20A',
#   'UBA6',
#   'NOL11',
#   'SGTA',
#   'CDCA3',
#   'SPAG5',
#   'TSC22D2',
#   'EIF2S1',
#   'ANKRD17',
#   'ATG4D',
#   'STAU2',
#   'PPP2R2A',
#   'KRTCAP3',
#   'KDM3A',
#   'AHCY',
#   'MMP13',
#   'RBKS',
#   'CDC37L1',
#   'CXCL6',
#   'TBL1X',
#   'PAQR4',
#   'UNG',
#   'PTGES',
#   'ZNF318',
#   'NUDT5',
#   'WDHD1',
#   'JAK1',
#   'UMPS',
#   'PAX9',
#   'STIP1',
#   'ZDHHC13',
#   'NOLC1',
#   'SIPA1L3',
#   'RAB18',
#   'TP63',
#   'SUGP1',
#   'TSTA3',
#   'USP18',
#   'IL1RN',
#   'ABCB6',
#   'HIF1AN',
#   'CASP4',
#   'TMEM45A',
#   'PSAT1',
#   'HDGF',
#   'PTRH2',
#   'GEMIN2',
#   'PBK',
#   'USP7',
#   'ABCF3',
#   'UBE3A',
#   'ZC3H7A',
#   'FAM50B',
#   'JAG2',
#   'STAMBP',
#   'FERMT1',
#   'RBBP8',
#   'ACVR2A',
#   'ZFP37',
#   'BEND3',
#   'SDC4',
#   'SAAL1',
#   'ORC5',
#   'GRHL1',
#   'E2F6',
#   'RAD54B',
#   'PLK1',
#   'STX5',
#   'RNF39',
#   'EPHA7',
#   'SLC27A4',
#   'LAMB3',
#   'TSR1',
#   'UPK1B',
#   'RTN4R',
#   'LSG1',
#   'SLC40A1',
#   'UBE4B',
#   'C11orf58',
#   'OTUD4',
#   'MTCL1',
#   'LAT2',
#   'FXN',
#   'NDUFAF7',
#   'AMMECR1',
#   'CABYR',
#   'FBN2',
#   'UBQLN4',
#   'TAGAP',
#   'STAT3',
#   'RNF168',
#   'WNK2',
#   'DPYSL5',
#   'UBAC2',
#   'BAZ1B',
#   'CES2',
#   'TTC14',
#   'TEFM',
#   'MSH2',
#   'PRMT3',
#   'CREB5',
#   'EIF5B',
#   'IVL',
#   'BRF2',
#   'CPOX',
#   'ECI1',
#   'SLC25A12',
#   'SKA1',
#   'TRMT10C',
#   'ZC3H15',
#   'USP39',
#   'MAPKBP1',
#   'MST1R',
#   'DNAJA3',
#   'RGMA',
#   'SLC1A5',
#   'NEMF',
#   'PTK7',
#   'GOT2',
#   'NDUFAF4',
#   'SERPINB5',
#   'C11orf96',
#   'GSPT2',
#   'ETFB',
#   'LAMA1',
#   'STAU1',
#   'GSPT1',
#   'P2RY2',
#   'FMO4',
#   'CHAF1A',
#   'DHX57',
#   'MT1E',
#   'FZD7',
#   'NSFL1C',
#   'SIX4',
#   'PXYLP1',
#   'AR',
#   'SYNCRIP',
#   'WDR62',
#   'ITGA5',
#   'CLIP1',
#   'KLHL9',
#   'SLC7A11',
#   'GSTZ1',
#   'ABCC1',
#   'BLVRA',
#   'STK17B',
#   'EYA2',
#   'SEC63',
#   'WDR43',
#   'DCUN1D1',
#   'KLHL29',
#   'CDK12',
#   'POLR2H',
#   'CAPN1',
#   'CCNT1',
#   'DCTPP1',
#   'KRT6C',
#   'POU2F1',
#   'KIF14',
#   'CERS4',
#   'KRT8',
#   'TFAP4',
#   'ZNF217',
#   'NIF3L1',
#   'ALKBH4',
#   'RBMXL1',
#   'TRIP6',
#   'OSGEPL1',
#   'IMPACT',
#   'LSR',
#   'CPEB4',
#   'CRKL',
#   'CDCP1',
#   'TXNL1',
#   'MDN1',
#   'DPYD',
#   'HDAC9',
#   'KIF2C',
#   'ADAM23',
#   'C17orf75',
#   'SUZ12',
#   'TRMT6',
#   'SOX6',
#   'FBXL19',
#   'MGA',
#   'RPUSD2',
#   'TFB1M',
#   'NR2C2AP',
#   'CAD',
#   'SMIM4',
#   'ATXN1',
#   'TIPIN',
#   'GRHL3',
#   'GOT1',
#   'TIMM44',
#   'SLC29A1',
#   'EHF',
#   'FAM83B',
#   'YKT6',
#   'PPFIA3',
#   'HNRNPF',
#   'FBXO4',
#   'AVL9',
#   'MRRF',
#   'CUL2',
#   'CLSPN',
#   'KLF4',
#   'PKP1',
#   'GSTA4',
#   'FADS1',
#   'DHRS11',
#   'NAA15',
#   'ARHGEF19',
#   'MTERF3',
#   'WDR44',
#   'ARID2',
#   'CHMP1B',
#   'LRIG3',
#   'SMC4',
#   'LY75',
#   'BCAR3',
#   'DHRS13',
#   'GNAI2',
#   'ACTL6A',
#   'CRCT1',
#   'XPO7',
#   'ITGB6',
#   'RELA',
#   'USP14',
#   'SPINK5',
#   'ETF1',
#   'ARMCX3',
#   'ZNFX1',
#   'PSMD10',
#   'ESCO2',
#   'CLNS1A',
#   'BZW1',
#   'S100A14',
#   'C4orf19',
#   'TFDP1',
#   'KLHDC7A',
#   'COIL',
#   'ABCE1',
#   'CPS1',
#   'TPP2',
#   'F2RL1',
#   'FAM83G',
#   'TNS4',
#   'FAT2',
#   'MTFR1',
#   'DHX35',
#   'DSG3',
#   'MPV17L',
#   'GLUD1',
#   'TOPBP1',
#   'SRXN1',
#   'DNM1L',
#   'ZNF658',
#   'SYT7',
#   'HGH1',
#   'CDC45',
#   'ATP2B1',
#   'GALNT14',
#   'FRRS1',
#   'PCP4',
#   'SDC1',
#   'KRT16',
#   'AHSA1',
#   'FLOT2',
#   'UBE2R2',
#   'SEC24B',
#   'PSPH',
#   'NSRP1',
#   'PAPOLG',
#   'KRT13',
#   'HSPA9',
#   'PPME1',
#   'CCDC58',
#   'DUOX2',
#   'COL19A1',
#   'KRT15',
#   'EPS8L1',
#   'TRAP1',
#   'MAPRE1',
#   'WBP11',
#   'COL17A1',
#   'L2HGDH',
#   'HAGHL',
#   'LANCL2',
#   'MUC20',
#   'XPNPEP3',
#   'IL36G',
#   'GCSH',
#   'PRIM1',
#   'SLC4A1AP',
#   'RAD18',
#   'EZR',
#   'PPP1R3D',
#   'PGK1',
#   'PIAS2',
#   'MAT1A',
#   'METTL8',
#   'CHD8',
#   'BCL2L14',
#   'HNRNPM',
#   'ARHGEF16',
#   'RNMT',
#   'SUPV3L1',
#   'USP16',
#   'LRP10',
#   'STX4',
#   'ANKZF1',
#   'UGT8',
#   'CEBPZ',
#   'BRCA1',
#   'CTSO',
#   'HSP90AA1',
#   'CHEK2',
#   'EMD',
#   'XPR1',
#   'AP1G1',
#   'LGI2',
#   'CENPF',
#   'PRNP',
#   'SUPT6H',
#   'TIMELESS',
#   'BTBD11',
#   'ZFAND2B',
#   'ARMC9',
#   'ERCC6L',
#   'MTOR',
#   'FASTKD5',
#   'BCAR1',
#   'RIOK3',
#   'EPHA2',
#   'GFPT1',
#   'ADM',
#   'OPA1',
#   'CDC42EP4',
#   'SCFD1',
#   'UBA2',
#   'MMP11',
#   'CA12',
#   'KPNB1',
#   'BOLA1',
#   'FAM83F',
#   'FIGNL1',
#   'DTYMK',
#   'XPOT',
#   'ECT2',
#   'ACAP2',
#   'LRRC8D',
#   'HPDL',
#   'TRIP11',
#   'TDRKH',
#   'URGCP',
#   'BAG4',
#   'YWHAG',
#   'ABCC5',
#   'PKP2',
#   'AMACR',
#   'STRAP',
#   'GNL1',
#   'UBE2G1',
#   'SLC2A1',
#   'STOML2',
#   'KRT23',
#   'PANK2',
#   'CDKAL1',
#   'MEGF10',
#   'MAP7D2',
#   'TNK1',
#   'PTHLH',
#   'CHD6',
#   'PDE12',
#   'NSUN5',
#   'FOXC1',
#   'UGT1A10',
#   'CNNM2',
#   'AFG3L2',
#   'KIF20A',
#   'DSC2',
#   'TPRG1',
#   'NUDT8',
#   'SBNO1',
#   'HOMEZ',
#   'UBAC1',
#   'PROM2',
#   'SCYL3',
#   'LIAS',
#   'ICAM1',
#   'SBSN',
#   'MCM10',
#   'SMOX',
#   'PGAM5',
#   'SRSF4',
#   'CNP',
#   'NAA25',
#   'TLE4',
#   'KIF1A',
#   'PDLIM1',
#   'DKK1',
#   'FOXE1',
#   'PITX1',
#   'EPHA1',
#   'CA9',
#   'SMC2',
#   'DSC3',
#   'KRT6A',
#   'IPO7',
#   'IDH3A',
#   'GCLC',
#   'SEPHS1',
#   'VTCN1',
#   'COL11A1',
#   'PRPSAP2',
#   'NSUN2',
#   'ZNF205',
#   'KRT5',
#   'TARS2',
#   'ERLIN1',
#   'NFKBIB',
#   'AKAP11',
#   'KHK',
#   'NXPH4',
#   'C1QBP',
#   'MMP3',
#   'EIF4EBP1',
#   'PLD1',
#   'DNAJA2',
#   'TNFRSF1A',
#   'BLMH',
#   'SLC25A33',
#   'LCMT1',
#   'DENND4A',
#   'EDARADD',
#   'STC2',
#   'UGT1A7',
#   'IGFL1',
#   'NTS',
#   'ZNF280C',
#   'PNPT1',
#   'KCTD1',
#   'PA2G4',
#   'GMPS',
#   'MYO3B',
#   'RAB3B',
#   'FADD',
#   'GOLPH3',
#   'NOL10',
#   'IGFBP2',
#   'SERPINB13',
#   'MT2A',
#   'UBE2M',
#   'BBOX1',
#   'SAGE1',
#   'FANCD2',
#   'UBR1',
#   'TMEM41A',
#   'ZPR1',
#   'MAP7D1',
#   'POMK',
#   'PAFAH1B3',
#   'C6orf15',
#   'KIF18B',
#   'IGF2BP3',
#   'MPPED2',
#   'BUB1',
#   'PPP4R1',
#   'POMC',
#   'SLC25A14',
#   'METAP1',
#   'CT45A10',
#   'SPRR2D',
#   'DBNDD1',
#   'MSI1',
#   'VDAC2',
#   'SRSF12',
#   'PDCD2',
#   'COG3',
#   'SOX2',
#   'DAPL1',
#   'KIF22',
#   'EIF5',
#   'SCAF4',
#   'GFM1',
#   'MUC13',
#   'KRT17',
#   'SKP2',
#   'YWHAZ',
#   'PODXL2',
#   'NCAPD3',
#   'RFC5',
#   'PRAME',
#   'INCENP',
#   'ADM2',
#   'CKAP2L',
#   'MELK',
#   'PDCD2L',
#   'SPRR1B',
#   'S100A7',
#   'CARD6',
#   'TMPRSS11E',
#   'OVOL2',
#   'S100A2',
#   'CAPNS2',
#   'NFX1',
#   'TRIP13',
#   'DDX55',
#   'PRC1',
#   'KRT14',
#   'MMS22L',
#   'DHX36',
#   'TMPRSS11D',
#   'KEAP1',
#   'TIMM8A',
#   'LYPD3',
#   'NFKB1',
#   'EHD4',
#   'EPHA4',
#   'ANXA1',
#   'KPNA4',
#   'GBP6',
#   'TP53',
#   'FGFR3',
#   'SAR1B',
#   'RCOR2',
#   'RDH16',
#   'TSHZ2',
#   'NEK11',
#   'NCCRP1',
#   'AADAT',
#   'FANCI',
#   'LRPPRC',
#   'SERPINB4',
#   'RIN1',
#   'FAM83A',
#   'SWAP70',
#   'ADSL',
#   'DCAF11',
#   'ZNF669',
#   'TACC1',
#   'TMF1',
#   'BAG3',
#   'ARIH1',
#   'RIPK1',
#   'ENTPD3',
#   'NUP153',
#   'MAGEA1',
#   'CDH23',
#   'ZNF750',
#   'WDR5B',
#   'ERVMER34-1',
#   'KLK8'],
#  'luad': ['SUZ12',
#   'GDAP1',
#   'GMPR',
#   'GRHL1',
#   'KIF23',
#   'CLNS1A',
#   'QRSL1',
#   'PECR',
#   'S100A16',
#   'MTERF3',
#   'MCM4',
#   'SPINT1',
#   'CPLX2',
#   'NCAPG',
#   'STMN3',
#   'LONP2',
#   'GFPT1',
#   'WDR43',
#   'STOX2',
#   'CKS1B',
#   'BZW1',
#   'KCNK5',
#   'ETF1',
#   'PDCD6',
#   'AGPAT5',
#   'TCP1',
#   'C7orf50',
#   'MRPL1',
#   'EGFL7',
#   'SP4',
#   'ZFHX3',
#   'NAT1',
#   'PITPNC1',
#   'FOXA1',
#   'NAV2',
#   'ACSL3',
#   'UNG',
#   'PEX6',
#   'SLC22A18',
#   'NUBPL',
#   'SPATS2',
#   'SLC12A2',
#   'TLK1',
#   'PTCD3',
#   'NFKBIA',
#   'SLC30A5',
#   'SNX21',
#   'TLK2',
#   'MCM3',
#   'SLC52A2',
#   'MCM6',
#   'B4GALNT3',
#   'ABL2',
#   'IPO9',
#   'ATP1A1',
#   'LRPPRC',
#   'PDCD11',
#   'RRM1',
#   'AP1G1',
#   'TRIP11',
#   'EXD2',
#   'RPP40',
#   'NDC1',
#   'CAND1',
#   'USP14',
#   'POP1',
#   'ZNF467',
#   'ARID3A',
#   'SERPINB1',
#   'UBAP1',
#   'UBE2K',
#   'DFFB',
#   'PROM2',
#   'C12orf73',
#   'RELL1',
#   'ABCA12',
#   'FAM160B2',
#   'UBE2O',
#   'TIPRL',
#   'RAI1',
#   'NT5C1A',
#   'SMPD1',
#   'GFRA3',
#   'CHEK1',
#   'DYNC1LI1',
#   'UBQLN4',
#   'DCAF11',
#   'URM1',
#   'NEFL',
#   'PLAA',
#   'PARS2',
#   'CDCP1',
#   'GCNT1',
#   'UFSP2',
#   'CTDP1',
#   'MMP11',
#   'UGT1A6',
#   'UBA2',
#   'EPHX4',
#   'CD3EAP',
#   'NAA25',
#   'AK9',
#   'TUSC3',
#   'THAP7',
#   'STEAP1',
#   'SWAP70',
#   'KRT6B',
#   'HARS2',
#   'RCAN3',
#   'ARID2',
#   'EFS',
#   'IPO7',
#   'PIPOX',
#   'MAPRE1',
#   'TK2',
#   'TMEM248',
#   'LETMD1',
#   'SLFN11',
#   'IFT57',
#   'DPY19L1',
#   'PICALM',
#   'TAF2',
#   'ARNT',
#   'NUDT1',
#   'CA12',
#   'CYP3A5',
#   'DNMT3A',
#   'PPP1R3G',
#   'PADI1',
#   'TOX',
#   'AHCY',
#   'PITPNB',
#   'PSMG3',
#   'CRABP1',
#   'RASAL1',
#   'THTPA',
#   'ISG20L2',
#   'LRRC8D',
#   'ZNF516',
#   'TRMT6',
#   'UMPS',
#   'OLA1',
#   'EVI5L',
#   'ZWILCH',
#   'HS2ST1',
#   'PPAT',
#   'PRIM1',
#   'ELMO1',
#   'CRACR2A',
#   'DSCC1',
#   'TRMT5',
#   'CDC42EP3',
#   'NTS',
#   'MAML2',
#   'BCL10',
#   'RPRD1A',
#   'DHX57',
#   'SLC7A5',
#   'OTUD4',
#   'GNL1',
#   'USP28',
#   'RRM2',
#   'YTHDF1',
#   'KPNA6',
#   'TOE1',
#   'PTGES',
#   'TTK',
#   'NARS2',
#   'TRIM72',
#   'SEMA3A',
#   'PPP2CB',
#   'HOMEZ',
#   'MMP1',
#   'HIF1AN',
#   'CHD8',
#   'UBTD2',
#   'ENPP3',
#   'FKBP10',
#   'ABCC6',
#   'GMNN',
#   'DDX41',
#   'SERINC5',
#   'FOXA2',
#   'TPD52',
#   'GATAD2B',
#   'ST6GALNAC1',
#   'FBXL14',
#   'COG3',
#   'CIT',
#   'SNX13',
#   'NOL11',
#   'STK39',
#   'CDC42EP1',
#   'VPS37A',
#   'MUC16',
#   'FAM83B',
#   'AHCYL1',
#   'MARK3',
#   'MAP2K4',
#   'RSBN1L',
#   'AMACR',
#   'N4BP2',
#   'LYPD3',
#   'POGZ',
#   'MUC3A',
#   'CLSPN',
#   'GRHL2',
#   'CLDN12',
#   'DNAJC12',
#   'KIF1A',
#   'AKR7A3',
#   'NLRX1',
#   'USP19',
#   'PAX9',
#   'PRR36',
#   'FAHD2A',
#   'STAP2',
#   'MIER1',
#   'PCBD2',
#   'HIBADH',
#   'ACAD10',
#   'CTSF',
#   'BAG4',
#   'DLAT',
#   'PKP2',
#   'SERPINI1',
#   'DPH5',
#   'S100A14',
#   'NOLC1',
#   'LRRFIP2',
#   'MLLT3',
#   'AGR2',
#   'SLC25A21',
#   'MDN1',
#   'TRIM68',
#   'RAD54B',
#   'PA2G4',
#   'NAALADL2',
#   'UTP20',
#   'NSFL1C',
#   'MCM5',
#   'FUT8',
#   'FAM120C',
#   'SEPHS1',
#   'TTI1',
#   'BOLA3',
#   'METTL7B',
#   'MORC3',
#   'EIF2S1',
#   'MTMR3',
#   'MAD2L1',
#   'IGSF3',
#   'GALNT6',
#   'UGDH',
#   'BLMH',
#   'SAMD8',
#   'KHK',
#   'LYSMD1',
#   'KPNA2',
#   'OXSR1',
#   'TMPRSS11E',
#   'OSGEP',
#   'GRSF1',
#   'CLPTM1L',
#   'ULBP3',
#   'IGF2BP3',
#   'RIOK1',
#   'SFPQ',
#   'COL11A1',
#   'CYP24A1',
#   'SCG3',
#   'FBXO4',
#   'ANLN',
#   'EPHA4',
#   'BACE2',
#   'DENND4A',
#   'POF1B',
#   'PROX1',
#   'SYNCRIP',
#   'PGM2L1',
#   'GLCCI1',
#   'CLIP1',
#   'STXBP1',
#   'TARS2',
#   'XPA',
#   'NCAPD3',
#   'CHAT',
#   'MIPEP',
#   'DLGAP5',
#   'GABARAPL1',
#   'ZFP36L1',
#   'ESF1',
#   'C1orf122',
#   'VIL1',
#   'NCOR1',
#   'PDZK1IP1',
#   'SOX9',
#   'RAB39B',
#   'HID1',
#   'HS3ST1',
#   'ANXA2',
#   'GMPS',
#   'SBNO1',
#   'EIF4G1',
#   'GPT2',
#   'ABCC3',
#   'HS6ST2',
#   'XPO5',
#   'WBP4',
#   'GLB1L2',
#   'SPINK2',
#   'NAA15',
#   'NCAPG2',
#   'CAPN5',
#   'PRRC2A',
#   'PURB',
#   'ST14',
#   'NFKB1',
#   'NDUFAF7',
#   'PLA2G4A',
#   'HGD',
#   'ERCC6L',
#   'GMDS',
#   'CCL28',
#   'ARHGEF16',
#   'SPAG5',
#   'EDEM3',
#   'IKZF2',
#   'TBC1D30',
#   'DDI2',
#   'SLC25A37',
#   'ABCB10',
#   'LIG1',
#   'MAPKAPK2',
#   'EFCAB14',
#   'ECI2',
#   'CHAF1A',
#   'IRF2BPL',
#   'PSMD5',
#   'MRS2',
#   'METAP1',
#   'B3GNT7',
#   'LTBR',
#   'SDE2',
#   'OTUB1',
#   'SDC4',
#   'TAX1BP1',
#   'SGSM3',
#   'NCOA2',
#   'LCMT1',
#   'PPP2R2A',
#   'ZYG11B',
#   'ECT2',
#   'PPP1R1B',
#   'HEATR1',
#   'PPFIBP2',
#   'TFB2M',
#   'ODC1',
#   'NSUN2',
#   'ZMYM2',
#   'EEF1A2',
#   'SYT7',
#   'NHLRC3',
#   'GLCE',
#   'ATP10B',
#   'PAH',
#   'DNAJC2',
#   'LANCL2',
#   'PPP1R37',
#   'RASA1',
#   'IL6R',
#   'SPC24',
#   'DPYD',
#   'PMS2',
#   'IFI16',
#   'MSN',
#   'PDLIM1',
#   'PPME1',
#   'TK1',
#   'TMEM59',
#   'CLDN6',
#   'HDAC9',
#   'SIT1',
#   'PPM1D',
#   'SLC5A1',
#   'L2HGDH',
#   'GINS2',
#   'ITPKA',
#   'LRRC15',
#   'FAM83F',
#   'DTYMK',
#   'DSG2',
#   'ATPAF1',
#   'GCNT3',
#   'WIPI2',
#   'THG1L',
#   'SCG2',
#   'STAMBP',
#   'SYT2',
#   'HGH1',
#   'KLK6',
#   'TOPBP1',
#   'GATAD1',
#   'PFAS',
#   'SUPV3L1',
#   'CCNB1',
#   'MINPP1',
#   'GMPR2',
#   'ADAM28',
#   'STRAP',
#   'GINS4',
#   'ZDHHC13',
#   'PAK1',
#   'DCBLD2',
#   'TOP2A',
#   'BCL2L1',
#   'ZNF544',
#   'HSPB8',
#   'ATAD2',
#   'SPC25',
#   'GEMIN2',
#   'EIF4EBP1',
#   'RELA',
#   'KLF12',
#   'PYCR1',
#   'KPNB1',
#   'C2orf72',
#   'TGM1',
#   'SPOCD1',
#   'FAF1',
#   'STAU2',
#   'GLB1L3',
#   'HMGB3',
#   'ATP7A',
#   'SDC1',
#   'PPIL4',
#   'FANCI',
#   'EIF4EBP3',
#   'CAPNS2',
#   'GUF1',
#   'BCL2L13',
#   'NCAPH',
#   'UBR1',
#   'TSC22D2',
#   'MKI67',
#   'XPR1',
#   'VDAC2',
#   'SPRTN',
#   'TDRKH',
#   'URGCP',
#   'FKBP14',
#   'DNM1L',
#   'HEATR5A',
#   'ALDOA',
#   'SEPSECS',
#   'SEZ6L2',
#   'NCAPD2',
#   'CDK1',
#   'FBXL18',
#   'GATA6',
#   'TUBB2B',
#   'RBMXL1',
#   'RBKS',
#   'NVL',
#   'FUNDC2',
#   'PTK6',
#   'ARMCX3',
#   'CAD',
#   'BCL2L15',
#   'TRAP1',
#   'BRCA1',
#   'CRABP2',
#   'ACE2',
#   'HLTF',
#   'REEP6',
#   'PMEPA1',
#   'BIRC5',
#   'TWISTNB',
#   'ZNF318',
#   'HHIPL2',
#   'ABCF1',
#   'RECQL5',
#   'SCAF4',
#   'CHMP1B',
#   'HOXB6',
#   'IL37',
#   'CARD14',
#   'AVL9',
#   'CELF2',
#   'STRA6',
#   'FAM111B',
#   'GLMN',
#   'EMD',
#   'SRSF4',
#   'FAF2',
#   'JAG2',
#   'PPFIA3',
#   'GRAMD1B',
#   'PAICS',
#   'CD1A',
#   'HAS3',
#   'ZNF608',
#   'CALB1',
#   'KIF4A',
#   'BAG3',
#   'KIF22',
#   'UBFD1',
#   'TMPRSS4',
#   'ENTPD5',
#   'UGT8',
#   'TNS4',
#   'TYMS',
#   'MCM7',
#   'PSMC3IP',
#   'CDC20',
#   'TMEM159',
#   'PAFAH1B3',
#   'KIF2C',
#   'BROX',
#   'PCP4',
#   'COIL',
#   'KIFC1',
#   'DHFR',
#   'INTS7',
#   'KNTC1',
#   'DCTPP1',
#   'ICAM1',
#   'ZNF845',
#   'GOLGA7B',
#   'MIS18A',
#   'ABHD17C',
#   'NUAK1',
#   'CBLC',
#   'EZR',
#   'FA2H',
#   'OCIAD2',
#   'GPRASP1',
#   'TACC1',
#   'UBE2T',
#   'TPCN2',
#   'MCM2',
#   'CCNB2',
#   'TPX2',
#   'S100A7',
#   'ADSL',
#   'PROSER3',
#   'YWHAZ',
#   'VPS36',
#   'TOX3',
#   'FLAD1',
#   'ESCO2',
#   'B3GNT6',
#   'CCR2',
#   'EHD4',
#   'ACY3',
#   'SYT1',
#   'PRMT3',
#   'PBK',
#   'ANXA1',
#   'AURKA',
#   'WDHD1',
#   'MELK',
#   'NUP153',
#   'NELL1',
#   'GGCT',
#   'XDH',
#   'TRIP13',
#   'SMC2',
#   'CENPH',
#   'CDC45']}

# %%
top_genes_residuals_diff = {}
for cancer_type in cancer_types:
    res = residuals[cancer_type]
    
    top_res = res[res["Gene"].isin(highest_delta_genes[cancer_type])].\
    pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values="orth_resid",
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).\
    dropna(axis=0, how="any").\
    reset_index(drop=False)
    
    top_res = top_res.\
    assign(tumor_normal_residual_diff=top_res["Tumor"] - top_res["Normal"]).\
    pivot(
        index="Patient_ID",
        columns="Gene",
        values="tumor_normal_residual_diff",
    ).\
    add_prefix("tumor_normal_residual_diff_")
    
    top_res.columns.name = None
    
    top_genes_residuals_diff[cancer_type] = top_res

top_genes_residuals_diff["ccrcc"]
# Out:
#             tumor_normal_residual_diff_ADCY3  tumor_normal_residual_diff_AGK  \
# Patient_ID
# C3L-00004                                NaN                       -0.017927
# C3L-00010                                NaN                        0.030770
# C3L-00011                                NaN                       -0.158858
# C3L-00026                                NaN                        0.293615
# C3L-00079                                NaN                       -0.159576
# ...                                      ...                             ...
# C3N-01646                                NaN                       -0.150593
# C3N-01648                                NaN                       -0.018247
# C3N-01649                           0.131998                        0.047608
# C3N-01651                                NaN                       -0.076749
# C3N-01808                           0.080269                       -0.039130
#
#             tumor_normal_residual_diff_AGXT  tumor_normal_residual_diff_AHSA1  \
# Patient_ID
# C3L-00004                         -0.427347                         -0.027146
# C3L-00010                          0.389726                          0.291561
# C3L-00011                         -0.048885                         -0.005581
# C3L-00026                          0.243402                         -0.068528
# C3L-00079                          0.520756                         -0.042411
# ...                                     ...                               ...
# C3N-01646                         -0.677954                          0.037328
# C3N-01648                         -0.166399                         -0.055132
# C3N-01649                          0.058750                          0.049832
# C3N-01651                         -0.418871                          0.129164
# C3N-01808                          0.609666                          0.006983
#
#             tumor_normal_residual_diff_ALDH18A1  \
# Patient_ID
# C3L-00004                             -0.274487
# C3L-00010                              0.200216
# C3L-00011                              0.078417
# C3L-00026                              0.503235
# C3L-00079                             -0.057107
# ...                                         ...
# C3N-01646                             -0.238651
# C3N-01648                              0.287773
# C3N-01649                              0.138271
# C3N-01651                              0.253536
# C3N-01808                              0.255479
#
#             tumor_normal_residual_diff_ANKZF1  \
# Patient_ID
# C3L-00004                            0.121017
# C3L-00010                            0.018235
# C3L-00011                            0.085755
# C3L-00026                            0.066225
# C3L-00079                            0.175662
# ...                                       ...
# C3N-01646                           -0.029590
# C3N-01648                            0.040302
# C3N-01649                            0.248659
# C3N-01651                           -0.091163
# C3N-01808                           -0.089406
#
#             tumor_normal_residual_diff_AP3M1  \
# Patient_ID
# C3L-00004                          -0.024181
# C3L-00010                          -0.092127
# C3L-00011                          -0.021808
# C3L-00026                          -0.173053
# C3L-00079                          -0.077721
# ...                                      ...
# C3N-01646                           0.054482
# C3N-01648                          -0.004579
# C3N-01649                           0.007734
# C3N-01651                          -0.113438
# C3N-01808                           0.060329
#
#             tumor_normal_residual_diff_AP4S1  \
# Patient_ID
# C3L-00004                          -0.184498
# C3L-00010                          -0.047637
# C3L-00011                          -0.061461
# C3L-00026                          -0.002121
# C3L-00079                          -0.171132
# ...                                      ...
# C3N-01646                          -0.041253
# C3N-01648                           0.040053
# C3N-01649                           0.122265
# C3N-01651                           0.230977
# C3N-01808                          -0.037160
#
#             tumor_normal_residual_diff_APLP2  \
# Patient_ID
# C3L-00004                           0.221461
# C3L-00010                           0.213010
# C3L-00011                           0.162054
# C3L-00026                          -0.154429
# C3L-00079                           0.052900
# ...                                      ...
# C3N-01646                           0.014083
# C3N-01648                           0.054391
# C3N-01649                          -0.013364
# C3N-01651                           0.096755
# C3N-01808                           0.133836
#
#             tumor_normal_residual_diff_APPL1  ...  \
# Patient_ID                                    ...
# C3L-00004                           0.019471  ...
# C3L-00010                          -0.005618  ...
# C3L-00011                           0.024129  ...
# C3L-00026                           0.161409  ...
# C3L-00079                           0.321521  ...
# ...                                      ...  ...
# C3N-01646                           0.057598  ...
# C3N-01648                           0.017791  ...
# C3N-01649                          -0.054940  ...
# C3N-01651                           0.104274  ...
# C3N-01808                           0.031893  ...
#
#             tumor_normal_residual_diff_USP47  \
# Patient_ID
# C3L-00004                          -0.060553
# C3L-00010                          -0.063582
# C3L-00011                           0.202844
# C3L-00026                          -0.094514
# C3L-00079                           0.104721
# ...                                      ...
# C3N-01646                           0.128537
# C3N-01648                          -0.153775
# C3N-01649                          -0.065001
# C3N-01651                          -0.113729
# C3N-01808                           0.056003
#
#             tumor_normal_residual_diff_USP6NL  \
# Patient_ID
# C3L-00004                           -0.166229
# C3L-00010                           -0.105923
# C3L-00011                            0.070314
# C3L-00026                            0.042727
# C3L-00079                            0.246074
# ...                                       ...
# C3N-01646                            0.118924
# C3N-01648                            0.236419
# C3N-01649                            0.046015
# C3N-01651                            0.040112
# C3N-01808                           -0.042508
#
#             tumor_normal_residual_diff_VPS25  tumor_normal_residual_diff_WNK1  \
# Patient_ID
# C3L-00004                           0.102887                         0.027144
# C3L-00010                          -0.065229                         0.017284
# C3L-00011                           0.106287                         0.057198
# C3L-00026                          -0.031146                        -0.169713
# C3L-00079                          -0.113529                        -0.180434
# ...                                      ...                              ...
# C3N-01646                          -0.012401                        -0.028849
# C3N-01648                          -0.102720                         0.178380
# C3N-01649                           0.012371                        -0.035182
# C3N-01651                           0.118889                         0.052720
# C3N-01808                           0.021813                        -0.078380
#
#             tumor_normal_residual_diff_XPNPEP1  \
# Patient_ID
# C3L-00004                            -0.022660
# C3L-00010                            -0.183118
# C3L-00011                             0.117379
# C3L-00026                            -0.176085
# C3L-00079                            -0.219944
# ...                                        ...
# C3N-01646                            -0.052458
# C3N-01648                             0.076352
# C3N-01649                             0.076530
# C3N-01651                            -0.093561
# C3N-01808                             0.006426
#
#             tumor_normal_residual_diff_YARS2  \
# Patient_ID
# C3L-00004                           0.032056
# C3L-00010                           0.516323
# C3L-00011                           0.289518
# C3L-00026                           0.657336
# C3L-00079                          -0.405774
# ...                                      ...
# C3N-01646                          -0.001251
# C3N-01648                           0.167799
# C3N-01649                          -0.432277
# C3N-01651                           0.391485
# C3N-01808                          -0.102282
#
#             tumor_normal_residual_diff_ZDHHC2  \
# Patient_ID
# C3L-00004                                 NaN
# C3L-00010                                 NaN
# C3L-00011                           -0.678727
# C3L-00026                                 NaN
# C3L-00079                                 NaN
# ...                                       ...
# C3N-01646                            0.534525
# C3N-01648                                 NaN
# C3N-01649                                 NaN
# C3N-01651                                 NaN
# C3N-01808                                 NaN
#
#             tumor_normal_residual_diff_ZEB1  \
# Patient_ID
# C3L-00004                               NaN
# C3L-00010                               NaN
# C3L-00011                               NaN
# C3L-00026                          0.011026
# C3L-00079                         -0.173976
# ...                                     ...
# C3N-01646                               NaN
# C3N-01648                               NaN
# C3N-01649                          0.312212
# C3N-01651                         -0.000415
# C3N-01808                         -0.255815
#
#             tumor_normal_residual_diff_ZNF358  \
# Patient_ID
# C3L-00004                            0.221142
# C3L-00010                                 NaN
# C3L-00011                           -0.050268
# C3L-00026                                 NaN
# C3L-00079                            0.033889
# ...                                       ...
# C3N-01646                           -0.128325
# C3N-01648                            0.017676
# C3N-01649                            0.182501
# C3N-01651                                 NaN
# C3N-01808                           -0.052708
#
#             tumor_normal_residual_diff_ZNF397
# Patient_ID
# C3L-00004                                 NaN
# C3L-00010                                 NaN
# C3L-00011                                 NaN
# C3L-00026                                 NaN
# C3L-00079                                 NaN
# ...                                       ...
# C3N-01646                                 NaN
# C3N-01648                                 NaN
# C3N-01649                                 NaN
# C3N-01651                           -0.079001
# C3N-01808                                 NaN
#
# [75 rows x 183 columns]

# %% [markdown]
# #### Select tumor and normal above_reg_line values for top genes

# %%
above_reg_line_top_genes = {}
for cancer_type in cancer_types:
    res = residuals[cancer_type]
    
    top_res = res[res["Gene"].isin(highest_delta_genes[cancer_type])].\
    pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values="above_reg_line",
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).\
    dropna(axis=0, how="any").\
    reset_index(drop=False)
    
    top_res = top_res.\
    pivot(
        index="Patient_ID",
        columns="Gene",
        values=["Normal", "Tumor"],
    ).\
    swaplevel(0, 1, axis=1).\
    sort_index(axis=1)
    
    top_res = cput.reduce_multiindex(top_res, flatten=True).\
    add_prefix("above_reg_line_")
    
    top_res.columns.name = None
    
    above_reg_line_top_genes[cancer_type] = top_res.astype(bool)

above_reg_line_top_genes["ccrcc"]
# Out:
#             above_reg_line_ADCY3_Normal  above_reg_line_ADCY3_Tumor  \
# Patient_ID
# C3L-00004                          True                        True
# C3L-00010                          True                        True
# C3L-00011                          True                        True
# C3L-00026                          True                        True
# C3L-00079                          True                        True
# ...                                 ...                         ...
# C3N-01646                          True                        True
# C3N-01648                          True                        True
# C3N-01649                         False                       False
# C3N-01651                          True                        True
# C3N-01808                         False                        True
#
#             above_reg_line_AGK_Normal  above_reg_line_AGK_Tumor  \
# Patient_ID
# C3L-00004                        True                     False
# C3L-00010                       False                     False
# C3L-00011                        True                     False
# C3L-00026                        True                      True
# C3L-00079                       False                      True
# ...                               ...                       ...
# C3N-01646                        True                      True
# C3N-01648                        True                     False
# C3N-01649                       False                     False
# C3N-01651                        True                      True
# C3N-01808                        True                      True
#
#             above_reg_line_AGXT_Normal  above_reg_line_AGXT_Tumor  \
# Patient_ID
# C3L-00004                         True                       True
# C3L-00010                         True                      False
# C3L-00011                         True                       True
# C3L-00026                         True                       True
# C3L-00079                        False                      False
# ...                                ...                        ...
# C3N-01646                        False                      False
# C3N-01648                         True                       True
# C3N-01649                        False                      False
# C3N-01651                         True                      False
# C3N-01808                         True                       True
#
#             above_reg_line_AHSA1_Normal  above_reg_line_AHSA1_Tumor  \
# Patient_ID
# C3L-00004                         False                        True
# C3L-00010                          True                       False
# C3L-00011                          True                        True
# C3L-00026                         False                       False
# C3L-00079                         False                        True
# ...                                 ...                         ...
# C3N-01646                         False                       False
# C3N-01648                          True                        True
# C3N-01649                          True                       False
# C3N-01651                          True                        True
# C3N-01808                          True                        True
#
#             above_reg_line_ALDH18A1_Normal  above_reg_line_ALDH18A1_Tumor  \
# Patient_ID
# C3L-00004                            False                           True
# C3L-00010                            False                          False
# C3L-00011                             True                          False
# C3L-00026                             True                           True
# C3L-00079                             True                           True
# ...                                    ...                            ...
# C3N-01646                             True                           True
# C3N-01648                             True                           True
# C3N-01649                             True                          False
# C3N-01651                             True                           True
# C3N-01808                             True                           True
#
#             ...  above_reg_line_YARS2_Normal  above_reg_line_YARS2_Tumor  \
# Patient_ID  ...
# C3L-00004   ...                        False                        True
# C3L-00010   ...                        False                       False
# C3L-00011   ...                         True                       False
# C3L-00026   ...                        False                        True
# C3L-00079   ...                        False                        True
# ...         ...                          ...                         ...
# C3N-01646   ...                         True                       False
# C3N-01648   ...                         True                        True
# C3N-01649   ...                         True                        True
# C3N-01651   ...                         True                        True
# C3N-01808   ...                         True                       False
#
#             above_reg_line_ZDHHC2_Normal  above_reg_line_ZDHHC2_Tumor  \
# Patient_ID
# C3L-00004                           True                         True
# C3L-00010                           True                         True
# C3L-00011                           True                        False
# C3L-00026                           True                         True
# C3L-00079                           True                         True
# ...                                  ...                          ...
# C3N-01646                          False                         True
# C3N-01648                           True                         True
# C3N-01649                           True                         True
# C3N-01651                           True                         True
# C3N-01808                           True                         True
#
#             above_reg_line_ZEB1_Normal  above_reg_line_ZEB1_Tumor  \
# Patient_ID
# C3L-00004                         True                       True
# C3L-00010                         True                       True
# C3L-00011                         True                       True
# C3L-00026                         True                       True
# C3L-00079                         True                       True
# ...                                ...                        ...
# C3N-01646                         True                       True
# C3N-01648                         True                       True
# C3N-01649                         True                      False
# C3N-01651                        False                       True
# C3N-01808                         True                       True
#
#             above_reg_line_ZNF358_Normal  above_reg_line_ZNF358_Tumor  \
# Patient_ID
# C3L-00004                          False                        False
# C3L-00010                           True                         True
# C3L-00011                          False                        False
# C3L-00026                           True                         True
# C3L-00079                           True                         True
# ...                                  ...                          ...
# C3N-01646                          False                         True
# C3N-01648                          False                         True
# C3N-01649                           True                         True
# C3N-01651                           True                         True
# C3N-01808                           True                        False
#
#             above_reg_line_ZNF397_Normal  above_reg_line_ZNF397_Tumor
# Patient_ID
# C3L-00004                           True                         True
# C3L-00010                           True                         True
# C3L-00011                           True                         True
# C3L-00026                           True                         True
# C3L-00079                           True                         True
# ...                                  ...                          ...
# C3N-01646                           True                         True
# C3N-01648                           True                         True
# C3N-01649                           True                         True
# C3N-01651                          False                        False
# C3N-01808                           True                         True
#
# [75 rows x 366 columns]

# %% [markdown]
# ### Generate, for each patient, correlation between tumor and normal residuals
#
# This is the correlation value from a graph for each patient where the x axis is normal residuals for a gene in that patient and the y axis is tumor residuals for a gene in that patient.

# %%
# FINDS THE TUMOR NORMAL CORR FOR THE HIGHEST DELTA GENES

def get_patient_residuals_corr(res):
    """For a particular cancer type, find the correlation coefficient of tumor
    residual to normal residual for each patient in the cancer type.
    
    Parameters:
    res (pandas.DataFrame): The residuals table for the cancer type
    
    Returns:
    pandas.DataFrame: A table containing the correlation coefficient of tumor 
        residual to normal residual for each patient in the cancer type
    """
    
    # Just get the columns we need
    res = res[["Patient_ID", "Gene", "Tissue", "orth_resid"]]
    
    # Make tumor and normal residuals separate columns
    res = res.pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values="orth_resid",
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).reset_index(drop=False)
    
    res.columns.name = None
    
    # Define function to get correlation for a particular patient
    def get_corr(df):
        return df.corr(
            method="spearman",
            min_periods=10 if cancer_type == "endometrial" else 15,
        ).iloc[0][1]
    
    # Get correlation for each patient
    corr = res.\
    groupby("Patient_ID").\
    apply(get_corr).\
    rename("tumor_normal_residuals_corr").\
    to_frame().\
    dropna(axis=0, how="any")
    
    return corr

patient_residuals_corr = {}
for cancer_type in cancer_types:
    df = residuals[cancer_type]
    patient_residuals_corr[cancer_type] = get_patient_residuals_corr(df[df['Gene'].isin(highest_delta_genes[cancer_type])])

patient_residuals_corr["luad"]
# Out:
#             tumor_normal_residuals_corr
# Patient_ID
# C3L-00001                      0.250850
# C3L-00009                      0.221196
# C3L-00080                      0.091227
# C3L-00083                      0.057682
# C3L-00093                      0.070900
# ...                                 ...
# C3N-02582                      0.192453
# C3N-02586                      0.219598
# C3N-02587                      0.203052
# C3N-02588                      0.147810
# C3N-02729                      0.217526
#
# [101 rows x 1 columns]

# %%
def patient_residuals_corr_plot(res):
    """For a particular cancer type, find the correlation coefficient of tumor
    residual to normal residual for each patient in the cancer type.
    
    Parameters:
    res (pandas.DataFrame): The residuals table for the cancer type
    
    Returns:
    pandas.DataFrame: A table containing the correlation coefficient of tumor 
        residual to normal residual for each patient in the cancer type
    """
    
    # Just get the columns we need
    res = res[["Patient_ID", "Gene", "Tissue", "orth_resid"]]

    
    # Make tumor and normal residuals separate columns
    res = res.pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values="orth_resid",
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).reset_index(drop=False)
    
    res.columns.name = None
    res = res[res["Patient_ID"] == "C3N-01648"]
    
    
    scatter = alt.Chart(res).mark_point().encode(
        x=alt.X(
            "Normal",
            title="Normal residual"
        ),
        y=alt.Y(
            "Tumor",
            title="Tumor residual"
        ),
    )
    
    chart = (scatter + scatter.transform_regression('Normal', 'Tumor').mark_line(color="#FF7F0E")).properties(
        title=["Tumor-normal residuals correlation for each protein", "Patient C3N-01648"]
    )
    
    return chart

df = residuals['ccrcc']
#patient_residuals_corr_plot(residuals["ccrcc"])
patient_residuals_corr_plot(df[df['Gene'].isin(highest_delta_genes[cancer_type])])
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Now remember--we can only generate this data for paired tumor-normal samples. Earlier we calculated how many paired samples we have for each data type; below we print the numbers of patients we have tumor-normal residuals correlation values for, which should be the same as the number of paired samples for each cancer type.

# %%
print("Number of patients per cancer type for which we were able to calculate tumor-normal residuals correlation:")
for cancer_type in cancer_types:
    print(f"{cancer_type: >11} - {patient_residuals_corr[cancer_type].shape[0]: >3}")
# Out:
# Number of patients per cancer type for which we were able to calculate tumor-normal residuals correlation:
#       ccrcc -  75
# endometrial -  14
#       hnscc -  42
#        lscc -  94
#        luad - 101

# %% [markdown]
# ### Generate, for each patient, correlations of RNA tumor-normal ratio to protein tumor-normal ratio
#
# This is the correlation value from a graph for each patient where the x axis is the ratio of tumor over normal transcriptomics value for a gene in that patient, and the y axis is the ratio of tumor over normal proteomics value for a gene in that patient.

# %%
prot_RNA_tumor_normal_ratios_corr = {}
for cancer_type in cancer_types:
    df = residuals[cancer_type]
    df = df[df['Gene'].isin(highest_delta_genes[cancer_type])]
    ratios = df[["Patient_ID", "Tissue", "Gene", "Proteomics", "Transcriptomics"]].\
    pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values=["Proteomics", "Transcriptomics"],
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).\
    reset_index(drop=False)
    ratios = cput.reduce_multiindex(ratios, flatten=True)
    
    def make_cols_ratio(df, col1, col2, ratio_col_name):
        return df.\
        assign(**{ratio_col_name: df[col1] / df[col2]}).\
        drop(columns=[col1, col2])
    
    ratios = make_cols_ratio(
        ratios, 
        "Proteomics_Tumor", 
        "Proteomics_Normal", 
        "Prot_Tumor_Normal_Ratio"
    )
    ratios = make_cols_ratio(
        ratios, 
        "Transcriptomics_Tumor", 
        "Transcriptomics_Normal", 
        "RNA_Tumor_Normal_Ratio"
    )
    
    # Define function to get correlation for a particular patient
    def get_corr(df):
        return df.corr(
            method="spearman",
            min_periods=10 if cancer_type == "endometrial" else 15,
        ).iloc[0][1]
    
    corr = ratios.\
    groupby("Patient_ID").\
    apply(get_corr).\
    rename("prot_RNA_tumor_normal_ratios_corr").\
    to_frame().\
    dropna(axis=0, how="any")
    
    prot_RNA_tumor_normal_ratios_corr[cancer_type] = corr
    
prot_RNA_tumor_normal_ratios_corr["ccrcc"]
# Out:
#             prot_RNA_tumor_normal_ratios_corr
# Patient_ID
# C3L-00004                            0.055306
# C3L-00010                            0.010438
# C3L-00011                            0.152253
# C3L-00026                            0.018879
# C3L-00079                           -0.298308
# ...                                       ...
# C3N-01646                            0.205542
# C3N-01648                            0.174059
# C3N-01649                            0.135709
# C3N-01651                            0.082687
# C3N-01808                           -0.028746
#
# [75 rows x 1 columns]

# %%
for cancer_type in ["hnscc"]:
    df = residuals[cancer_type]
    df = df[df['Gene'].isin(highest_delta_genes[cancer_type])]
    ratios = df[["Patient_ID", "Tissue", "Gene", "Proteomics", "Transcriptomics"]].\
    pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values=["Proteomics", "Transcriptomics"],
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).\
    reset_index(drop=False)
    ratios = cput.reduce_multiindex(ratios, flatten=True)
    
    def make_cols_ratio(df, col1, col2, ratio_col_name):
        return df.\
        assign(**{ratio_col_name: df[col1] / df[col2]}).\
        drop(columns=[col1, col2])
    
    ratios = make_cols_ratio(
        ratios, 
        "Proteomics_Tumor", 
        "Proteomics_Normal", 
        "Prot_Tumor_Normal_Ratio"
    )
    ratios = make_cols_ratio(
        ratios, 
        "Transcriptomics_Tumor", 
        "Transcriptomics_Normal", 
        "RNA_Tumor_Normal_Ratio"
    )
    
ratios = ratios[ratios["Patient_ID"] == "C3N-03888"]

scatter = alt.Chart(ratios).mark_point().encode(
    x=alt.X(
        "RNA_Tumor_Normal_Ratio",
        title="RNA tumor-normal ratio"
    ),
    y=alt.Y(
        "Prot_Tumor_Normal_Ratio",
        title="Protein tumor-normal ratio"
    ),
    tooltip="Gene"
)

chart = (scatter + scatter.transform_regression("RNA_Tumor_Normal_Ratio", "Prot_Tumor_Normal_Ratio").mark_line(color="#FF7F0E")).properties(
    title=["RNA to protein tumor-normal ratio correlation for each protein", "Patient C3N-03888"]
)
chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Load pancan clinical data

# %%
dss = {
    "ccrcc": pc.PancanCcrcc,
    "endometrial": pc.PancanUcec,
    "hnscc": pc.PancanHnscc,
    "lscc": pc.PancanLscc,
    "luad": pc.PancanLuad,
}

# %%
def get_clinical(dss, cancer_type):
    
    # Download
    #pc.download("pancan" + cancer_type) if cancer_type != "endometrial" else pc.download("pancanucec")
    
    # Instantiate the dataset
    ds = dss[cancer_type]()
    
    # We use get_clinical instead of get_followup because get_followup just returns
    # a subset of the clinical table, and we need other columns too
    clin_vars = ds.get_clinical()[[
        "Recurrence status (1, yes; 0, no)",
        "Survial status (1, dead; 0, alive)",
        "baseline/histologic_type",
        "baseline/pathologic_staging_primary_tumor",
        "cptac_path/histologic_grade",
        "follow-up/measure_of_success_of_outcome_at_last_available_follow-up",
    ]]

    # Get rid of categorizing prefixes in column names, where they exist
    cols = clin_vars.columns.str.split("/", expand=True).to_frame()
    cols.columns = ["a", "b"]
    cols = cols.assign(b=cols["b"].fillna(cols["a"])) # If there was no prefix, no change
    clin_vars.columns = cols["b"].rename(None)
    
    # Fix values in measure of success column--sometimes deceased patients are listed
    # as "Persistent Disease" in this column, instead of "Patient Deceased"
    clin_vars = clin_vars.assign(
        **{"measure_of_success_of_outcome_at_last_available_follow-up": np.where(
            clin_vars["Survial status (1, dead; 0, alive)"] == 1,
            "Patient Deceased",
            clin_vars["measure_of_success_of_outcome_at_last_available_follow-up"]
        )}
    )
    
    # Make paired Patient_IDs same
    clin_vars.index = clin_vars.index.str.split("\.N", expand=True).to_frame()[0]
    
    # Drop any completely NaN rows
    clin_vars = clin_vars.dropna(axis=0, how="all")

    return clin_vars

clin = {}
for cancer_type in cancer_types:
    clin[cancer_type] = get_clinical(dss, cancer_type)

# %% [markdown]
# ### Combine data into one table

# %%
all_data = {}
for cancer_type in cancer_types:
    dfs = [
        top_genes_residuals_diff[cancer_type],
        above_reg_line_top_genes[cancer_type],
        patient_residuals_corr[cancer_type],
        prot_RNA_tumor_normal_ratios_corr[cancer_type],
        clin[cancer_type],
    ]
    
    cancer_type_all = dfs[0]
    for df in dfs[1:]:
        cancer_type_all = cancer_type_all.join(df, how="outer")
    cancer_type_all = cancer_type_all.assign(cancer_type=cancer_type)
    all_data[cancer_type] = cancer_type_all

# %%
all_data
# Out:
#            tumor_normal_residual_diff_AAGAB  tumor_normal_residual_diff_AAR2  \
# C3L-00004                         -0.114371                         0.058212
# C3L-00010                          0.125057                        -0.010755
# C3L-00011                         -0.000058                        -0.015141
# C3L-00026                          0.056581                        -0.065460
# C3L-00079                          0.173266                        -0.040997
# ...                                     ...                              ...
# C3N-02582                          0.538398                              NaN
# C3N-02586                          0.510025                              NaN
# C3N-02587                         -0.080176                              NaN
# C3N-02588                          0.118428                              NaN
# C3N-02729                          0.078965                              NaN
#
#            tumor_normal_residual_diff_ABAT  tumor_normal_residual_diff_ABCC1  \
# C3L-00004                        -0.126338                          0.279651
# C3L-00010                         0.322410                         -0.112348
# C3L-00011                         0.504048                          0.073510
# C3L-00026                         0.076625                         -0.471484
# C3L-00079                        -0.469949                         -0.156338
# ...                                    ...                               ...
# C3N-02582                              NaN                               NaN
# C3N-02586                              NaN                               NaN
# C3N-02587                              NaN                               NaN
# C3N-02588                              NaN                               NaN
# C3N-02729                              NaN                               NaN
#
#            tumor_normal_residual_diff_ABHD11  \
# C3L-00004                           0.191433
# C3L-00010                          -0.030529
# C3L-00011                          -0.028614
# C3L-00026                           0.533219
# C3L-00079                          -0.052869
# ...                                      ...
# C3N-02582                           0.133200
# C3N-02586                           0.115293
# C3N-02587                           0.292935
# C3N-02588                          -0.078499
# C3N-02729                           0.830643
#
#            tumor_normal_residual_diff_ABHD15  \
# C3L-00004                          -0.806119
# C3L-00010                           0.174814
# C3L-00011                           0.577749
# C3L-00026                          -1.328916
# C3L-00079                                NaN
# ...                                      ...
# C3N-02582                                NaN
# C3N-02586                                NaN
# C3N-02587                                NaN
# C3N-02588                                NaN
# C3N-02729                                NaN
#
#            tumor_normal_residual_diff_ABHD3  tumor_normal_residual_diff_ABI2  \
# C3L-00004                          0.286192                        -0.024497
# C3L-00010                         -0.010978                        -0.092135
# C3L-00011                          0.022975                        -0.162236
# C3L-00026                          0.007143                        -0.034911
# C3L-00079                         -0.014427                        -0.061460
# ...                                     ...                              ...
# C3N-02582                               NaN                              NaN
# C3N-02586                               NaN                              NaN
# C3N-02587                               NaN                              NaN
# C3N-02588                               NaN                              NaN
# C3N-02729                               NaN                              NaN
#
#            tumor_normal_residual_diff_ABO  tumor_normal_residual_diff_ABRACL  \
# C3L-00004                             NaN                          -0.258826
# C3L-00010                        0.067995                          -0.141112
# C3L-00011                       -0.014068                           0.012607
# C3L-00026                        0.553142                          -0.525805
# C3L-00079                             NaN                           0.014097
# ...                                   ...                                ...
# C3N-02582                             NaN                                NaN
# C3N-02586                             NaN                                NaN
# C3N-02587                             NaN                                NaN
# C3N-02588                             NaN                                NaN
# C3N-02729                             NaN                                NaN
#
#            ...  above_reg_line_ZNF532_Normal  above_reg_line_ZNF532_Tumor  \
# C3L-00004  ...                           NaN                          NaN
# C3L-00010  ...                           NaN                          NaN
# C3L-00011  ...                           NaN                          NaN
# C3L-00026  ...                           NaN                          NaN
# C3L-00079  ...                           NaN                          NaN
# ...        ...                           ...                          ...
# C3N-02582  ...                         False                         True
# C3N-02586  ...                         False                        False
# C3N-02587  ...                          True                        False
# C3N-02588  ...                         False                        False
# C3N-02729  ...                         False                         True
#
#            above_reg_line_ZNF544_Normal  above_reg_line_ZNF544_Tumor  \
# C3L-00004                           NaN                          NaN
# C3L-00010                           NaN                          NaN
# C3L-00011                           NaN                          NaN
# C3L-00026                           NaN                          NaN
# C3L-00079                           NaN                          NaN
# ...                                 ...                          ...
# C3N-02582                         False                         True
# C3N-02586                         False                         True
# C3N-02587                          True                         True
# C3N-02588                         False                        False
# C3N-02729                          True                         True
#
#            above_reg_line_ZNF609_Normal  above_reg_line_ZNF609_Tumor  \
# C3L-00004                           NaN                          NaN
# C3L-00010                           NaN                          NaN
# C3L-00011                           NaN                          NaN
# C3L-00026                           NaN                          NaN
# C3L-00079                           NaN                          NaN
# ...                                 ...                          ...
# C3N-02582                         False                        False
# C3N-02586                         False                        False
# C3N-02587                         False                        False
# C3N-02588                         False                         True
# C3N-02729                         False                        False
#
#            above_reg_line_ZNF668_Normal  above_reg_line_ZNF668_Tumor  \
# C3L-00004                           NaN                          NaN
# C3L-00010                           NaN                          NaN
# C3L-00011                           NaN                          NaN
# C3L-00026                           NaN                          NaN
# C3L-00079                           NaN                          NaN
# ...                                 ...                          ...
# C3N-02582                         False                        False
# C3N-02586                         False                        False
# C3N-02587                         False                         True
# C3N-02588                         False                        False
# C3N-02729                         False                         True
#
#            above_reg_line_ZNF672_Normal  above_reg_line_ZNF672_Tumor
# C3L-00004                           NaN                          NaN
# C3L-00010                           NaN                          NaN
# C3L-00011                           NaN                          NaN
# C3L-00026                           NaN                          NaN
# C3L-00079                           NaN                          NaN
# ...                                 ...                          ...
# C3N-02582                          True                        False
# C3N-02586                          True                        False
# C3N-02587                         False                         True
# C3N-02588                          True                        False
# C3N-02729                          True                        False
#
# [546 rows x 20613 columns]

# %%
# Define input and target columns
# input_cols = [  

#     # Cancer type
#     "cancer_type",
    
#     # Our calculated correlations
#     "tumor_normal_residuals_corr",
#     "prot_RNA_tumor_normal_ratios_corr",
    
#     # Gene-based regression data
#     "above_reg_line_ACSS1_Normal",
#     "above_reg_line_ACSS1_Tumor",
#     "above_reg_line_C1orf116_Normal",
#     "above_reg_line_C1orf116_Tumor",
#     "above_reg_line_CARD9_Normal",
#     "above_reg_line_CARD9_Tumor",
#     "above_reg_line_CDKN2A_Normal",
#     "above_reg_line_CDKN2A_Tumor",
#     "above_reg_line_CFI_Normal",
#     "above_reg_line_CFI_Tumor",
#     "above_reg_line_DYNC1LI1_Normal",
#     "above_reg_line_DYNC1LI1_Tumor",
#     "above_reg_line_ECH1_Normal",
#     "above_reg_line_ECH1_Tumor",
#     "above_reg_line_ECT2_Normal",
#     "above_reg_line_ECT2_Tumor",
#     "above_reg_line_FAM57A_Normal",
#     "above_reg_line_FAM57A_Tumor",
#     "above_reg_line_GPCPD1_Normal",
#     "above_reg_line_GPCPD1_Tumor",
#     "above_reg_line_HPS3_Normal",
#     "above_reg_line_HPS3_Tumor",
#     "above_reg_line_IFT43_Normal",
#     "above_reg_line_IFT43_Tumor",
#     "above_reg_line_IMPDH1_Normal",
#     "above_reg_line_IMPDH1_Tumor",
#     "above_reg_line_IMPDH2_Normal",
#     "above_reg_line_IMPDH2_Tumor",
#     "above_reg_line_MBNL2_Normal",
#     "above_reg_line_MBNL2_Tumor",
#     "above_reg_line_MFSD4A_Normal",
#     "above_reg_line_MFSD4A_Tumor",
#     "above_reg_line_NELL1_Normal",
#     "above_reg_line_NELL1_Tumor",
#     "above_reg_line_PPM1L_Normal",
#     "above_reg_line_PPM1L_Tumor",
#     "above_reg_line_RIPK3_Normal",
#     "above_reg_line_RIPK3_Tumor",
#     "above_reg_line_RNASET2_Normal",
#     "above_reg_line_RNASET2_Tumor",
#     "above_reg_line_SLC1A5_Normal",
#     "above_reg_line_SLC1A5_Tumor",
#     "above_reg_line_TALDO1_Normal",
#     "above_reg_line_TALDO1_Tumor",
#     "above_reg_line_THADA_Normal",
#     "above_reg_line_THADA_Tumor",
#     "above_reg_line_TXLNG_Normal",
#     "above_reg_line_TXLNG_Tumor",
#     "above_reg_line_USP7_Normal",
#     "above_reg_line_USP7_Tumor",
#     "tumor_normal_residual_diff_ACSS1",
#     "tumor_normal_residual_diff_C1orf116",
#     "tumor_normal_residual_diff_CARD9",
#     "tumor_normal_residual_diff_CDKN2A",
#     "tumor_normal_residual_diff_CFI",
#     "tumor_normal_residual_diff_DYNC1LI1",
#     "tumor_normal_residual_diff_ECH1",
#     "tumor_normal_residual_diff_ECT2",
#     "tumor_normal_residual_diff_FAM57A",
#     "tumor_normal_residual_diff_GPCPD1",
#     "tumor_normal_residual_diff_HPS3",
#     "tumor_normal_residual_diff_IFT43",
#     "tumor_normal_residual_diff_IMPDH1",
#     "tumor_normal_residual_diff_IMPDH2",
#     "tumor_normal_residual_diff_MBNL2",
#     "tumor_normal_residual_diff_MFSD4A",
#     "tumor_normal_residual_diff_NELL1",
#     "tumor_normal_residual_diff_PPM1L",
#     "tumor_normal_residual_diff_RIPK3",
#     "tumor_normal_residual_diff_RNASET2",
#     "tumor_normal_residual_diff_SLC1A5",
#     "tumor_normal_residual_diff_TALDO1",
#     "tumor_normal_residual_diff_THADA",
#     "tumor_normal_residual_diff_TXLNG",
#     "tumor_normal_residual_diff_USP7",
# ]

input_cols = [
    #Cancer type
     "cancer_type",
    
     # Our calculated correlations
     "tumor_normal_residuals_corr",
     "prot_RNA_tumor_normal_ratios_corr",
    
    ] + 

target_cols = [
    "Recurrence status (1, yes; 0, no)",
    "Survial status (1, dead; 0, alive)",
    "histologic_grade",
    "histologic_type",
    "measure_of_success_of_outcome_at_last_available_follow-up",
    "pathologic_staging_primary_tumor",
]

# %%
# Drop rows where input cols are all NaN
nan_subset = input_cols.copy()
nan_subset.remove("cancer_type")
all_data = all_data.dropna(axis=0, how="all", subset=nan_subset)

# %%
# Clean up and simplify the tumor stage column
all_data = all_data.assign(pathologic_staging_primary_tumor=all_data["pathologic_staging_primary_tumor"].\
    str.split(" ", expand=True)[0].\
    str.lower().\
    str.strip().\
    str.replace(":", "", regex=False).\
    str.replace("^p", "", regex=True).\
    str.replace("^(\d)", "t\1", regex=True).\
    str.replace("\x01", "", regex=False).\
    str.replace("[abc]", "", regex=True).\
    replace(to_replace="t", value=np.nan)
)

# %%
# Reorder the columns nicely, and split into inputs and targets
inputs = all_data[input_cols]
targets = all_data[target_cols]

# %%
# Save the tables
inputs.to_csv("inputs.tsv", sep="\t")
targets.to_csv("targets.tsv", sep="\t")
