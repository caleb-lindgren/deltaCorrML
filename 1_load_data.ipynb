# %%
import cptac.pancan as pc
import cptac.utils as cput
import numpy as np
import os
import pandas as pd
import pcprutils as ut
import altair as alt
import math
from math import dist

# %% [markdown]
# ### Get pancancerProteinMRNA repository path
# This analysis will build off of data stored in the pancancerProteinMRNA repo, which is publicly accessible. To access that data, clone the repository, then store the path to it in a text file with no quotes named pancancerProteinMRNA_repo_path.txt in the same directory as this notebook. The notebook will then read the path from that file and be able to access the data.

# %%
with open("pancancerProteinMRNA_repo_path.txt", "r") as pcp_path_file:
    pcp_path = pcp_path_file.read()

print(pcp_path)
# Out:
# /Users/Bryn/PayneLab/pancancer/pancancerProteinMRNA

# %%
cancer_types = [
    "ccrcc",
    "endometrial",
    "hnscc",
    "lscc",
    "luad",
]

# %% [markdown]
# ### Load delta correlations

# %%
delta_corr_path = os.path.join(pcp_path, "notebook_steps_Spearman", "data", "delta_correlation_df.csv")
delta_corr = pd.read_csv(delta_corr_path)
delta_corr = delta_corr.assign(Cancer=delta_corr["Cancer"].str.lower())

delta_corr
# Out:
#          Gene  Delta_Correlation       P_Value           FDR       Cancer
# 0        A1BG          -0.198013  2.451044e-01  4.045115e-01        hnscc
# 1         A2M          -0.118384  4.480278e-01  6.091130e-01        hnscc
# 2       A2ML1          -0.023469  2.918125e-01  4.561968e-01        hnscc
# 3        AAAS           0.275905  1.051756e-01  2.209072e-01        hnscc
# 4        AACS          -0.136836  1.800586e-01  3.266475e-01        hnscc
# ...       ...                ...           ...           ...          ...
# 50684   ZWINT           1.219024  2.267627e-09  1.049863e-07  endometrial
# 50685    ZXDC          -0.346532  2.983295e-01  5.386144e-01  endometrial
# 50686  ZYG11B           0.768196  5.463938e-04  5.319699e-03  endometrial
# 50687     ZYX           0.253630  2.456049e-01  4.795301e-01  endometrial
# 50688   ZZEF1           0.176244  5.839048e-01  7.795750e-01  endometrial
#
# [50689 rows x 5 columns]

# %% [markdown]
# ### Load gene-based residuals data

# %%
residuals = {}
residuals_dir_path = os.path.join(pcp_path, "notebook_steps_Spearman", "clinical_associations")

for cancer_type in cancer_types:
    file_name = f"{cancer_type}_residuals.tsv.gz"
    res = pd.read_csv(os.path.join(residuals_dir_path, file_name), sep="\t")
    res = res.assign(Patient_ID=res["Name"].str.split("\.N", expand=True)[0]) # Make paired Patient_IDs same
    residuals[cancer_type] = res

residuals["ccrcc"]
# Out:
#                Name     Gene  Proteomics  Tissue  Transcriptomics         m  \
# 0         C3L-00004     A1CF    0.569688   Tumor        15.287382  0.131457
# 1         C3L-00010     A1CF    0.289879   Tumor        15.952434  0.131457
# 2         C3L-00011     A1CF   -2.555520   Tumor         0.016077  0.131457
# 3         C3L-00026     A1CF    0.392756   Tumor        15.005262  0.131457
# 4         C3L-00079     A1CF   -0.884605   Tumor         4.334532  0.131457
# ...             ...      ...         ...     ...              ...       ...
# 556633  C3N-01646.N  ZSCAN18    0.336257  Normal         8.516963  0.031765
# 556634  C3N-01648.N  ZSCAN18    0.181620  Normal         7.488197  0.031765
# 556635  C3N-01649.N  ZSCAN18    0.122117  Normal        10.325149  0.031765
# 556636  C3N-01651.N  ZSCAN18    0.136398  Normal         6.818568  0.031765
# 556637  C3N-01808.N  ZSCAN18    0.081424  Normal         7.905172  0.031765
#
#                b  orth_resid  intersect_x  intersect_y  above_reg_line  \
# 0      -1.330471    0.108536    15.273236     0.677298           False
# 1      -1.330471    0.472637    15.890833     0.758485           False
# 2      -1.330471    1.216695    -0.142501    -1.349203           False
# 3      -1.330471    0.247188    14.973045     0.637836           False
# 4      -1.330471    0.122880     4.318517    -0.762773           False
# ...          ...         ...          ...          ...             ...
# 556633 -0.094214    0.159848     8.522038     0.176490            True
# 556634 -0.094214    0.037951     7.489402     0.143688            True
# 556635 -0.094214    0.111592    10.321607     0.233653           False
# 556636 -0.094214    0.014012     6.819013     0.122393            True
# 556637 -0.094214    0.075433     7.902777     0.156819           False
#
#        Patient_ID
# 0       C3L-00004
# 1       C3L-00010
# 2       C3L-00011
# 3       C3L-00026
# 4       C3L-00079
# ...           ...
# 556633  C3N-01646
# 556634  C3N-01648
# 556635  C3N-01649
# 556636  C3N-01651
# 556637  C3N-01808
#
# [556638 rows x 12 columns]

# %% [markdown]
# ### Get the genes that are highly correlated and highly significant for each cancer type

# %%
def get_highest_delta_corr(df):
    df = df.assign(abs_delta_corr=df["Delta_Correlation"].abs())
    df = df.sort_values(by="abs_delta_corr")
    df = df.loc[(df['FDR'] < 0.05) & ((df['Delta_Correlation'] > 0.7) | (df['Delta_Correlation'] < -0.7))]
    return df["Gene"].tolist()

highest_delta_genes = {}
for cancer in cancer_types:
    cancer_df = delta_corr.loc[delta_corr['Cancer'] == cancer]
    highest_delta_genes[cancer] = get_highest_delta_corr(cancer_df)

highest_delta_genes
# Out:
# {'ccrcc': ['AP4S1',
#   'GDAP1',
#   'UNC5B',
#   'ZDHHC2',
#   'USP47',
#   'NEK3',
#   'PTTG1IP',
#   'STRA6',
#   'AZI2',
#   'WNK1',
#   'RALGAPA1',
#   'FAF2',
#   'TSPYL4',
#   'SCGN',
#   'LSR',
#   'MUC15',
#   'SLC35A5',
#   'CLINT1',
#   'GMFB',
#   'RHAG',
#   'MARK3',
#   'EFHD1',
#   'CR2',
#   'CNTLN',
#   'PEG10',
#   'PTPRG',
#   'NACC1',
#   'C9orf78',
#   'IGF2BP3',
#   'LY6E',
#   'MUC13',
#   'YARS2',
#   'CERCAM',
#   'PGK1',
#   'LPCAT1',
#   'AP3M1',
#   'NCOA7',
#   'DNAAF2',
#   'NPEPPS',
#   'METAP1D',
#   'PGBD5',
#   'SCAP',
#   'CCP110',
#   'GOLPH3L',
#   'ALDH18A1',
#   'SLC36A2',
#   'PDCD7',
#   'PPM1M',
#   'GCDH',
#   'RBP2',
#   'POMT2',
#   'NOVA2',
#   'DLG5',
#   'APLP2',
#   'PGD',
#   'COLEC12',
#   'MCC',
#   'PIK3R4',
#   'PDZRN3',
#   'AHSA1',
#   'KIAA1522',
#   'CYP4F2',
#   'NOL3',
#   'SLC44A1',
#   'DCTD',
#   'ZNF358',
#   'ENPP2',
#   'PPID',
#   'PLS1',
#   'TTC36',
#   'NGLY1',
#   'EHD4',
#   'MAPK10',
#   'SMAP1',
#   'CCNY',
#   'PNCK',
#   'TREM2',
#   'PDP1',
#   'SMPD2',
#   'CALCRL',
#   'CLCC1',
#   'PPP1R3G',
#   'SLC22A8',
#   'NCAPD2',
#   'MIOS',
#   'PISD',
#   'BTN3A1',
#   'COL5A1',
#   'DUSP11',
#   'GNAI3',
#   'ANKZF1',
#   'SORCS3',
#   'XPNPEP1',
#   'HOOK1',
#   'SCAMP1',
#   'CTSS',
#   'FAM114A2',
#   'AGK',
#   'CD70',
#   'SLC12A1',
#   'POLA2',
#   'VPS25',
#   'TATDN1',
#   'DNALI1',
#   'PPIP5K2',
#   'GAP43',
#   'TTC7B',
#   'AGXT',
#   'USP6NL',
#   'SLC34A3',
#   'RNF138',
#   'CDH4',
#   'CTSV',
#   'KIR3DL2',
#   'NFIB',
#   'GNA13',
#   'RALA',
#   'FPGS',
#   'TMEM132A',
#   'C1GALT1C1',
#   'CTSO',
#   'SNTB2',
#   'KLHL12',
#   'UHRF1',
#   'DUSP9',
#   'KCNAB2',
#   'CACNA2D1',
#   'ASPN',
#   'GFOD1',
#   'TPX2',
#   'OLA1',
#   'EIF4EBP1',
#   'CFDP1',
#   'CLASP2',
#   'TRAM2',
#   'MAP2K4',
#   'COMMD2',
#   'GNAQ',
#   'SLC29A1',
#   'ATP2C1',
#   'GINS3',
#   'AQP2',
#   'CPNE6',
#   'GRAMD4',
#   'IDO1',
#   'PCSK6',
#   'GALNT5',
#   'ESD',
#   'CA9',
#   'CALB1',
#   'ASPM',
#   'NT5C1A',
#   'SEMA6B',
#   'CFAP36',
#   'FBXL2',
#   'RAB5A',
#   'KLHL29',
#   'ZEB1',
#   'HSD17B4',
#   'RCAN2',
#   'PTPRK',
#   'CHRD',
#   'TMEM88',
#   'PLA2G7',
#   'SLC12A3',
#   'PPP1R13B',
#   'COPZ2',
#   'TFG',
#   'SLFN13',
#   'ATP2B1',
#   'EPS8L3',
#   'ADCY3',
#   'HLA-G',
#   'SLC40A1',
#   'ATG2B',
#   'BET1',
#   'APPL1',
#   'MYCT1',
#   'INPP5E',
#   'INPP5A',
#   'C4orf19',
#   'ZNF397',
#   'SNX2',
#   'TLN2',
#   'KRBA1',
#   'RNASET2'],
#  'endometrial': ['GBP4',
#   'C12orf57',
#   'LRRC8E',
#   'SMC4',
#   'FKBP3',
#   'SERPINA3',
#   'HSPB7',
#   'IFIT2',
#   'NT5DC2',
#   'CXorf38',
#   'TRMT1L',
#   'SETMAR',
#   'MALT1',
#   'OTUD7B',
#   'RRP1B',
#   'CEACAM5',
#   'FBXL17',
#   'IPO9',
#   'KNTC1',
#   'BCAM',
#   'MIPEP',
#   'CKS1B',
#   'MET',
#   'GYS1',
#   'CLPTM1',
#   'POGZ',
#   'RTF1',
#   'PDCD2L',
#   'ACOT13',
#   'MUC4',
#   'EZR',
#   'CD47',
#   'WDR75',
#   'USP15',
#   'MACROD1',
#   'PPP2CB',
#   'UPF1',
#   'CTSZ',
#   'LDHD',
#   'RNASET2',
#   'TOM1',
#   'HKDC1',
#   'LPXN',
#   'ARHGAP35',
#   'TNFSF10',
#   'BOLA3',
#   'CEP55',
#   'SPAG1',
#   'SCYL2',
#   'EVI2B',
#   'TRERF1',
#   'FOXJ2',
#   'STRN',
#   'EHHADH',
#   'CLIC1',
#   'POF1B',
#   'HINT3',
#   'MSR1',
#   'EIF4EBP2',
#   'INCENP',
#   'PCNA',
#   'HOOK3',
#   'WDR47',
#   'RIPK1',
#   'PTPN12',
#   'INPP1',
#   'NCOA5',
#   'YBX3',
#   'SLC22A18',
#   'GATAD2A',
#   'CDC73',
#   'PHYHIPL',
#   'PTPRJ',
#   'PARP12',
#   'TMCO3',
#   'HSD17B4',
#   'CLTB',
#   'CWH43',
#   'SLC6A14',
#   'RANGRF',
#   'CHEK2',
#   'CPT1A',
#   'ANXA7',
#   'PPM1L',
#   'ZNF608',
#   'HEXIM1',
#   'GSTO1',
#   'DTX2',
#   'FGD4',
#   'HDHD2',
#   'KRTCAP3',
#   'CHMP4C',
#   'RHEB',
#   'ZWILCH',
#   'PLEKHS1',
#   'ZNF687',
#   'GM2A',
#   'TTYH3',
#   'YTHDF1',
#   'ERAL1',
#   'NME5',
#   'KIAA1211L',
#   'SLC9A7',
#   'ATP8B1',
#   'DECR1',
#   'ECHS1',
#   'ESRP1',
#   'ZNRF2',
#   'PIK3AP1',
#   'POLI',
#   'ANKRD22',
#   'FGFBP1',
#   'ZFP36L2',
#   'CEP97',
#   'SLC12A4',
#   'LGALS8',
#   'CYP2S1',
#   'KIF1A',
#   'KCTD12',
#   'GRAP',
#   'SLC38A1',
#   'PLCH1',
#   'SQLE',
#   'CD3EAP',
#   'FAM114A2',
#   'TXLNG',
#   'DDX60L',
#   'FBXL20',
#   'RABEP1',
#   'SMARCA2',
#   'NCLN',
#   'KIF20A',
#   'PIP4K2C',
#   'ZNF704',
#   'YRDC',
#   'EIF3H',
#   'CHCHD6',
#   'BAZ2A',
#   'AMOT',
#   'TTI2',
#   'SCGB2A2',
#   'MKNK1',
#   'RNF169',
#   'IFIT1',
#   'C2orf69',
#   'ARL3',
#   'IFT46',
#   'PCDH7',
#   'PROSER2',
#   'ZBTB10',
#   'KCTD1',
#   'CLEC3B',
#   'GMPS',
#   'MPV17',
#   'MARVELD2',
#   'DCAF6',
#   'CASP3',
#   'DPF2',
#   'ALDH3A1',
#   'DOK1',
#   'RFC1',
#   'SRP54',
#   'FAM83G',
#   'NPL',
#   'CAND1',
#   'OAS3',
#   'AQP5',
#   'GNE',
#   'MISP',
#   'CCDC86',
#   'TOMM22',
#   'GPX1',
#   'KIFC1',
#   'SNTB2',
#   'DDX49',
#   'SIRT1',
#   'FBXO4',
#   'ESR1',
#   'VIM',
#   'BCKDK',
#   'FGR',
#   'PITPNC1',
#   'ZNF592',
#   'SYNCRIP',
#   'NSUN2',
#   'RIOK1',
#   'UBR1',
#   'GIMAP1',
#   'COPRS',
#   'NTN4',
#   'RELB',
#   'RTN4IP1',
#   'SECISBP2L',
#   'MLKL',
#   'THADA',
#   'ZYG11B',
#   'FOLH1',
#   'NFAT5',
#   'TBXAS1',
#   'SOX6',
#   'GCNT1',
#   'ASF1B',
#   'SLC44A4',
#   'HSD17B12',
#   'S100A14',
#   'GTF2E2',
#   'MGLL',
#   'STOX2',
#   'PDE12',
#   'STARD7',
#   'CHD4',
#   'PCGF5',
#   'TARS2',
#   'CPPED1',
#   'NCF2',
#   'GET4',
#   'GTF3C4',
#   'CTNNAL1',
#   'EHMT2',
#   'SS18L1',
#   'EZH1',
#   'CPOX',
#   'PROM2',
#   'NAALADL2',
#   'KLC3',
#   'OSBPL3',
#   'ZNFX1',
#   'STEAP1',
#   'SSU72',
#   'CHTF18',
#   'STK4',
#   'ROBO2',
#   'FAM110C',
#   'SERPINA6',
#   'CYBB',
#   'IL1R1',
#   'FAM120B',
#   'PYCARD',
#   'SLC27A1',
#   'TTC28',
#   'NUDC',
#   'MDM1',
#   'RP9',
#   'PRR15',
#   'S100A12',
#   'BIN2',
#   'HOXD9',
#   'FASTKD5',
#   'MAP3K2',
#   'CCDC137',
#   'CAMSAP2',
#   'LRP4',
#   'CAPN1',
#   'GIMAP4',
#   'CAMSAP3',
#   'ALPL',
#   'KIF4A',
#   'AKR7A2',
#   'ACOT11',
#   'SPTLC3',
#   'APOBEC3F',
#   'VPS4A',
#   'FGD3',
#   'HSPA13',
#   'SGTA',
#   'TSEN15',
#   'SHB',
#   'RMDN3',
#   'GOLIM4',
#   'MAP1LC3A',
#   'TRAF3IP1',
#   'RCBTB2',
#   'PLD2',
#   'NIT1',
#   'GSDMD',
#   'GPX4',
#   'APLF',
#   'UAP1',
#   'SH3RF1',
#   'HIGD1A',
#   'ODF3B',
#   'CCL20',
#   'ECH1',
#   'ABI3BP',
#   'MTIF3',
#   'TAGAP',
#   'C19orf33',
#   'ACTR1A',
#   'PSTPIP2',
#   'KCNN4',
#   'SCAMP3',
#   'SCO2',
#   'APOBEC3B',
#   'RGS19',
#   'HOMER1',
#   'RSRC1',
#   'NR2F2',
#   'GBF1',
#   'HP',
#   'YY1AP1',
#   'CCNE1',
#   'LRRK2',
#   'ZNF587',
#   'NAA38',
#   'LMO7',
#   'HS6ST1',
#   'ARF1',
#   'KDM3B',
#   'HEATR6',
#   'PDSS2',
#   'DNAJA3',
#   'SNX13',
#   'CARD6',
#   'MRPS18B',
#   'CHMP1A',
#   'SAA1',
#   'KIF15',
#   'SEC23IP',
#   'COQ9',
#   'PYGB',
#   'RNF170',
#   'DCP1A',
#   'OTUD4',
#   'ACAD8',
#   'TDRKH',
#   'TMCO4',
#   'TMEM165',
#   'TBC1D22B',
#   'RPL18',
#   'PDE8A',
#   'AP1AR',
#   'UBE2E3',
#   'AAGAB',
#   'RPRD2',
#   'RNASEL',
#   'RANBP1',
#   'STC2',
#   'TEC',
#   'CCDC8',
#   'RAB19',
#   'UQCRC1',
#   'TFF3',
#   'EIF4EBP1',
#   'FTO',
#   'TRMT6',
#   'SIK3',
#   'PARP14',
#   'HOMER2',
#   'ANP32B',
#   'HMGN5',
#   'SFXN5',
#   'FDFT1',
#   'EPS8L3',
#   'RNF181',
#   'CD300A',
#   'PPP3CC',
#   'ARHGEF5',
#   'ERAP1',
#   'PMM1',
#   'SCAMP4',
#   'AJUBA',
#   'CAPN13',
#   'ZC3H4',
#   'TRAPPC1',
#   'MSX1',
#   'CYB561',
#   'BMP2K',
#   'LMAN2L',
#   'NARF',
#   'SERF2',
#   'AGPAT3',
#   'KRT13',
#   'PPP1R3D',
#   'EFNB1',
#   'KLK10',
#   'IVNS1ABP',
#   'ACSF3',
#   'FGFR2',
#   'CCT2',
#   'NUF2',
#   'NID1',
#   'CNNM3',
#   'WDR26',
#   'DNAL1',
#   'CCDC78',
#   'GPRIN3',
#   'RNF113A',
#   'IMPDH2',
#   'TRAPPC5',
#   'TBC1D2',
#   'FBXL15',
#   'FAM177A1',
#   'DYNC1LI1',
#   'CBX2',
#   'BCAR3',
#   'TCEA2',
#   'WTIP',
#   'MINPP1',
#   'GEMIN2',
#   'SRA1',
#   'HTT',
#   'MGME1',
#   'PRAME',
#   'APBA2',
#   'SAAL1',
#   'RIC8B',
#   'PRKAB1',
#   'MCM5',
#   'FBLN5',
#   'ATAD2B',
#   'CCP110',
#   'DR1',
#   'SZRD1',
#   'MAD2L2',
#   'GPATCH11',
#   'PLXNB1',
#   'IGLL1',
#   'PFKL',
#   'ALG13',
#   'GIMAP8',
#   'AGPAT1',
#   'FANCD2',
#   'HMGCS1',
#   'SDHA',
#   'STRA6',
#   'SNX2',
#   'RNF13',
#   'GLUD2',
#   'GNAQ',
#   'PRRC2C',
#   'PRSS23',
#   'TP53I11',
#   'PTPN9',
#   'RPA1',
#   'PRR36',
#   'MCCC1',
#   'CLPB',
#   'GORASP1',
#   'NAT14',
#   'CHD7',
#   'PECR',
#   'CNOT3',
#   'LARP4',
#   'EPC1',
#   'IRAK1',
#   'PAFAH1B3',
#   'RAB27B',
#   'SLC16A3',
#   'SWAP70',
#   'DTNB',
#   'AOC1',
#   'ARL8A',
#   'VAV1',
#   'NLRP2',
#   'CLU',
#   'IFT74',
#   'SCGB2A1',
#   'TATDN3',
#   'EIF4H',
#   'ENPP3',
#   'NUP37',
#   'CD55',
#   'IDNK',
#   'RPS8',
#   'RSPH4A',
#   'PLEKHA2',
#   'TBC1D30',
#   'GPT2',
#   'FAM172A',
#   'S100P',
#   'ZC3H18',
#   'CRYL1',
#   'TSC22D4',
#   'THOC5',
#   'NEK6',
#   'PAMR1',
#   'FOLR1',
#   'PPP4R1',
#   'WASL',
#   'HYKK',
#   'EXOC6B',
#   'DBI',
#   'LAMTOR2',
#   'TTC39B',
#   'ZNF639',
#   'POLDIP2',
#   'IDI1',
#   'CDC40',
#   'PPP6R3',
#   'C12orf29',
#   'STARD10',
#   'LACTB2',
#   'CFAP36',
#   'XAF1',
#   'PDSS1',
#   'C3',
#   'ATXN2L',
#   'WDR60',
#   'MT1G',
#   'CNP',
#   'IDO1',
#   'DCTD',
#   'FNDC3A',
#   'CDV3',
#   'TRAP1',
#   'NUDT8',
#   'DNAJB13',
#   'EIF6',
#   'UBR7',
#   'TET3',
#   'GEMIN5',
#   'EFS',
#   'MCRS1',
#   'EEFSEC',
#   'MTHFD1L',
#   'UFL1',
#   'RPS6KB2',
#   'CTHRC1',
#   'ARFGAP3',
#   'NNMT',
#   'PLD3',
#   'ANGPT2',
#   'ITGB8',
#   'CD40',
#   'CLDN10',
#   'RPL32',
#   'ANKRD35',
#   'ZMIZ1',
#   'USP34',
#   'ITIH1',
#   'PCSK9',
#   'EXOSC2',
#   'TNFAIP2',
#   'ASAP3',
#   'CEACAM1',
#   'SLC25A35',
#   'KDM5B',
#   'ZMYM3',
#   'TPBG',
#   'HMMR',
#   'HLA-B',
#   'ZNF853',
#   'MST1R',
#   'CARD9',
#   'CXCL1',
#   'CLPP',
#   'NAPG',
#   'BLNK',
#   'IL1RN',
#   'NAAA',
#   'MYO10',
#   'TFAP4',
#   'SPC25',
#   'CHAF1B',
#   'NBEAL1',
#   'NRP1',
#   'MRPL37',
#   'S100A8',
#   'TXNDC12',
#   'ADD2',
#   'HELLS',
#   'GLRX5',
#   'GPHN',
#   'KIF2C',
#   'ACTR1B',
#   'PRKCI',
#   'DZIP3',
#   'MT1F',
#   'ABCC4',
#   'SCEL',
#   'CBLB',
#   'TAP2',
#   'CENPF',
#   'SNTB1',
#   'RAPGEF1',
#   'ATP6V1F',
#   'EPHA4',
#   'DHX36',
#   'MEGF8',
#   'EBAG9',
#   'APOBEC3C',
#   'FBXO11',
#   'SPRYD7',
#   'RPP25',
#   'CKMT2',
#   'COA4',
#   'MECR',
#   'RHBDD3',
#   'ECI2',
#   'BCL3',
#   'CEP78',
#   'SOWAHB',
#   'CARS2',
#   'MAP2K4',
#   'ANLN',
#   'XIAP',
#   'RNPEP',
#   'PRIM1',
#   'CNOT7',
#   'AKAP7',
#   'TPX2',
#   'SMARCAL1',
#   'APOE',
#   'PLOD2',
#   'TRIM22',
#   'TOR1B',
#   'ARFIP2',
#   'RPAP1',
#   'PLEK2',
#   'CASP9',
#   'CUL1',
#   'GATAD2B',
#   'SAMD12',
#   'KLHL14',
#   'SLC47A1',
#   'USP16',
#   'TAGLN2',
#   'C1RL',
#   'TUT1',
#   'SRPK2',
#   'DENND4A',
#   'TMEM159',
#   'FOXA2',
#   'FARP2',
#   'OSBP',
#   'PYCR1',
#   'PRPSAP1',
#   'ASNS',
#   'ALMS1',
#   'RASAL1',
#   'PPP6R1',
#   'CHAC2',
#   'HLA-DMA',
#   'NCAPH',
#   'PSME2',
#   'C6orf132',
#   'NPDC1',
#   'AZGP1',
#   'S100A9',
#   'SACS',
#   'UBE3C',
#   'ACOT8',
#   'CCNA2',
#   'TTC38',
#   'TYMS',
#   'NMT1',
#   'TOR3A',
#   'ZC3H7A',
#   'SDK1',
#   'NXT2',
#   'LMBRD2',
#   'STK3',
#   'AURKB',
#   'RPL19',
#   'MCMBP',
#   'GRAMD1A',
#   'CTH',
#   'ECD',
#   'NMD3',
#   'BCAT2',
#   'SLC1A5',
#   'HK2',
#   'DHCR24',
#   'FILIP1L',
#   'CRISP3',
#   'ACADS',
#   'CCNB1',
#   'B9D2',
#   'MSX2',
#   'BLOC1S2',
#   'FRMD4A',
#   'KLHL29',
#   'FAM204A',
#   'ITGB6',
#   'PTPRG',
#   'SERPINA1',
#   'LYRM1',
#   'MTHFD2',
#   'VPS37B',
#   'WDHD1',
#   'XYLT2',
#   'FZD6',
#   'HAPLN1',
#   'KLHL7',
#   'PACS1',
#   'SARDH',
#   'RRAGC',
#   'SHMT1',
#   'FAM120C',
#   'TRIP13',
#   'MMP7',
#   'GRB14',
#   'ORM2',
#   'DEFB1',
#   'GMNN',
#   'KRT4',
#   'XPNPEP3',
#   'RPL13',
#   'SERPINA5',
#   'ATXN10',
#   'MRPL57',
#   'HADHB',
#   'GK',
#   'PGK1',
#   'PATL1',
#   'PBK',
#   'SCYL3',
#   'RFK',
#   'ATAD2',
#   'UCK2',
#   'PIK3CD',
#   'VNN1',
#   'TXNRD2',
#   'TLR2',
#   'OAT',
#   'MEF2C',
#   'NAPRT',
#   'RNF141',
#   'FAM92B',
#   'CEP131',
#   'KRT80',
#   'FOXA1',
#   'SLC27A2',
#   'SETD3',
#   'TALDO1',
#   'TESC',
#   'TSPAN1',
#   'CTSL',
#   'ZNF219',
#   'NFATC2',
#   'MMS19',
#   'XDH',
#   'NFKB1',
#   'PRODH',
#   'DCDC2',
#   'CERS6',
#   'ANKLE2',
#   'CHEK1',
#   'RAP1GAP2',
#   'TBC1D5',
#   'CD151',
#   'RUFY2',
#   'MSTO1',
#   'C1QTNF7',
#   'C15orf39',
#   'ECT2',
#   'GCLM',
#   'HELZ2',
#   'GFM1',
#   'HAUS4',
#   'OSBPL2',
#   'ARMC4',
#   'RAB11FIP3',
#   'TNFAIP8L2',
#   'ERCC6L',
#   'GSPT2',
#   'GPALPP1',
#   'KRT17',
#   'CLIC3',
#   'EIF2S2',
#   'QKI',
#   'GNB1L',
#   'DUSP23',
#   'GDF15',
#   'FAM83B',
#   'FLRT3',
#   'FANCI',
#   'PEX2',
#   'PTS',
#   'REEP6',
#   'MSI1',
#   'ACBD7',
#   'TACC3',
#   'MYOC',
#   'SLC3A2',
#   'HK3',
#   'GATA2',
#   'DCUN1D1',
#   'NCAPD3',
#   'EGLN1',
#   'GPR39',
#   'BBS4',
#   'SLC7A5',
#   'UXS1',
#   'CDK1',
#   'MBNL2',
#   'WIPI1',
#   'VPS37A',
#   'CUL2',
#   'KLHL25',
#   'UBA6',
#   'EPHA7',
#   'UBE2E2',
#   'ACAA2',
#   'C9orf64',
#   'GDAP2',
#   'GAPVD1',
#   'GPCPD1',
#   'CP',
#   'KIF11',
#   'AS3MT',
#   'PLAU',
#   'SDS',
#   'RRAD',
#   'TSTD2',
#   'RNF2',
#   'PYGO1',
#   'SLC16A1',
#   'LRG1',
#   'HLA-DPB1',
#   'FAM3D',
#   'CHMP7',
#   'UHRF1BP1L',
#   'MAD2L1',
#   'ZWINT',
#   'CAD',
#   'HERC4',
#   'CFI',
#   'MTM1',
#   'LIN54',
#   'LIMK2',
#   'ZNF281',
#   'C1orf116',
#   'SRD5A3',
#   'ZFP3',
#   'ABHD6',
#   'ZNF318',
#   'C15orf48',
#   'CDKN2A',
#   'S100A13',
#   'TFRC',
#   'XYLB',
#   'NDP',
#   'IFT43',
#   'GOT1'],
#  'hnscc': ['IGFBP3',
#   'MIEF1',
#   'IDO1',
#   'MELK',
#   'CRBN',
#   'PSMG3',
#   'TRMT10C',
#   'NPEPL1',
#   'CENPF',
#   'RBKS',
#   'TMEM223',
#   'HTATSF1',
#   'IFFO2',
#   'APEH',
#   'CLPB',
#   'ST13',
#   'TRAP1',
#   'HMGA2',
#   'COL28A1',
#   'MASTL',
#   'PPME1',
#   'POMP',
#   'KCTD18',
#   'LRRC8E',
#   'KCNK1',
#   'RNF115',
#   'PLAT',
#   'DHX58',
#   'NDUFV2',
#   'PELO',
#   'KAT7',
#   'FARS2',
#   'PRPSAP2',
#   'GATAD1',
#   'HPDL',
#   'CHD8',
#   'PGK1',
#   'RCN2',
#   'PCSK5',
#   'GNB5',
#   'MUCL1',
#   'RAB7A',
#   'SLC25A15',
#   'UBE2F',
#   'SSBP1',
#   'PLAA',
#   'MTAP',
#   'ATG2B',
#   'ZNF282',
#   'CXCL10',
#   'KRT4',
#   'UBE4A',
#   'GCFC2',
#   'SLC7A8',
#   'PARP16',
#   'PCP4',
#   'FAM133B',
#   'RPIA',
#   'HTT',
#   'UBA1',
#   'ITGB6',
#   'UBE2T',
#   'MRRF',
#   'EPHB4',
#   'NCS1',
#   'DNMT3A',
#   'TMEM143',
#   'CAMKMT',
#   'PAFAH1B1',
#   'DNAJC11',
#   'EGFL7',
#   'PDHA1',
#   'BRAF',
#   'KCTD21',
#   'REPIN1',
#   'WDR77',
#   'SMIM12',
#   'EIF2B3',
#   'NCEH1',
#   'C2CD2L',
#   'ALPK1',
#   'THTPA',
#   'URB1',
#   'HMBS',
#   'RARRES2',
#   'ACADL',
#   'KHDC1L',
#   'TBL1X',
#   'LAMC2',
#   'SCGB3A2',
#   'DDX19A',
#   'ZWINT',
#   'ALKBH4',
#   'TARBP1',
#   'MAP2K3',
#   'NTHL1',
#   'RSBN1L',
#   'DDHD2',
#   'MED9',
#   'TP53BP2',
#   'NUDT22',
#   'RFK',
#   'FKBP14',
#   'PMPCA',
#   'KIAA1191',
#   'DCAF10',
#   'ERAL1',
#   'YWHAE',
#   'SLC25A17',
#   'IARS2',
#   'PDCD2',
#   'FBXL6',
#   'NGLY1',
#   'MYH15',
#   'TMEM177',
#   'MAGEA4',
#   'ISCA2',
#   'KLK5',
#   'GGT5',
#   'CLUAP1',
#   'IPO7',
#   'ENPP6',
#   'FAM168A',
#   'MMAA',
#   'GRHPR',
#   'MT-ND4',
#   'APLP2',
#   'TFB1M',
#   'KIFC1',
#   'ATAD3A',
#   'MTM1',
#   'EPM2AIP1',
#   'LANCL2',
#   'DCAF16',
#   'MMP13',
#   'CCNA2',
#   'METTL25',
#   'VAMP3',
#   'DDX31',
#   'NAP1L4',
#   'NUDT15',
#   'BPGM',
#   'HEATR5A',
#   'MAGEA3',
#   'ARHGEF26',
#   'INPP5K',
#   'SLC2A1',
#   'RIC8A',
#   'THBD',
#   'LRPPRC',
#   'UBE3C',
#   'THOP1',
#   'FAM117A',
#   'WDR37',
#   'PCDH7',
#   'UBE2O',
#   'CTSE',
#   'COA4',
#   'MCTS1',
#   'CMC1',
#   'ISG15',
#   'PAIP1',
#   'GEMIN5',
#   'CEACAM6',
#   'MTX1',
#   'RTP4',
#   'XPNPEP3',
#   'VCP',
#   'FAT1',
#   'PDGFC',
#   'RANBP6',
#   'AASDHPPT',
#   'ACAD9',
#   'DGKH',
#   'TFAM',
#   'SCO1',
#   'HSD17B2',
#   'MCTS2P',
#   'FLRT3',
#   'PADI3',
#   'CYP27C1',
#   'RFX3',
#   'CDKN2A',
#   'OXLD1',
#   'SOX13',
#   'WDR90',
#   'PARL',
#   'NCAPG2',
#   'PHB2',
#   'HTRA2',
#   'GPCPD1',
#   'PCM1',
#   'BIRC2',
#   'PLEKHG4',
#   'QSER1',
#   'SMAD4',
#   'GNG12',
#   'UBE2N',
#   'PXMP2',
#   'TBRG4',
#   'SIAE',
#   'PDE6D',
#   'PRR16',
#   'ASB6',
#   'GBP5',
#   'MFSD3',
#   'AIM2',
#   'RNLS',
#   'NUAK2',
#   'PBX1',
#   'USP18',
#   'BCS1L',
#   'CENPL',
#   'PCTP',
#   'WDR1',
#   'STK25',
#   'CCNB2',
#   'HINT1',
#   'DPH5',
#   'MYO10',
#   'ESCO1',
#   'CCDC127',
#   'SCAF8',
#   'PRC1',
#   'LSM1',
#   'OLA1',
#   'FLAD1',
#   'IGF2BP1',
#   'CDKN2B',
#   'PRKAR2A',
#   'MAGEB2',
#   'NACC2',
#   'LYZ',
#   'IRGQ',
#   'TIMM50',
#   'C14orf119',
#   'DARS2',
#   'CCDC58',
#   'TATDN1',
#   'SBK2',
#   'TIPIN',
#   'OPA1',
#   'PRDM11',
#   'DLGAP5',
#   'STOML2',
#   'RNF114',
#   'ALKBH2',
#   'HARS2',
#   'SUGP2',
#   'FADD',
#   'TOMM22',
#   'TBC1D9'],
#  'lscc': ['WDR45B',
#   'NRIP1',
#   'CHPF',
#   'GYG1',
#   'RAD51AP1',
#   'LNX1',
#   'QRSL1',
#   'A2ML1',
#   'XXYLT1',
#   'UROD',
#   'CDH2',
#   'PITPNC1',
#   'DUSP22',
#   'STX17',
#   'STRA6',
#   'FREM2',
#   'NCBP1',
#   'TRMT1',
#   'NFATC1',
#   'MT1F',
#   'SPRR2G',
#   'LY6D',
#   'RAD51C',
#   'AGK',
#   'HDAC4',
#   'LRRN4CL',
#   'TLK2',
#   'DNAJA1',
#   'ZBTB7C',
#   'SPRR1A',
#   'PLEKHG3',
#   'CALML3',
#   'DUSP9',
#   'DERL2',
#   'DNAJC21',
#   'TTF1',
#   'ZDHHC17',
#   'ARL1',
#   'PPM1L',
#   'VPS4B',
#   'ATPAF1',
#   'UBP1',
#   'TGS1',
#   'FAM210B',
#   'GNE',
#   'CENPU',
#   'IRF2BPL',
#   'MIEN1',
#   'DPY19L1',
#   'CTSV',
#   'AKR1B10',
#   'XPO5',
#   'UBE3C',
#   'SSBP1',
#   'UBLCP1',
#   'HAS3',
#   'RBBP5',
#   'SPRTN',
#   'ZHX2',
#   'TACO1',
#   'CENPJ',
#   'RAB15',
#   'DMKN',
#   'MIS18A',
#   'PIGM',
#   'DLST',
#   'SEC16B',
#   'CEACAM7',
#   'ANXA8',
#   'P4HA3',
#   'SERPINB9',
#   'KRT75',
#   'WBP4',
#   'USP5',
#   'FAM83C',
#   'TRMT1L',
#   'MTA3',
#   'KHSRP',
#   'TRMT5',
#   'MAD2L1',
#   'SNX19',
#   'AKAP8',
#   'TFAP2A',
#   'EIF2B1',
#   'MSN',
#   'ACSS1',
#   'PIN1',
#   'FH',
#   'DHRS7B',
#   'ASF1A',
#   'DPH5',
#   'SUV39H2',
#   'KIF11',
#   'IL36A',
#   'ATP7A',
#   'NLRX1',
#   'ISCA1',
#   'KIFC1',
#   'FURIN',
#   'EIF4A3',
#   'RTN4IP1',
#   'PLEKHG4B',
#   'GUF1',
#   'MLLT11',
#   'KDM1B',
#   'IDE',
#   'LYSMD1',
#   'TPI1',
#   'ABHD4',
#   'PTK6',
#   'PYCR1',
#   'LMAN2L',
#   'TIMM50',
#   'CLTB',
#   'DUSP12',
#   'IL36RN',
#   'PPAT',
#   'DICER1',
#   'UBIAD1',
#   'RIC8A',
#   'CPTP',
#   'SOX15',
#   'TOR3A',
#   'GINS3',
#   'SPRR2F',
#   'MAST4',
#   'SLC5A3',
#   'GYS1',
#   'GSDMC',
#   'GINS2',
#   'DCLRE1A',
#   'TPD52L1',
#   'ZFP36L2',
#   'COASY',
#   'PPP1R2',
#   'FGFBP1',
#   'PNMA5',
#   'OSBP',
#   'SEMA3C',
#   'MCAT',
#   'ANXA2',
#   'NOS1AP',
#   'DDX31',
#   'TES',
#   'RHBDL2',
#   'RAE1',
#   'SRSF7',
#   'UCHL5',
#   'ABCF1',
#   'SERPINI1',
#   'SLC6A4',
#   'UPRT',
#   'SETD3',
#   'C5orf22',
#   'B4GALT4',
#   'SMG7',
#   'RIOK1',
#   'TFAP2C',
#   'JRK',
#   'GSS',
#   'PAQR7',
#   'ETNK2',
#   'BEND5',
#   'PRMT5',
#   'PHC2',
#   'ARF4',
#   'CACYBP',
#   'GAPVD1',
#   'CIT',
#   'NPTXR',
#   'KPNA1',
#   'UBAP2',
#   'BICD2',
#   'SPC24',
#   'MCU',
#   'TRA2B',
#   'DDI2',
#   'MTPAP',
#   'RAB3GAP2',
#   'CARM1',
#   'UPF1',
#   'CELSR2',
#   'APEH',
#   'ZMYM2',
#   'TUBB6',
#   'RAB43',
#   'POLA1',
#   'SYTL5',
#   'LIG3',
#   'BCL11A',
#   'TXNDC11',
#   'NKRF',
#   'TOE1',
#   'DDX52',
#   'MASTL',
#   'CELF2',
#   'XPA',
#   'RPRD1A',
#   'CLCA2',
#   'NCOR1',
#   'SEPSECS',
#   'GGT7',
#   'CERS3',
#   'RPTN',
#   'CCDC127',
#   'SEMA4B',
#   'ANAPC1',
#   'MAGEA6',
#   'INPP1',
#   'PELP1',
#   'KIF4A',
#   'MEX3A',
#   'YY1',
#   'CSNK1G1',
#   'CALB1',
#   'CBX2',
#   'IARS2',
#   'RRP12',
#   'DDX18',
#   'WIPI2',
#   'DUSP14',
#   'SERPINB3',
#   'CROT',
#   'EIF3J',
#   'CEP170B',
#   'TMPRSS4',
#   'CDV3',
#   'CAB39',
#   'FAM20A',
#   'UBA6',
#   'NOL11',
#   'SGTA',
#   'CDCA3',
#   'SPAG5',
#   'TSC22D2',
#   'EIF2S1',
#   'ANKRD17',
#   'ATG4D',
#   'STAU2',
#   'PPP2R2A',
#   'KRTCAP3',
#   'KDM3A',
#   'AHCY',
#   'MMP13',
#   'RBKS',
#   'CDC37L1',
#   'CXCL6',
#   'TBL1X',
#   'PAQR4',
#   'UNG',
#   'PTGES',
#   'ZNF318',
#   'NUDT5',
#   'WDHD1',
#   'JAK1',
#   'UMPS',
#   'PAX9',
#   'STIP1',
#   'ZDHHC13',
#   'NOLC1',
#   'SIPA1L3',
#   'RAB18',
#   'TP63',
#   'SUGP1',
#   'TSTA3',
#   'USP18',
#   'IL1RN',
#   'ABCB6',
#   'HIF1AN',
#   'CASP4',
#   'TMEM45A',
#   'PSAT1',
#   'HDGF',
#   'PTRH2',
#   'GEMIN2',
#   'PBK',
#   'USP7',
#   'ABCF3',
#   'UBE3A',
#   'ZC3H7A',
#   'FAM50B',
#   'JAG2',
#   'STAMBP',
#   'FERMT1',
#   'RBBP8',
#   'ACVR2A',
#   'ZFP37',
#   'BEND3',
#   'SDC4',
#   'SAAL1',
#   'ORC5',
#   'GRHL1',
#   'E2F6',
#   'RAD54B',
#   'PLK1',
#   'STX5',
#   'RNF39',
#   'EPHA7',
#   'SLC27A4',
#   'LAMB3',
#   'TSR1',
#   'UPK1B',
#   'RTN4R',
#   'LSG1',
#   'SLC40A1',
#   'UBE4B',
#   'C11orf58',
#   'OTUD4',
#   'MTCL1',
#   'LAT2',
#   'FXN',
#   'NDUFAF7',
#   'AMMECR1',
#   'CABYR',
#   'FBN2',
#   'UBQLN4',
#   'TAGAP',
#   'STAT3',
#   'RNF168',
#   'WNK2',
#   'DPYSL5',
#   'UBAC2',
#   'BAZ1B',
#   'CES2',
#   'TTC14',
#   'TEFM',
#   'MSH2',
#   'PRMT3',
#   'CREB5',
#   'EIF5B',
#   'IVL',
#   'BRF2',
#   'CPOX',
#   'ECI1',
#   'SLC25A12',
#   'SKA1',
#   'TRMT10C',
#   'ZC3H15',
#   'USP39',
#   'MAPKBP1',
#   'MST1R',
#   'DNAJA3',
#   'RGMA',
#   'SLC1A5',
#   'NEMF',
#   'PTK7',
#   'GOT2',
#   'NDUFAF4',
#   'SERPINB5',
#   'C11orf96',
#   'GSPT2',
#   'ETFB',
#   'LAMA1',
#   'STAU1',
#   'GSPT1',
#   'P2RY2',
#   'FMO4',
#   'CHAF1A',
#   'DHX57',
#   'MT1E',
#   'FZD7',
#   'NSFL1C',
#   'SIX4',
#   'PXYLP1',
#   'AR',
#   'SYNCRIP',
#   'WDR62',
#   'ITGA5',
#   'CLIP1',
#   'KLHL9',
#   'SLC7A11',
#   'GSTZ1',
#   'ABCC1',
#   'BLVRA',
#   'STK17B',
#   'EYA2',
#   'SEC63',
#   'WDR43',
#   'DCUN1D1',
#   'KLHL29',
#   'CDK12',
#   'POLR2H',
#   'CAPN1',
#   'CCNT1',
#   'DCTPP1',
#   'KRT6C',
#   'POU2F1',
#   'KIF14',
#   'CERS4',
#   'KRT8',
#   'TFAP4',
#   'ZNF217',
#   'NIF3L1',
#   'ALKBH4',
#   'RBMXL1',
#   'TRIP6',
#   'OSGEPL1',
#   'IMPACT',
#   'LSR',
#   'CPEB4',
#   'CRKL',
#   'CDCP1',
#   'TXNL1',
#   'MDN1',
#   'DPYD',
#   'HDAC9',
#   'KIF2C',
#   'ADAM23',
#   'C17orf75',
#   'SUZ12',
#   'TRMT6',
#   'SOX6',
#   'FBXL19',
#   'MGA',
#   'RPUSD2',
#   'TFB1M',
#   'NR2C2AP',
#   'CAD',
#   'SMIM4',
#   'ATXN1',
#   'TIPIN',
#   'GRHL3',
#   'GOT1',
#   'TIMM44',
#   'SLC29A1',
#   'EHF',
#   'FAM83B',
#   'YKT6',
#   'PPFIA3',
#   'HNRNPF',
#   'FBXO4',
#   'AVL9',
#   'MRRF',
#   'CUL2',
#   'CLSPN',
#   'KLF4',
#   'PKP1',
#   'GSTA4',
#   'FADS1',
#   'DHRS11',
#   'NAA15',
#   'ARHGEF19',
#   'MTERF3',
#   'WDR44',
#   'ARID2',
#   'CHMP1B',
#   'LRIG3',
#   'SMC4',
#   'LY75',
#   'BCAR3',
#   'DHRS13',
#   'GNAI2',
#   'ACTL6A',
#   'CRCT1',
#   'XPO7',
#   'ITGB6',
#   'RELA',
#   'USP14',
#   'SPINK5',
#   'ETF1',
#   'ARMCX3',
#   'ZNFX1',
#   'PSMD10',
#   'ESCO2',
#   'CLNS1A',
#   'BZW1',
#   'S100A14',
#   'C4orf19',
#   'TFDP1',
#   'KLHDC7A',
#   'COIL',
#   'ABCE1',
#   'CPS1',
#   'TPP2',
#   'F2RL1',
#   'FAM83G',
#   'TNS4',
#   'FAT2',
#   'MTFR1',
#   'DHX35',
#   'DSG3',
#   'MPV17L',
#   'GLUD1',
#   'TOPBP1',
#   'SRXN1',
#   'DNM1L',
#   'ZNF658',
#   'SYT7',
#   'HGH1',
#   'CDC45',
#   'ATP2B1',
#   'GALNT14',
#   'FRRS1',
#   'PCP4',
#   'SDC1',
#   'KRT16',
#   'AHSA1',
#   'FLOT2',
#   'UBE2R2',
#   'SEC24B',
#   'PSPH',
#   'NSRP1',
#   'PAPOLG',
#   'KRT13',
#   'HSPA9',
#   'PPME1',
#   'CCDC58',
#   'DUOX2',
#   'COL19A1',
#   'KRT15',
#   'EPS8L1',
#   'TRAP1',
#   'MAPRE1',
#   'WBP11',
#   'COL17A1',
#   'L2HGDH',
#   'HAGHL',
#   'LANCL2',
#   'MUC20',
#   'XPNPEP3',
#   'IL36G',
#   'GCSH',
#   'PRIM1',
#   'SLC4A1AP',
#   'RAD18',
#   'EZR',
#   'PPP1R3D',
#   'PGK1',
#   'PIAS2',
#   'MAT1A',
#   'METTL8',
#   'CHD8',
#   'BCL2L14',
#   'HNRNPM',
#   'ARHGEF16',
#   'RNMT',
#   'SUPV3L1',
#   'USP16',
#   'LRP10',
#   'STX4',
#   'ANKZF1',
#   'UGT8',
#   'CEBPZ',
#   'BRCA1',
#   'CTSO',
#   'HSP90AA1',
#   'CHEK2',
#   'EMD',
#   'XPR1',
#   'AP1G1',
#   'LGI2',
#   'CENPF',
#   'PRNP',
#   'SUPT6H',
#   'TIMELESS',
#   'BTBD11',
#   'ZFAND2B',
#   'ARMC9',
#   'ERCC6L',
#   'MTOR',
#   'FASTKD5',
#   'BCAR1',
#   'RIOK3',
#   'EPHA2',
#   'GFPT1',
#   'ADM',
#   'OPA1',
#   'CDC42EP4',
#   'SCFD1',
#   'UBA2',
#   'MMP11',
#   'CA12',
#   'KPNB1',
#   'BOLA1',
#   'FAM83F',
#   'FIGNL1',
#   'DTYMK',
#   'XPOT',
#   'ECT2',
#   'ACAP2',
#   'LRRC8D',
#   'HPDL',
#   'TRIP11',
#   'TDRKH',
#   'URGCP',
#   'BAG4',
#   'YWHAG',
#   'ABCC5',
#   'PKP2',
#   'AMACR',
#   'STRAP',
#   'GNL1',
#   'UBE2G1',
#   'SLC2A1',
#   'STOML2',
#   'KRT23',
#   'PANK2',
#   'CDKAL1',
#   'MEGF10',
#   'MAP7D2',
#   'TNK1',
#   'PTHLH',
#   'CHD6',
#   'PDE12',
#   'NSUN5',
#   'FOXC1',
#   'UGT1A10',
#   'CNNM2',
#   'AFG3L2',
#   'KIF20A',
#   'DSC2',
#   'TPRG1',
#   'NUDT8',
#   'SBNO1',
#   'HOMEZ',
#   'UBAC1',
#   'PROM2',
#   'SCYL3',
#   'LIAS',
#   'ICAM1',
#   'SBSN',
#   'MCM10',
#   'SMOX',
#   'PGAM5',
#   'SRSF4',
#   'CNP',
#   'NAA25',
#   'TLE4',
#   'KIF1A',
#   'PDLIM1',
#   'DKK1',
#   'FOXE1',
#   'PITX1',
#   'EPHA1',
#   'CA9',
#   'SMC2',
#   'DSC3',
#   'KRT6A',
#   'IPO7',
#   'IDH3A',
#   'GCLC',
#   'SEPHS1',
#   'VTCN1',
#   'COL11A1',
#   'PRPSAP2',
#   'NSUN2',
#   'ZNF205',
#   'KRT5',
#   'TARS2',
#   'ERLIN1',
#   'NFKBIB',
#   'AKAP11',
#   'KHK',
#   'NXPH4',
#   'C1QBP',
#   'MMP3',
#   'EIF4EBP1',
#   'PLD1',
#   'DNAJA2',
#   'TNFRSF1A',
#   'BLMH',
#   'SLC25A33',
#   'LCMT1',
#   'DENND4A',
#   'EDARADD',
#   'STC2',
#   'UGT1A7',
#   'IGFL1',
#   'NTS',
#   'ZNF280C',
#   'PNPT1',
#   'KCTD1',
#   'PA2G4',
#   'GMPS',
#   'MYO3B',
#   'RAB3B',
#   'FADD',
#   'GOLPH3',
#   'NOL10',
#   'IGFBP2',
#   'SERPINB13',
#   'MT2A',
#   'UBE2M',
#   'BBOX1',
#   'SAGE1',
#   'FANCD2',
#   'UBR1',
#   'TMEM41A',
#   'ZPR1',
#   'MAP7D1',
#   'POMK',
#   'PAFAH1B3',
#   'C6orf15',
#   'KIF18B',
#   'IGF2BP3',
#   'MPPED2',
#   'BUB1',
#   'PPP4R1',
#   'POMC',
#   'SLC25A14',
#   'METAP1',
#   'CT45A10',
#   'SPRR2D',
#   'DBNDD1',
#   'MSI1',
#   'VDAC2',
#   'SRSF12',
#   'PDCD2',
#   'COG3',
#   'SOX2',
#   'DAPL1',
#   'KIF22',
#   'EIF5',
#   'SCAF4',
#   'GFM1',
#   'MUC13',
#   'KRT17',
#   'SKP2',
#   'YWHAZ',
#   'PODXL2',
#   'NCAPD3',
#   'RFC5',
#   'PRAME',
#   'INCENP',
#   'ADM2',
#   'CKAP2L',
#   'MELK',
#   'PDCD2L',
#   'SPRR1B',
#   'S100A7',
#   'CARD6',
#   'TMPRSS11E',
#   'OVOL2',
#   'S100A2',
#   'CAPNS2',
#   'NFX1',
#   'TRIP13',
#   'DDX55',
#   'PRC1',
#   'KRT14',
#   'MMS22L',
#   'DHX36',
#   'TMPRSS11D',
#   'KEAP1',
#   'TIMM8A',
#   'LYPD3',
#   'NFKB1',
#   'EHD4',
#   'EPHA4',
#   'ANXA1',
#   'KPNA4',
#   'GBP6',
#   'TP53',
#   'FGFR3',
#   'SAR1B',
#   'RCOR2',
#   'RDH16',
#   'TSHZ2',
#   'NEK11',
#   'NCCRP1',
#   'AADAT',
#   'FANCI',
#   'LRPPRC',
#   'SERPINB4',
#   'RIN1',
#   'FAM83A',
#   'SWAP70',
#   'ADSL',
#   'DCAF11',
#   'ZNF669',
#   'TACC1',
#   'TMF1',
#   'BAG3',
#   'ARIH1',
#   'RIPK1',
#   'ENTPD3',
#   'NUP153',
#   'MAGEA1',
#   'CDH23',
#   'ZNF750',
#   'WDR5B',
#   'ERVMER34-1',
#   'KLK8'],
#  'luad': ['SUZ12',
#   'GDAP1',
#   'GMPR',
#   'GRHL1',
#   'KIF23',
#   'CLNS1A',
#   'QRSL1',
#   'PECR',
#   'S100A16',
#   'MTERF3',
#   'MCM4',
#   'SPINT1',
#   'CPLX2',
#   'NCAPG',
#   'STMN3',
#   'LONP2',
#   'GFPT1',
#   'WDR43',
#   'STOX2',
#   'CKS1B',
#   'BZW1',
#   'KCNK5',
#   'ETF1',
#   'PDCD6',
#   'AGPAT5',
#   'TCP1',
#   'C7orf50',
#   'MRPL1',
#   'EGFL7',
#   'SP4',
#   'ZFHX3',
#   'NAT1',
#   'PITPNC1',
#   'FOXA1',
#   'NAV2',
#   'ACSL3',
#   'UNG',
#   'PEX6',
#   'SLC22A18',
#   'NUBPL',
#   'SPATS2',
#   'SLC12A2',
#   'TLK1',
#   'PTCD3',
#   'NFKBIA',
#   'SLC30A5',
#   'SNX21',
#   'TLK2',
#   'MCM3',
#   'SLC52A2',
#   'MCM6',
#   'B4GALNT3',
#   'ABL2',
#   'IPO9',
#   'ATP1A1',
#   'LRPPRC',
#   'PDCD11',
#   'RRM1',
#   'AP1G1',
#   'TRIP11',
#   'EXD2',
#   'RPP40',
#   'NDC1',
#   'CAND1',
#   'USP14',
#   'POP1',
#   'ZNF467',
#   'ARID3A',
#   'SERPINB1',
#   'UBAP1',
#   'UBE2K',
#   'DFFB',
#   'PROM2',
#   'C12orf73',
#   'RELL1',
#   'ABCA12',
#   'FAM160B2',
#   'UBE2O',
#   'TIPRL',
#   'RAI1',
#   'NT5C1A',
#   'SMPD1',
#   'GFRA3',
#   'CHEK1',
#   'DYNC1LI1',
#   'UBQLN4',
#   'DCAF11',
#   'URM1',
#   'NEFL',
#   'PLAA',
#   'PARS2',
#   'CDCP1',
#   'GCNT1',
#   'UFSP2',
#   'CTDP1',
#   'MMP11',
#   'UGT1A6',
#   'UBA2',
#   'EPHX4',
#   'CD3EAP',
#   'NAA25',
#   'AK9',
#   'TUSC3',
#   'THAP7',
#   'STEAP1',
#   'SWAP70',
#   'KRT6B',
#   'HARS2',
#   'RCAN3',
#   'ARID2',
#   'EFS',
#   'IPO7',
#   'PIPOX',
#   'MAPRE1',
#   'TK2',
#   'TMEM248',
#   'LETMD1',
#   'SLFN11',
#   'IFT57',
#   'DPY19L1',
#   'PICALM',
#   'TAF2',
#   'ARNT',
#   'NUDT1',
#   'CA12',
#   'CYP3A5',
#   'DNMT3A',
#   'PPP1R3G',
#   'PADI1',
#   'TOX',
#   'AHCY',
#   'PITPNB',
#   'PSMG3',
#   'CRABP1',
#   'RASAL1',
#   'THTPA',
#   'ISG20L2',
#   'LRRC8D',
#   'ZNF516',
#   'TRMT6',
#   'UMPS',
#   'OLA1',
#   'EVI5L',
#   'ZWILCH',
#   'HS2ST1',
#   'PPAT',
#   'PRIM1',
#   'ELMO1',
#   'CRACR2A',
#   'DSCC1',
#   'TRMT5',
#   'CDC42EP3',
#   'NTS',
#   'MAML2',
#   'BCL10',
#   'RPRD1A',
#   'DHX57',
#   'SLC7A5',
#   'OTUD4',
#   'GNL1',
#   'USP28',
#   'RRM2',
#   'YTHDF1',
#   'KPNA6',
#   'TOE1',
#   'PTGES',
#   'TTK',
#   'NARS2',
#   'TRIM72',
#   'SEMA3A',
#   'PPP2CB',
#   'HOMEZ',
#   'MMP1',
#   'HIF1AN',
#   'CHD8',
#   'UBTD2',
#   'ENPP3',
#   'FKBP10',
#   'ABCC6',
#   'GMNN',
#   'DDX41',
#   'SERINC5',
#   'FOXA2',
#   'TPD52',
#   'GATAD2B',
#   'ST6GALNAC1',
#   'FBXL14',
#   'COG3',
#   'CIT',
#   'SNX13',
#   'NOL11',
#   'STK39',
#   'CDC42EP1',
#   'VPS37A',
#   'MUC16',
#   'FAM83B',
#   'AHCYL1',
#   'MARK3',
#   'MAP2K4',
#   'RSBN1L',
#   'AMACR',
#   'N4BP2',
#   'LYPD3',
#   'POGZ',
#   'MUC3A',
#   'CLSPN',
#   'GRHL2',
#   'CLDN12',
#   'DNAJC12',
#   'KIF1A',
#   'AKR7A3',
#   'NLRX1',
#   'USP19',
#   'PAX9',
#   'PRR36',
#   'FAHD2A',
#   'STAP2',
#   'MIER1',
#   'PCBD2',
#   'HIBADH',
#   'ACAD10',
#   'CTSF',
#   'BAG4',
#   'DLAT',
#   'PKP2',
#   'SERPINI1',
#   'DPH5',
#   'S100A14',
#   'NOLC1',
#   'LRRFIP2',
#   'MLLT3',
#   'AGR2',
#   'SLC25A21',
#   'MDN1',
#   'TRIM68',
#   'RAD54B',
#   'PA2G4',
#   'NAALADL2',
#   'UTP20',
#   'NSFL1C',
#   'MCM5',
#   'FUT8',
#   'FAM120C',
#   'SEPHS1',
#   'TTI1',
#   'BOLA3',
#   'METTL7B',
#   'MORC3',
#   'EIF2S1',
#   'MTMR3',
#   'MAD2L1',
#   'IGSF3',
#   'GALNT6',
#   'UGDH',
#   'BLMH',
#   'SAMD8',
#   'KHK',
#   'LYSMD1',
#   'KPNA2',
#   'OXSR1',
#   'TMPRSS11E',
#   'OSGEP',
#   'GRSF1',
#   'CLPTM1L',
#   'ULBP3',
#   'IGF2BP3',
#   'RIOK1',
#   'SFPQ',
#   'COL11A1',
#   'CYP24A1',
#   'SCG3',
#   'FBXO4',
#   'ANLN',
#   'EPHA4',
#   'BACE2',
#   'DENND4A',
#   'POF1B',
#   'PROX1',
#   'SYNCRIP',
#   'PGM2L1',
#   'GLCCI1',
#   'CLIP1',
#   'STXBP1',
#   'TARS2',
#   'XPA',
#   'NCAPD3',
#   'CHAT',
#   'MIPEP',
#   'DLGAP5',
#   'GABARAPL1',
#   'ZFP36L1',
#   'ESF1',
#   'C1orf122',
#   'VIL1',
#   'NCOR1',
#   'PDZK1IP1',
#   'SOX9',
#   'RAB39B',
#   'HID1',
#   'HS3ST1',
#   'ANXA2',
#   'GMPS',
#   'SBNO1',
#   'EIF4G1',
#   'GPT2',
#   'ABCC3',
#   'HS6ST2',
#   'XPO5',
#   'WBP4',
#   'GLB1L2',
#   'SPINK2',
#   'NAA15',
#   'NCAPG2',
#   'CAPN5',
#   'PRRC2A',
#   'PURB',
#   'ST14',
#   'NFKB1',
#   'NDUFAF7',
#   'PLA2G4A',
#   'HGD',
#   'ERCC6L',
#   'GMDS',
#   'CCL28',
#   'ARHGEF16',
#   'SPAG5',
#   'EDEM3',
#   'IKZF2',
#   'TBC1D30',
#   'DDI2',
#   'SLC25A37',
#   'ABCB10',
#   'LIG1',
#   'MAPKAPK2',
#   'EFCAB14',
#   'ECI2',
#   'CHAF1A',
#   'IRF2BPL',
#   'PSMD5',
#   'MRS2',
#   'METAP1',
#   'B3GNT7',
#   'LTBR',
#   'SDE2',
#   'OTUB1',
#   'SDC4',
#   'TAX1BP1',
#   'SGSM3',
#   'NCOA2',
#   'LCMT1',
#   'PPP2R2A',
#   'ZYG11B',
#   'ECT2',
#   'PPP1R1B',
#   'HEATR1',
#   'PPFIBP2',
#   'TFB2M',
#   'ODC1',
#   'NSUN2',
#   'ZMYM2',
#   'EEF1A2',
#   'SYT7',
#   'NHLRC3',
#   'GLCE',
#   'ATP10B',
#   'PAH',
#   'DNAJC2',
#   'LANCL2',
#   'PPP1R37',
#   'RASA1',
#   'IL6R',
#   'SPC24',
#   'DPYD',
#   'PMS2',
#   'IFI16',
#   'MSN',
#   'PDLIM1',
#   'PPME1',
#   'TK1',
#   'TMEM59',
#   'CLDN6',
#   'HDAC9',
#   'SIT1',
#   'PPM1D',
#   'SLC5A1',
#   'L2HGDH',
#   'GINS2',
#   'ITPKA',
#   'LRRC15',
#   'FAM83F',
#   'DTYMK',
#   'DSG2',
#   'ATPAF1',
#   'GCNT3',
#   'WIPI2',
#   'THG1L',
#   'SCG2',
#   'STAMBP',
#   'SYT2',
#   'HGH1',
#   'KLK6',
#   'TOPBP1',
#   'GATAD1',
#   'PFAS',
#   'SUPV3L1',
#   'CCNB1',
#   'MINPP1',
#   'GMPR2',
#   'ADAM28',
#   'STRAP',
#   'GINS4',
#   'ZDHHC13',
#   'PAK1',
#   'DCBLD2',
#   'TOP2A',
#   'BCL2L1',
#   'ZNF544',
#   'HSPB8',
#   'ATAD2',
#   'SPC25',
#   'GEMIN2',
#   'EIF4EBP1',
#   'RELA',
#   'KLF12',
#   'PYCR1',
#   'KPNB1',
#   'C2orf72',
#   'TGM1',
#   'SPOCD1',
#   'FAF1',
#   'STAU2',
#   'GLB1L3',
#   'HMGB3',
#   'ATP7A',
#   'SDC1',
#   'PPIL4',
#   'FANCI',
#   'EIF4EBP3',
#   'CAPNS2',
#   'GUF1',
#   'BCL2L13',
#   'NCAPH',
#   'UBR1',
#   'TSC22D2',
#   'MKI67',
#   'XPR1',
#   'VDAC2',
#   'SPRTN',
#   'TDRKH',
#   'URGCP',
#   'FKBP14',
#   'DNM1L',
#   'HEATR5A',
#   'ALDOA',
#   'SEPSECS',
#   'SEZ6L2',
#   'NCAPD2',
#   'CDK1',
#   'FBXL18',
#   'GATA6',
#   'TUBB2B',
#   'RBMXL1',
#   'RBKS',
#   'NVL',
#   'FUNDC2',
#   'PTK6',
#   'ARMCX3',
#   'CAD',
#   'BCL2L15',
#   'TRAP1',
#   'BRCA1',
#   'CRABP2',
#   'ACE2',
#   'HLTF',
#   'REEP6',
#   'PMEPA1',
#   'BIRC5',
#   'TWISTNB',
#   'ZNF318',
#   'HHIPL2',
#   'ABCF1',
#   'RECQL5',
#   'SCAF4',
#   'CHMP1B',
#   'HOXB6',
#   'IL37',
#   'CARD14',
#   'AVL9',
#   'CELF2',
#   'STRA6',
#   'FAM111B',
#   'GLMN',
#   'EMD',
#   'SRSF4',
#   'FAF2',
#   'JAG2',
#   'PPFIA3',
#   'GRAMD1B',
#   'PAICS',
#   'CD1A',
#   'HAS3',
#   'ZNF608',
#   'CALB1',
#   'KIF4A',
#   'BAG3',
#   'KIF22',
#   'UBFD1',
#   'TMPRSS4',
#   'ENTPD5',
#   'UGT8',
#   'TNS4',
#   'TYMS',
#   'MCM7',
#   'PSMC3IP',
#   'CDC20',
#   'TMEM159',
#   'PAFAH1B3',
#   'KIF2C',
#   'BROX',
#   'PCP4',
#   'COIL',
#   'KIFC1',
#   'DHFR',
#   'INTS7',
#   'KNTC1',
#   'DCTPP1',
#   'ICAM1',
#   'ZNF845',
#   'GOLGA7B',
#   'MIS18A',
#   'ABHD17C',
#   'NUAK1',
#   'CBLC',
#   'EZR',
#   'FA2H',
#   'OCIAD2',
#   'GPRASP1',
#   'TACC1',
#   'UBE2T',
#   'TPCN2',
#   'MCM2',
#   'CCNB2',
#   'TPX2',
#   'S100A7',
#   'ADSL',
#   'PROSER3',
#   'YWHAZ',
#   'VPS36',
#   'TOX3',
#   'FLAD1',
#   'ESCO2',
#   'B3GNT6',
#   'CCR2',
#   'EHD4',
#   'ACY3',
#   'SYT1',
#   'PRMT3',
#   'PBK',
#   'ANXA1',
#   'AURKA',
#   'WDHD1',
#   'MELK',
#   'NUP153',
#   'NELL1',
#   'GGCT',
#   'XDH',
#   'TRIP13',
#   'SMC2',
#   'CENPH',
#   'CDC45']}

# %% [markdown]
# ### Get the distance between the tumor and normal residuals for each patient and each significant gene.

# %%
top_genes_residuals_dist = {}
for cancer_type in cancer_types:
    res = residuals[cancer_type]
    
    top_res = res[res["Gene"].isin(highest_delta_genes[cancer_type])].\
    pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values=["intersect_x", "intersect_y"],
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).\
    dropna(axis=0, how="any").\
    reset_index(drop=False)
    
    x_tumor = top_res['intersect_x']['Tumor']
    y_tumor = top_res['intersect_y']['Tumor']
    x_normal = top_res['intersect_x']['Normal']
    y_normal = top_res['intersect_y']['Normal']
    
    tumor = tuple(zip(x_tumor, y_tumor))
    normal = tuple(zip(x_normal, y_normal))
    
    top_res = top_res.\
    assign(tumor_normal_residual_dist=[math.dist(tumor[x], normal[x]) for x in range(len(tumor))]).\
    pivot(
        index="Patient_ID",
        columns="Gene",
        values="tumor_normal_residual_dist",
    ).\
    add_prefix("tumor_normal_residual_dist_")
    
    top_res.columns.name = None
    
    top_genes_residuals_dist[cancer_type] = top_res

top_genes_residuals_dist["ccrcc"]
# Out:
#             tumor_normal_residual_dist_ADCY3  tumor_normal_residual_dist_AGK  \
# Patient_ID
# C3L-00004                                NaN                        2.368666
# C3L-00010                                NaN                        0.160878
# C3L-00011                                NaN                        0.914093
# C3L-00026                                NaN                        1.699979
# C3L-00079                                NaN                        0.600205
# ...                                      ...                             ...
# C3N-01646                                NaN                        0.780648
# C3N-01648                                NaN                        1.179941
# C3N-01649                           3.768251                        0.663157
# C3N-01651                           2.546564                        1.107103
# C3N-01808                           6.482955                        0.651401
#
#             tumor_normal_residual_dist_AGXT  tumor_normal_residual_dist_AHSA1  \
# Patient_ID
# C3L-00004                         13.190856                          8.481922
# C3L-00010                         11.688750                         11.935946
# C3L-00011                          3.568109                          6.287237
# C3L-00026                          3.824380                          3.670214
# C3L-00079                          2.337069                          1.420444
# ...                                     ...                               ...
# C3N-01646                          4.981830                          7.273306
# C3N-01648                          5.613505                          0.705244
# C3N-01649                          5.136188                          3.093425
# C3N-01651                         10.179527                          3.290355
# C3N-01808                         14.667738                          5.776070
#
#             tumor_normal_residual_dist_ALDH18A1  \
# Patient_ID
# C3L-00004                              7.053608
# C3L-00010                              4.414980
# C3L-00011                             34.092835
# C3L-00026                             18.820047
# C3L-00079                              9.337463
# ...                                         ...
# C3N-01646                             20.638650
# C3N-01648                              5.357198
# C3N-01649                              1.741500
# C3N-01651                             23.025980
# C3N-01808                             16.348075
#
#             tumor_normal_residual_dist_ANKZF1  \
# Patient_ID
# C3L-00004                            2.121463
# C3L-00010                            2.268968
# C3L-00011                            7.746025
# C3L-00026                            5.686363
# C3L-00079                            3.583359
# ...                                       ...
# C3N-01646                            5.568947
# C3N-01648                            0.381726
# C3N-01649                            2.624052
# C3N-01651                           14.078832
# C3N-01808                            0.793491
#
#             tumor_normal_residual_dist_AP3M1  \
# Patient_ID
# C3L-00004                           1.227607
# C3L-00010                           2.087734
# C3L-00011                           5.285246
# C3L-00026                           1.816493
# C3L-00079                           0.263818
# ...                                      ...
# C3N-01646                           1.877280
# C3N-01648                           2.456724
# C3N-01649                           0.315908
# C3N-01651                           1.001933
# C3N-01808                           1.558424
#
#             tumor_normal_residual_dist_AP4S1  \
# Patient_ID
# C3L-00004                           0.648589
# C3L-00010                           1.128539
# C3L-00011                           1.872484
# C3L-00026                           0.364995
# C3L-00079                           1.039790
# ...                                      ...
# C3N-01646                           1.558076
# C3N-01648                           0.426310
# C3N-01649                           0.386628
# C3N-01651                           0.323635
# C3N-01808                           0.299202
#
#             tumor_normal_residual_dist_APLP2  \
# Patient_ID
# C3L-00004                          90.507645
# C3L-00010                          36.071283
# C3L-00011                           5.217191
# C3L-00026                          73.821719
# C3L-00079                          53.952419
# ...                                      ...
# C3N-01646                           9.978579
# C3N-01648                          34.261414
# C3N-01649                          42.591365
# C3N-01651                          71.024819
# C3N-01808                          44.707714
#
#             tumor_normal_residual_dist_APPL1  ...  \
# Patient_ID                                    ...
# C3L-00004                           1.901647  ...
# C3L-00010                           5.221817  ...
# C3L-00011                           2.252784  ...
# C3L-00026                           4.882907  ...
# C3L-00079                           7.534761  ...
# ...                                      ...  ...
# C3N-01646                           5.104328  ...
# C3N-01648                           4.428208  ...
# C3N-01649                           0.622113  ...
# C3N-01651                           5.637702  ...
# C3N-01808                           0.954673  ...
#
#             tumor_normal_residual_dist_USP47  \
# Patient_ID
# C3L-00004                           0.690147
# C3L-00010                           1.146994
# C3L-00011                           8.855820
# C3L-00026                           1.284213
# C3L-00079                           0.111235
# ...                                      ...
# C3N-01646                           2.485320
# C3N-01648                           0.456511
# C3N-01649                           0.759353
# C3N-01651                           3.961973
# C3N-01808                           0.361334
#
#             tumor_normal_residual_dist_USP6NL  \
# Patient_ID
# C3L-00004                            0.334414
# C3L-00010                            0.258698
# C3L-00011                            0.549924
# C3L-00026                            0.515147
# C3L-00079                            1.697944
# ...                                       ...
# C3N-01646                            0.622399
# C3N-01648                            0.030175
# C3N-01649                            1.172342
# C3N-01651                            0.378206
# C3N-01808                            0.288311
#
#             tumor_normal_residual_dist_VPS25  tumor_normal_residual_dist_WNK1  \
# Patient_ID
# C3L-00004                           2.890216                        22.063776
# C3L-00010                           1.391139                        27.201389
# C3L-00011                           2.219539                        37.144099
# C3L-00026                           4.089902                        29.820201
# C3L-00079                           6.768456                        13.759756
# ...                                      ...                              ...
# C3N-01646                           3.926320                        19.072103
# C3N-01648                           2.158922                        23.660798
# C3N-01649                           1.509458                        25.003360
# C3N-01651                           3.196001                        31.660524
# C3N-01808                           0.227577                        29.555190
#
#             tumor_normal_residual_dist_XPNPEP1  \
# Patient_ID
# C3L-00004                             6.150969
# C3L-00010                             4.916786
# C3L-00011                            11.330073
# C3L-00026                             5.085747
# C3L-00079                             2.167726
# ...                                        ...
# C3N-01646                             9.838101
# C3N-01648                             2.559214
# C3N-01649                             5.858864
# C3N-01651                             1.705531
# C3N-01808                            13.317052
#
#             tumor_normal_residual_dist_YARS2  \
# Patient_ID
# C3L-00004                           1.036304
# C3L-00010                           0.891255
# C3L-00011                           4.226288
# C3L-00026                           0.748156
# C3L-00079                           1.526541
# ...                                      ...
# C3N-01646                           2.040016
# C3N-01648                           0.734890
# C3N-01649                           0.976327
# C3N-01651                           1.383558
# C3N-01808                           1.615526
#
#             tumor_normal_residual_dist_ZDHHC2  \
# Patient_ID
# C3L-00004                                 NaN
# C3L-00010                                 NaN
# C3L-00011                           11.778113
# C3L-00026                                 NaN
# C3L-00079                                 NaN
# ...                                       ...
# C3N-01646                            7.116299
# C3N-01648                                 NaN
# C3N-01649                                 NaN
# C3N-01651                                 NaN
# C3N-01808                                 NaN
#
#             tumor_normal_residual_dist_ZEB1  \
# Patient_ID
# C3L-00004                               NaN
# C3L-00010                               NaN
# C3L-00011                               NaN
# C3L-00026                          0.145020
# C3L-00079                          4.290248
# ...                                     ...
# C3N-01646                               NaN
# C3N-01648                               NaN
# C3N-01649                         22.031193
# C3N-01651                          5.654181
# C3N-01808                          8.346101
#
#             tumor_normal_residual_dist_ZNF358  \
# Patient_ID
# C3L-00004                            1.803353
# C3L-00010                                 NaN
# C3L-00011                            2.735838
# C3L-00026                                 NaN
# C3L-00079                                 NaN
# ...                                       ...
# C3N-01646                                 NaN
# C3N-01648                            0.993375
# C3N-01649                                 NaN
# C3N-01651                                 NaN
# C3N-01808                                 NaN
#
#             tumor_normal_residual_dist_ZNF397
# Patient_ID
# C3L-00004                                 NaN
# C3L-00010                                 NaN
# C3L-00011                                 NaN
# C3L-00026                                 NaN
# C3L-00079                                 NaN
# ...                                       ...
# C3N-01646                            0.227134
# C3N-01648                                 NaN
# C3N-01649                                 NaN
# C3N-01651                            0.567331
# C3N-01808                                 NaN
#
# [75 rows x 186 columns]

# %% [markdown]
# ### Get the orthogonal distance of the tumor residuals and whether the point is above or below the regression line for each patient and each gene. (If the orthogonal distance is negative, it is below the line and vice versa)

# %%
def get_signed_res(row):
    if not row['above_reg_line']:
        return (row['orth_resid'] * -1)
    else:
        return row['orth_resid']
    
above_reg_line_top_genes = {}
for cancer_type in cancer_types:
    res = residuals[cancer_type]
    
    res['signed_orth_res'] = res.apply(get_signed_res, axis=1)
    
    top_res = res[res["Gene"].isin(highest_delta_genes[cancer_type])].\
    pivot_table(
        index=["Patient_ID", "Gene"],
        columns="Tissue",
        values="signed_orth_res",
        aggfunc=np.mean, # To handle duplicates--temp until we get Database_ID
    ).\
    dropna(axis=0, how="any").\
    reset_index(drop=False)
    
    top_res = top_res.\
    pivot(
        index="Patient_ID",
        columns="Gene",
        values="Tumor",
    ).\
    sort_index(axis=1)
    
    top_res = top_res.add_prefix("signed_orth_res_")
    
    top_res.columns.name = None
    
    above_reg_line_top_genes[cancer_type] = top_res

above_reg_line_top_genes["ccrcc"]
# Out:
#             signed_orth_res_ADCY3  signed_orth_res_AGK  signed_orth_res_AGXT  \
# Patient_ID
# C3L-00004                     NaN             0.087608              0.173471
# C3L-00010                     NaN            -0.297483              0.064843
# C3L-00011                     NaN            -0.326863              0.183270
# C3L-00026                     NaN             0.105183             -1.214213
# C3L-00079                     NaN             0.167635              0.090650
# ...                           ...                  ...                   ...
# C3N-01646                     NaN             0.176065             -0.509809
# C3N-01648                     NaN            -0.004708              0.204864
# C3N-01649                0.314160             0.035091              0.166634
# C3N-01651               -0.263315             0.418284             -0.090940
# C3N-01808                0.634746             0.380034              0.071437
#
#             signed_orth_res_AHSA1  signed_orth_res_ALDH18A1  \
# Patient_ID
# C3L-00004               -0.035851                 -0.148725
# C3L-00010               -0.240694                 -0.565231
# C3L-00011                0.333279                 -0.438071
# C3L-00026               -0.246163                  0.611293
# C3L-00079                0.126676                  0.310022
# ...                           ...                       ...
# C3N-01646               -0.121372                 -0.455689
# C3N-01648                0.148220                  0.456692
# C3N-01649               -0.277172                 -0.178384
# C3N-01651                0.025406                  0.347838
# C3N-01808                0.007071                  0.106280
#
#             signed_orth_res_ANKZF1  signed_orth_res_AP3M1  \
# Patient_ID
# C3L-00004                 0.380128              -0.050607
# C3L-00010                -0.117507               0.080662
# C3L-00011                 0.032485               0.093737
# C3L-00026                 0.342243              -0.017364
# C3L-00079                 0.359718              -0.083191
# ...                            ...                    ...
# C3N-01646                -0.016855               0.239441
# C3N-01648                 0.225285               0.035138
# C3N-01649                -0.373279              -0.162847
# C3N-01651                 0.258287              -0.001249
# C3N-01808                -0.148527              -0.164212
#
#             signed_orth_res_AP4S1  signed_orth_res_APLP2  \
# Patient_ID
# C3L-00004                0.051859              -0.525722
# C3L-00010                0.173044              -0.286951
# C3L-00011                0.008956               0.610745
# C3L-00026                0.117009              -0.153906
# C3L-00079                0.188223               0.421607
# ...                           ...                    ...
# C3N-01646                0.119615               0.031246
# C3N-01648                0.315726              -0.311116
# C3N-01649               -0.322632               0.014751
# C3N-01651               -0.155597              -0.108598
# C3N-01808                0.141817              -0.036783
#
#             signed_orth_res_APPL1  ...  signed_orth_res_USP47  \
# Patient_ID                         ...
# C3L-00004               -0.013978  ...               0.010893
# C3L-00010               -0.008435  ...              -0.075189
# C3L-00011               -0.228480  ...              -0.261528
# C3L-00026               -0.232801  ...               0.088498
# C3L-00079               -0.631637  ...              -0.097382
# ...                           ...  ...                    ...
# C3N-01646                0.030285  ...               0.057308
# C3N-01648                0.301077  ...               0.078408
# C3N-01649               -0.121734  ...              -0.187441
# C3N-01651                0.016128  ...               0.021833
# C3N-01808               -0.087491  ...               0.017798
#
#             signed_orth_res_USP6NL  signed_orth_res_VPS25  \
# Patient_ID
# C3L-00004                 0.152850               0.181947
# C3L-00010                 0.055203               0.050951
# C3L-00011                -0.312138              -0.777187
# C3L-00026                 0.155157              -0.068772
# C3L-00079                -0.313189              -0.276598
# ...                            ...                    ...
# C3N-01646                -0.252448              -0.027133
# C3N-01648                -0.588844               0.005994
# C3N-01649                 0.058879              -0.050599
# C3N-01651                -0.144407              -0.415184
# C3N-01808                 0.235795              -0.138567
#
#             signed_orth_res_WNK1  signed_orth_res_XPNPEP1  \
# Patient_ID
# C3L-00004               0.149241                 0.422377
# C3L-00010              -0.086946                 0.142795
# C3L-00011               0.605387                -0.179915
# C3L-00026              -0.096996                 0.189214
# C3L-00079               0.065601                 0.052522
# ...                          ...                      ...
# C3N-01646               0.098906                -0.123295
# C3N-01648               0.420178                -0.162881
# C3N-01649              -0.024938                -0.208821
# C3N-01651               0.089418                 0.032847
# C3N-01808               0.107705                 0.114809
#
#             signed_orth_res_YARS2  signed_orth_res_ZDHHC2  \
# Patient_ID
# C3L-00004                0.061650                     NaN
# C3L-00010               -0.338331                     NaN
# C3L-00011               -0.343415                0.018595
# C3L-00026                0.779191                     NaN
# C3L-00079                0.252166                     NaN
# ...                           ...                     ...
# C3N-01646               -0.373050                0.864411
# C3N-01648                0.089283                     NaN
# C3N-01649                0.035469                     NaN
# C3N-01651                0.417992                     NaN
# C3N-01808               -0.069852                     NaN
#
#             signed_orth_res_ZEB1  signed_orth_res_ZNF358  \
# Patient_ID
# C3L-00004                    NaN               -0.069231
# C3L-00010                    NaN                     NaN
# C3L-00011                    NaN                0.113805
# C3L-00026               0.288435                     NaN
# C3L-00079               0.195492                     NaN
# ...                          ...                     ...
# C3N-01646                    NaN                     NaN
# C3N-01648                    NaN                0.615288
# C3N-01649              -0.710171                     NaN
# C3N-01651               0.201946                     NaN
# C3N-01808               0.556281                     NaN
#
#             signed_orth_res_ZNF397
# Patient_ID
# C3L-00004                      NaN
# C3L-00010                      NaN
# C3L-00011                      NaN
# C3L-00026                      NaN
# C3L-00079                      NaN
# ...                            ...
# C3N-01646                 -0.09257
# C3N-01648                      NaN
# C3N-01649                      NaN
# C3N-01651                 -0.07813
# C3N-01808                      NaN
#
# [75 rows x 186 columns]

# %% [markdown]
# ### Combine the dataframes for the residual distances and orthogonal residual to create the input dataframe

# %%
all_data = {}
for cancer_type in cancer_types:
    cancer_type_all = top_genes_residuals_dist[cancer_type].join(above_reg_line_top_genes[cancer_type], how="outer")
    cancer_type_all = cancer_type_all.dropna(axis=0, how="all")
    all_data[cancer_type] = cancer_type_all
    
all_data['ccrcc']
# Out:
#             tumor_normal_residual_dist_ADCY3  tumor_normal_residual_dist_AGK  \
# Patient_ID
# C3L-00004                                NaN                        2.368666
# C3L-00010                                NaN                        0.160878
# C3L-00011                                NaN                        0.914093
# C3L-00026                                NaN                        1.699979
# C3L-00079                                NaN                        0.600205
# ...                                      ...                             ...
# C3N-01646                                NaN                        0.780648
# C3N-01648                                NaN                        1.179941
# C3N-01649                           3.768251                        0.663157
# C3N-01651                           2.546564                        1.107103
# C3N-01808                           6.482955                        0.651401
#
#             tumor_normal_residual_dist_AGXT  tumor_normal_residual_dist_AHSA1  \
# Patient_ID
# C3L-00004                         13.190856                          8.481922
# C3L-00010                         11.688750                         11.935946
# C3L-00011                          3.568109                          6.287237
# C3L-00026                          3.824380                          3.670214
# C3L-00079                          2.337069                          1.420444
# ...                                     ...                               ...
# C3N-01646                          4.981830                          7.273306
# C3N-01648                          5.613505                          0.705244
# C3N-01649                          5.136188                          3.093425
# C3N-01651                         10.179527                          3.290355
# C3N-01808                         14.667738                          5.776070
#
#             tumor_normal_residual_dist_ALDH18A1  \
# Patient_ID
# C3L-00004                              7.053608
# C3L-00010                              4.414980
# C3L-00011                             34.092835
# C3L-00026                             18.820047
# C3L-00079                              9.337463
# ...                                         ...
# C3N-01646                             20.638650
# C3N-01648                              5.357198
# C3N-01649                              1.741500
# C3N-01651                             23.025980
# C3N-01808                             16.348075
#
#             tumor_normal_residual_dist_ANKZF1  \
# Patient_ID
# C3L-00004                            2.121463
# C3L-00010                            2.268968
# C3L-00011                            7.746025
# C3L-00026                            5.686363
# C3L-00079                            3.583359
# ...                                       ...
# C3N-01646                            5.568947
# C3N-01648                            0.381726
# C3N-01649                            2.624052
# C3N-01651                           14.078832
# C3N-01808                            0.793491
#
#             tumor_normal_residual_dist_AP3M1  \
# Patient_ID
# C3L-00004                           1.227607
# C3L-00010                           2.087734
# C3L-00011                           5.285246
# C3L-00026                           1.816493
# C3L-00079                           0.263818
# ...                                      ...
# C3N-01646                           1.877280
# C3N-01648                           2.456724
# C3N-01649                           0.315908
# C3N-01651                           1.001933
# C3N-01808                           1.558424
#
#             tumor_normal_residual_dist_AP4S1  \
# Patient_ID
# C3L-00004                           0.648589
# C3L-00010                           1.128539
# C3L-00011                           1.872484
# C3L-00026                           0.364995
# C3L-00079                           1.039790
# ...                                      ...
# C3N-01646                           1.558076
# C3N-01648                           0.426310
# C3N-01649                           0.386628
# C3N-01651                           0.323635
# C3N-01808                           0.299202
#
#             tumor_normal_residual_dist_APLP2  \
# Patient_ID
# C3L-00004                          90.507645
# C3L-00010                          36.071283
# C3L-00011                           5.217191
# C3L-00026                          73.821719
# C3L-00079                          53.952419
# ...                                      ...
# C3N-01646                           9.978579
# C3N-01648                          34.261414
# C3N-01649                          42.591365
# C3N-01651                          71.024819
# C3N-01808                          44.707714
#
#             tumor_normal_residual_dist_APPL1  ...  signed_orth_res_USP47  \
# Patient_ID                                    ...
# C3L-00004                           1.901647  ...               0.010893
# C3L-00010                           5.221817  ...              -0.075189
# C3L-00011                           2.252784  ...              -0.261528
# C3L-00026                           4.882907  ...               0.088498
# C3L-00079                           7.534761  ...              -0.097382
# ...                                      ...  ...                    ...
# C3N-01646                           5.104328  ...               0.057308
# C3N-01648                           4.428208  ...               0.078408
# C3N-01649                           0.622113  ...              -0.187441
# C3N-01651                           5.637702  ...               0.021833
# C3N-01808                           0.954673  ...               0.017798
#
#             signed_orth_res_USP6NL  signed_orth_res_VPS25  \
# Patient_ID
# C3L-00004                 0.152850               0.181947
# C3L-00010                 0.055203               0.050951
# C3L-00011                -0.312138              -0.777187
# C3L-00026                 0.155157              -0.068772
# C3L-00079                -0.313189              -0.276598
# ...                            ...                    ...
# C3N-01646                -0.252448              -0.027133
# C3N-01648                -0.588844               0.005994
# C3N-01649                 0.058879              -0.050599
# C3N-01651                -0.144407              -0.415184
# C3N-01808                 0.235795              -0.138567
#
#             signed_orth_res_WNK1  signed_orth_res_XPNPEP1  \
# Patient_ID
# C3L-00004               0.149241                 0.422377
# C3L-00010              -0.086946                 0.142795
# C3L-00011               0.605387                -0.179915
# C3L-00026              -0.096996                 0.189214
# C3L-00079               0.065601                 0.052522
# ...                          ...                      ...
# C3N-01646               0.098906                -0.123295
# C3N-01648               0.420178                -0.162881
# C3N-01649              -0.024938                -0.208821
# C3N-01651               0.089418                 0.032847
# C3N-01808               0.107705                 0.114809
#
#             signed_orth_res_YARS2  signed_orth_res_ZDHHC2  \
# Patient_ID
# C3L-00004                0.061650                     NaN
# C3L-00010               -0.338331                     NaN
# C3L-00011               -0.343415                0.018595
# C3L-00026                0.779191                     NaN
# C3L-00079                0.252166                     NaN
# ...                           ...                     ...
# C3N-01646               -0.373050                0.864411
# C3N-01648                0.089283                     NaN
# C3N-01649                0.035469                     NaN
# C3N-01651                0.417992                     NaN
# C3N-01808               -0.069852                     NaN
#
#             signed_orth_res_ZEB1  signed_orth_res_ZNF358  \
# Patient_ID
# C3L-00004                    NaN               -0.069231
# C3L-00010                    NaN                     NaN
# C3L-00011                    NaN                0.113805
# C3L-00026               0.288435                     NaN
# C3L-00079               0.195492                     NaN
# ...                          ...                     ...
# C3N-01646                    NaN                     NaN
# C3N-01648                    NaN                0.615288
# C3N-01649              -0.710171                     NaN
# C3N-01651               0.201946                     NaN
# C3N-01808               0.556281                     NaN
#
#             signed_orth_res_ZNF397
# Patient_ID
# C3L-00004                      NaN
# C3L-00010                      NaN
# C3L-00011                      NaN
# C3L-00026                      NaN
# C3L-00079                      NaN
# ...                            ...
# C3N-01646                 -0.09257
# C3N-01648                      NaN
# C3N-01649                      NaN
# C3N-01651                 -0.07813
# C3N-01808                      NaN
#
# [75 rows x 372 columns]

# %% [markdown]
# ### Get the clinical data for each cancer that will be the targets for the model

# %%
dss = {
    "ccrcc": pc.PancanCcrcc,
    "endometrial": pc.PancanUcec,
    "hnscc": pc.PancanHnscc,
    "lscc": pc.PancanLscc,
    "luad": pc.PancanLuad,
}

# %%
def get_clinical(dss, cancer_type):
    
    # Download
    #pc.download("pancan" + cancer_type) if cancer_type != "endometrial" else pc.download("pancanucec")
    
    # Instantiate the dataset
    ds = dss[cancer_type]()
    
    # We use get_clinical instead of get_followup because get_followup just returns
    # a subset of the clinical table, and we need other columns too
    clin_vars = ds.get_clinical()[[
        "Recurrence status (1, yes; 0, no)",
        "Survial status (1, dead; 0, alive)",
        "baseline/histologic_type",
        "baseline/pathologic_staging_primary_tumor",
        "cptac_path/histologic_grade",
        "follow-up/measure_of_success_of_outcome_at_last_available_follow-up",
    ]]

    # Get rid of categorizing prefixes in column names, where they exist
    cols = clin_vars.columns.str.split("/", expand=True).to_frame()
    cols.columns = ["a", "b"]
    cols = cols.assign(b=cols["b"].fillna(cols["a"])) # If there was no prefix, no change
    clin_vars.columns = cols["b"].rename(None)
    
    # Fix values in measure of success column--sometimes deceased patients are listed
    # as "Persistent Disease" in this column, instead of "Patient Deceased"
    clin_vars = clin_vars.assign(
        **{"measure_of_success_of_outcome_at_last_available_follow-up": np.where(
            clin_vars["Survial status (1, dead; 0, alive)"] == 1,
            "Patient Deceased",
            clin_vars["measure_of_success_of_outcome_at_last_available_follow-up"]
        )}
    )
    
    # Make paired Patient_IDs same
    clin_vars.index = clin_vars.index.str.split("\.N", expand=True).to_frame()[0]
    
    # Drop any completely NaN rows
    clin_vars = clin_vars.dropna(axis=0, how="all")

    return clin_vars

clin = {}
for cancer_type in cancer_types:
    clin[cancer_type] = get_clinical(dss, cancer_type)

# %%
# Clean up and simplify the tumor stage column
for cancer_type in cancer_types:
    clin[cancer_type] = clin[cancer_type].assign(pathologic_staging_primary_tumor=clin[cancer_type]["pathologic_staging_primary_tumor"].\
        str.split(" ", expand=True)[0].\
        str.lower().\
        str.strip().\
        str.replace(":", "", regex=False).\
        str.replace("^p", "", regex=True).\
        str.replace("^(\d)", "t\1", regex=True).\
        str.replace("\x01", "", regex=False).\
        str.replace("[abc]", "", regex=True).\
        replace(to_replace="t", value=np.nan)
    )

# %%
# Drop rows where input cols are all NaN
for cancer_type in cancer_types:
    nan_subset = all_data[cancer_type].columns
    all_data[cancer_type] = all_data[cancer_type].dropna(axis=0, how="all", subset=nan_subset)
    
    nan_subset = clin[cancer_type].columns
    clin[cancer_type] = clin[cancer_type].dropna(axis=0, how="all", subset=nan_subset)

# %%
# Export input and target dataframes 
for cancer_type in cancer_types:
    all_data[cancer_type].to_csv(f'uncleaned_data/{cancer_type}_inputs.tsv', sep="\t")
    clin[cancer_type].to_csv(f'uncleaned_data/{cancer_type}_targets.tsv', sep="\t")

# %%
clin['ccrcc']
# Out:
#            Recurrence status (1, yes; 0, no)  \
# 0
# C3L-00004                                0.0
# C3L-00010                                0.0
# C3L-00011                                0.0
# C3L-00026                                0.0
# C3L-00079                                0.0
# ...                                      ...
# C3N-01646                                0.0
# C3N-01648                                0.0
# C3N-01649                                0.0
# C3N-01651                                1.0
# C3N-01808                                0.0
#
#            Survial status (1, dead; 0, alive)  \
# 0
# C3L-00004                                 0.0
# C3L-00010                                 0.0
# C3L-00011                                 1.0
# C3L-00026                                 0.0
# C3L-00079                                 1.0
# ...                                       ...
# C3N-01646                                 0.0
# C3N-01648                                 0.0
# C3N-01649                                 0.0
# C3N-01651                                 0.0
# C3N-01808                                 0.0
#
#                            histologic_type pathologic_staging_primary_tumor  \
# 0
# C3L-00004  Clear cell renal cell carcinoma                               t3
# C3L-00010  Clear cell renal cell carcinoma                               t1
# C3L-00011  Clear cell renal cell carcinoma                               t3
# C3L-00026  Clear cell renal cell carcinoma                               t1
# C3L-00079  Clear cell renal cell carcinoma                               t3
# ...                                    ...                              ...
# C3N-01646  Clear cell renal cell carcinoma                               t3
# C3N-01648  Clear cell renal cell carcinoma                               t2
# C3N-01649  Clear cell renal cell carcinoma                               t3
# C3N-01651  Clear cell renal cell carcinoma                               t2
# C3N-01808  Clear cell renal cell carcinoma                               t1
#
#                                             histologic_grade  \
# 0
# C3L-00004  G3: Nuclei very irregular, approximately 20µm;...
# C3L-00010  G3: Nuclei very irregular, approximately 20µm;...
# C3L-00011  G4: Nuclei bizarre and multilobulated, 20µm or...
# C3L-00026  G3: Nuclei very irregular, approximately 20µm;...
# C3L-00079  G3: Nuclei very irregular, approximately 20µm;...
# ...                                                      ...
# C3N-01646  G3: Nuclei very irregular, approximately 20µm;...
# C3N-01648  G2: Nuclei slightly irregular, approximately 1...
# C3N-01649  G2: Nuclei slightly irregular, approximately 1...
# C3N-01651  G3: Nuclei very irregular, approximately 20µm;...
# C3N-01808  G2: Nuclei slightly irregular, approximately 1...
#
#           measure_of_success_of_outcome_at_last_available_follow-up
# 0
# C3L-00004                                            Unknown
# C3L-00010                                 Complete Remission
# C3L-00011                                   Patient Deceased
# C3L-00026                                 Complete Remission
# C3L-00079                                   Patient Deceased
# ...                                                      ...
# C3N-01646                                 Complete Remission
# C3N-01648                                 Complete Remission
# C3N-01649                                 Complete Remission
# C3N-01651                                 Persistent Disease
# C3N-01808                                 Complete Remission
#
# [110 rows x 6 columns]

# %%
clin['lscc']
# Out:
#            Recurrence status (1, yes; 0, no)  \
# 0
# C3L-00081                                1.0
# C3L-00415                                1.0
# C3L-00445                                0.0
# C3L-00568                                0.0
# C3L-00603                                0.0
# ...                                      ...
# C3N-03886                                0.0
# C3N-04124                                0.0
# C3N-04127                                0.0
# C3N-04155                                0.0
# C3N-04162                                0.0
#
#            Survial status (1, dead; 0, alive)  \
# 0
# C3L-00081                                 1.0
# C3L-00415                                 0.0
# C3L-00445                                 1.0
# C3L-00568                                 0.0
# C3L-00603                                 0.0
# ...                                       ...
# C3N-03886                                 0.0
# C3N-04124                                 0.0
# C3N-04127                                 0.0
# C3N-04155                                 0.0
# C3N-04162                                 0.0
#
#                                     histologic_type  \
# 0
# C3L-00081                   Squamous cell carcinoma
# C3L-00415                   Squamous cell carcinoma
# C3L-00445      Keratinizing squamous cell carcinoma
# C3L-00568                   Squamous cell carcinoma
# C3L-00603                   Squamous cell carcinoma
# ...                                             ...
# C3N-03886          Basaloid squamous cell carcinoma
# C3N-04124                   Squamous cell carcinoma
# C3N-04127                   Squamous cell carcinoma
# C3N-04155  Non-keratinizing squamous cell carcinoma
# C3N-04162                   Squamous cell carcinoma
#
#           pathologic_staging_primary_tumor              histologic_grade  \
# 0
# C3L-00081                               t2  G2 Moderately differentiated
# C3L-00415                               t2      G3 Poorly differentiated
# C3L-00445                               t2  G2 Moderately differentiated
# C3L-00568                               t2  G2 Moderately differentiated
# C3L-00603                               t1      G3 Poorly differentiated
# ...                                    ...                           ...
# C3N-03886                               t2   GX Grade cannot be assessed
# C3N-04124                               t2      G3 Poorly differentiated
# C3N-04127                               t2  G2 Moderately differentiated
# C3N-04155                               t1  G2 Moderately differentiated
# C3N-04162                               t2  G2 Moderately differentiated
#
#           measure_of_success_of_outcome_at_last_available_follow-up
# 0
# C3L-00081                                   Patient Deceased
# C3L-00415                                 Persistent Disease
# C3L-00445                                   Patient Deceased
# C3L-00568                                     Not Applicable
# C3L-00603                                                NaN
# ...                                                      ...
# C3N-03886                                 Complete Remission
# C3N-04124                                     Not Applicable
# C3N-04127                                 Complete Remission
# C3N-04155                                 Complete Remission
# C3N-04162                                 Complete Remission
#
# [110 rows x 6 columns]
