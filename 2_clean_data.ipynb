# %% [markdown]
# # Clean data
#
# Normalization and imputing missing values.

# %%
import pandas as pd
import numpy as np
from copy import deepcopy

# %% [markdown]
# ## Load data

# %%
cancer_types = [
    "ccrcc",
    "endometrial",
    "hnscc",
    "lscc",
    "luad",
]

# %%
inputs = {}
for cancer in cancer_types:
    X = pd.read_csv(f'uncleaned_data/{cancer}_inputs.tsv', sep="\t", index_col=0)
    X.isna().sum(axis=0) / X.shape[0]
    inputs[cancer] = X

# %%
targets = {}
for cancer in cancer_types:
    targets[cancer] = pd.read_csv(f'uncleaned_data/{cancer}_targets.tsv', sep="\t", index_col=0)
    
for col in targets['lscc'].columns:
    print(col)
    print(targets['lscc'][col].value_counts(dropna=False).sort_index())
    print()
# Out:
# Recurrence status (1, yes; 0, no)
# 0.0    91
# 1.0    19
# Name: Recurrence status (1, yes; 0, no), dtype: int64
#
# Survial status (1, dead; 0, alive)
# 0.0    89
# 1.0    16
# NaN     5
# Name: Survial status (1, dead; 0, alive), dtype: int64
#
# histologic_type
# Adenosquamous Carcinoma; at least 66% squamous component             1
# Adenosquamous carcinoma                                              1
# Basaloid squamous cell carcinoma                                     2
# Keratinizing squamous cell carcinoma                                18
# Non-keratinizing squamous cell carcinoma                            14
# Solid adenocarcinoma                                                 1
# Spindle cell carcinoma with undifferentiated non small carcinoma     1
# Squamous cell carcinoma                                             71
# adenosquamous carcinoma                                              1
# Name: histologic_type, dtype: int64
#
# pathologic_staging_primary_tumor
# t1     19
# t2     63
# t3     17
# t4      2
# NaN     9
# Name: pathologic_staging_primary_tumor, dtype: int64
#
# histologic_grade
# G1 Well differentiated           1
# G2 Moderately differentiated    58
# G3 Poorly differentiated        48
# GX Grade cannot be assessed      3
# Name: histologic_grade, dtype: int64
#
# measure_of_success_of_outcome_at_last_available_follow-up
# Complete Remission    43
# Not Applicable        10
# Patient Deceased      16
# Persistent Disease    11
# Unknown               13
# NaN                   17
# Name: measure_of_success_of_outcome_at_last_available_follow-up, dtype: int64

# %% [markdown]
# ## Input: Impute unknowns and normalize

# %% [markdown]
# ### Impute numerical column NaNs
#
# We'll just fill with the column mean.

# %%
for cancer in cancer_types:
    inputs[cancer] = inputs[cancer].fillna(inputs[cancer].mean(axis=0))
    
inputs['ccrcc']
# Out:
#             tumor_normal_residual_dist_ADCY3  tumor_normal_residual_dist_AGK  \
# Patient_ID
# C3L-00004                           4.746706                        2.368666
# C3L-00010                           4.746706                        0.160878
# C3L-00011                           4.746706                        0.914093
# C3L-00026                           4.746706                        1.699979
# C3L-00079                           4.746706                        0.600205
# ...                                      ...                             ...
# C3N-01646                           4.746706                        0.780648
# C3N-01648                           4.746706                        1.179941
# C3N-01649                           3.768251                        0.663157
# C3N-01651                           2.546564                        1.107103
# C3N-01808                           6.482955                        0.651401
#
#             tumor_normal_residual_dist_AGXT  tumor_normal_residual_dist_AHSA1  \
# Patient_ID
# C3L-00004                         13.190856                          8.481922
# C3L-00010                         11.688750                         11.935946
# C3L-00011                          3.568109                          6.287237
# C3L-00026                          3.824380                          3.670214
# C3L-00079                          2.337069                          1.420444
# ...                                     ...                               ...
# C3N-01646                          4.981830                          7.273306
# C3N-01648                          5.613505                          0.705244
# C3N-01649                          5.136188                          3.093425
# C3N-01651                         10.179527                          3.290355
# C3N-01808                         14.667738                          5.776070
#
#             tumor_normal_residual_dist_ALDH18A1  \
# Patient_ID
# C3L-00004                              7.053608
# C3L-00010                              4.414980
# C3L-00011                             34.092835
# C3L-00026                             18.820047
# C3L-00079                              9.337463
# ...                                         ...
# C3N-01646                             20.638650
# C3N-01648                              5.357198
# C3N-01649                              1.741500
# C3N-01651                             23.025980
# C3N-01808                             16.348075
#
#             tumor_normal_residual_dist_ANKZF1  \
# Patient_ID
# C3L-00004                            2.121463
# C3L-00010                            2.268968
# C3L-00011                            7.746025
# C3L-00026                            5.686363
# C3L-00079                            3.583359
# ...                                       ...
# C3N-01646                            5.568947
# C3N-01648                            0.381726
# C3N-01649                            2.624052
# C3N-01651                           14.078832
# C3N-01808                            0.793491
#
#             tumor_normal_residual_dist_AP3M1  \
# Patient_ID
# C3L-00004                           1.227607
# C3L-00010                           2.087734
# C3L-00011                           5.285246
# C3L-00026                           1.816493
# C3L-00079                           0.263818
# ...                                      ...
# C3N-01646                           1.877280
# C3N-01648                           2.456724
# C3N-01649                           0.315908
# C3N-01651                           1.001933
# C3N-01808                           1.558424
#
#             tumor_normal_residual_dist_AP4S1  \
# Patient_ID
# C3L-00004                           0.648589
# C3L-00010                           1.128539
# C3L-00011                           1.872484
# C3L-00026                           0.364995
# C3L-00079                           1.039790
# ...                                      ...
# C3N-01646                           1.558076
# C3N-01648                           0.426310
# C3N-01649                           0.386628
# C3N-01651                           0.323635
# C3N-01808                           0.299202
#
#             tumor_normal_residual_dist_APLP2  \
# Patient_ID
# C3L-00004                          90.507645
# C3L-00010                          36.071283
# C3L-00011                           5.217191
# C3L-00026                          73.821719
# C3L-00079                          53.952419
# ...                                      ...
# C3N-01646                           9.978579
# C3N-01648                          34.261414
# C3N-01649                          42.591365
# C3N-01651                          71.024819
# C3N-01808                          44.707714
#
#             tumor_normal_residual_dist_APPL1  ...  signed_orth_res_USP47  \
# Patient_ID                                    ...
# C3L-00004                           1.901647  ...               0.010893
# C3L-00010                           5.221817  ...              -0.075189
# C3L-00011                           2.252784  ...              -0.261528
# C3L-00026                           4.882907  ...               0.088498
# C3L-00079                           7.534761  ...              -0.097382
# ...                                      ...  ...                    ...
# C3N-01646                           5.104328  ...               0.057308
# C3N-01648                           4.428208  ...               0.078408
# C3N-01649                           0.622113  ...              -0.187441
# C3N-01651                           5.637702  ...               0.021833
# C3N-01808                           0.954673  ...               0.017798
#
#             signed_orth_res_USP6NL  signed_orth_res_VPS25  \
# Patient_ID
# C3L-00004                 0.152850               0.181947
# C3L-00010                 0.055203               0.050951
# C3L-00011                -0.312138              -0.777187
# C3L-00026                 0.155157              -0.068772
# C3L-00079                -0.313189              -0.276598
# ...                            ...                    ...
# C3N-01646                -0.252448              -0.027133
# C3N-01648                -0.588844               0.005994
# C3N-01649                 0.058879              -0.050599
# C3N-01651                -0.144407              -0.415184
# C3N-01808                 0.235795              -0.138567
#
#             signed_orth_res_WNK1  signed_orth_res_XPNPEP1  \
# Patient_ID
# C3L-00004               0.149241                 0.422377
# C3L-00010              -0.086946                 0.142795
# C3L-00011               0.605387                -0.179915
# C3L-00026              -0.096996                 0.189214
# C3L-00079               0.065601                 0.052522
# ...                          ...                      ...
# C3N-01646               0.098906                -0.123295
# C3N-01648               0.420178                -0.162881
# C3N-01649              -0.024938                -0.208821
# C3N-01651               0.089418                 0.032847
# C3N-01808               0.107705                 0.114809
#
#             signed_orth_res_YARS2  signed_orth_res_ZDHHC2  \
# Patient_ID
# C3L-00004                0.061650                0.370635
# C3L-00010               -0.338331                0.370635
# C3L-00011               -0.343415                0.018595
# C3L-00026                0.779191                0.370635
# C3L-00079                0.252166                0.370635
# ...                           ...                     ...
# C3N-01646               -0.373050                0.864411
# C3N-01648                0.089283                0.370635
# C3N-01649                0.035469                0.370635
# C3N-01651                0.417992                0.370635
# C3N-01808               -0.069852                0.370635
#
#             signed_orth_res_ZEB1  signed_orth_res_ZNF358  \
# Patient_ID
# C3L-00004               0.042980               -0.069231
# C3L-00010               0.042980                0.141526
# C3L-00011               0.042980                0.113805
# C3L-00026               0.288435                0.141526
# C3L-00079               0.195492                0.141526
# ...                          ...                     ...
# C3N-01646               0.042980                0.141526
# C3N-01648               0.042980                0.615288
# C3N-01649              -0.710171                0.141526
# C3N-01651               0.201946                0.141526
# C3N-01808               0.556281                0.141526
#
#             signed_orth_res_ZNF397
# Patient_ID
# C3L-00004                -0.049632
# C3L-00010                -0.049632
# C3L-00011                -0.049632
# C3L-00026                -0.049632
# C3L-00079                -0.049632
# ...                            ...
# C3N-01646                -0.092570
# C3N-01648                -0.049632
# C3N-01649                -0.049632
# C3N-01651                -0.078130
# C3N-01808                -0.049632
#
# [75 rows x 372 columns]

# %% [markdown]
# ### Normalize numerical columns

# %%
for cancer in cancer_types:
    X_num = inputs[cancer]
    mins = X_num.min(axis=0)
    maxs = X_num.max(axis=0)
    inputs[cancer] = (X_num - mins) / (maxs - mins)

# %% [markdown]
# ### Save

# %%
for cancer in cancer_types:
    inputs[cancer].to_csv(f'clean_data/{cancer}_inputs.tsv', sep="\t")

# %% [markdown]
# ## Targets

# %% [markdown]
# Convert everything to lowercase.

# %%
def to_lowercase(y):
    for col in y.columns:
        if y[col].dtype == "O":
            y = y.assign(**{col: y[col].str.lower()})
            
    return y

# %% [markdown]
# First we're going to combine the similar groups in histologic_grade.

# %%
def combine_grade(y):
    y = y.assign(histologic_grade=y["histologic_grade"].str[:2])
    return y

# %% [markdown]
# Also group similar groups in histologic_type.

# %%
def combine_type(y): 
    y = y.assign(histologic_type=y["histologic_type"].replace(
        to_replace="adenocarcinoma, acinar predominant ",
        value="acinar adenocarcinoma",
    ).replace(
        to_replace="mixed acinar and micropapillary adenocarcinoma",
        value="adenocarcinoma, micropapillary and acinar",
    ).replace(
        to_replace="lepidic adenocarcinoma, invasive mucinous adenocarcinoma",
        value="lepidic adenocarcinoma",
    ).replace(
        to_replace="adenosquamous carcinoma (approx. 75% adeno, 25% squamous)",
        value="adenosquamous carcinoma",
    ).replace(
        to_replace="squamous cell carcinoma, conventional",
        value="squamous cell carcinoma",
    ).replace(
        to_replace="adenocaricnoma, mixed sub-type (solid and acinar)",
        value="adenocarcinoma, mixed subtype",
    ))
    
    return y

# %% [markdown]
# Shorten some column names.

# %%
def shorten_cols(y):   
    y.columns = y.columns.to_series().replace(
        "measure_of_success_of_outcome_at_last_available_follow-up",
        "success_last_follow-up",
    ).replace(
        "pathologic_staging_primary_tumor",
        "tumor_stage",
    ).replace(
        "Recurrence status (1, yes; 0, no)",
        "recurrence_status",
    ).replace(
        "Survial status (1, dead; 0, alive)",
        "survival_status",
    )
    
    return y

# %% [markdown]
# ### Address NaNs
#
# We'll just fill with the column mode.

# %%
def fill_nan(y):
    y = y.fillna(y.mode(dropna=True).iloc[0, :])
    return y

# %% [markdown]
# ### Get cleaned targets

# %%
for cancer in cancer_types:
    y = targets[cancer]
    y = to_lowercase(y)
    y = combine_grade(y)
    y = combine_type(y)
    y = shorten_cols(y)
    targets[cancer] = fill_nan(y)

# %% [markdown]
# Check the finished product.

# %%
for col in targets['luad'].columns:
    print(col)
    print(targets['luad'][col].value_counts(dropna=False).sort_index())
    print()
# Out:
# Recurrence status (1, yes; 0, no)
# 0.0    89
# 1.0    22
# Name: Recurrence status (1, yes; 0, no), dtype: int64
#
# Survial status (1, dead; 0, alive)
# 0.0    84
# 1.0    23
# NaN     4
# Name: Survial status (1, dead; 0, alive), dtype: int64
#
# histologic_type
# Acinar adenocarcinoma                                        25
# Acinar adenocarcinoma and papillary adenocarcinoma            1
# Adenocarcinoma                                               57
# Adenocarcinoma, acinar predominant                            1
# Adenocarcinoma, micropapillary and acinar                     1
# Adenocarcinoma, mixed subtype                                 1
# Adenocaricnoma, mixed sub-type (solid and acinar)             1
# Adenosquamous carcinoma                                       1
# Adenosquamous carcinoma (approx. 75% adeno, 25% squamous)     1
# Colloid adenocarcinoma                                        1
# Lepidic adenocarcinoma                                        2
# Lepidic adenocarcinoma, Invasive mucinous adenocarcinoma      1
# Mixed acinar and micropapillary adenocarcinoma                1
# Papillary adenocarcinoma                                      3
# Solid adenocarcinoma                                          7
# Squamous cell carcinoma                                       1
# adenocarcinoma with neuroendocrine differentiation            1
# not specified                                                 4
# squamous versus adenocarcinoma pending IHC                    1
# Name: histologic_type, dtype: int64
#
# pathologic_staging_primary_tumor
# t1    28
# t2    70
# t3    13
# Name: pathologic_staging_primary_tumor, dtype: int64
#
# histologic_grade
# G1 Well differentiated           7
# G2 Moderately differentiated    59
# G3 Poorly differentiated        39
# GX Grade cannot be assessed      6
# Name: histologic_grade, dtype: int64
#
# measure_of_success_of_outcome_at_last_available_follow-up
# Complete Remission    33
# Not Applicable        20
# Patient Deceased      23
# Persistent Disease    11
# Unknown               13
# NaN                   11
# Name: measure_of_success_of_outcome_at_last_available_follow-up, dtype: int64

# %% [markdown]
# ### Remove patients from targets that are not in inputs

# %%
for cancer in cancer_types:
    ind = inputs[cancer].index.tolist()
    targets[cancer] = targets[cancer].loc[ind]

# %% [markdown]
# Save the targets.

# %%
for cancer in cancer_types:
    targets[cancer].to_csv(f'clean_data/{cancer}_targets.tsv', sep="\t")
